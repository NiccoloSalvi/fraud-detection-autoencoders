# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import RobustScaler
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset

data = pd.read_csv('creditcard.csv')

dataset = data.to_numpy().astype(np.float32)  # Ensure data is float32 for PyTorch

scaler = RobustScaler(with_centering=True, with_scaling=True, quantile_range=(25.0, 75.0), unit_variance=False)
dataset[:, [0, 29]] = scaler.fit_transform(dataset[:, [0, 29]])

# %%
data_train, data_test = train_test_split(dataset, test_size=0.3, random_state=42)

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset
from sklearn.preprocessing import StandardScaler, MinMaxScaler, RobustScaler
from sklearn.model_selection import train_test_split
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# -----------------------------
# 3. Define the Autoencoder Model
# -----------------------------
class Autoencoder(nn.Module):
    def __init__(self):
        super(Autoencoder, self).__init__()
        # Encoder: 31 -> 23 -> 19 -> 17 -> 8 with dropout after first two hidden layers
        self.encoder = nn.Sequential(
            nn.Linear(31, 23),
            nn.Tanh(),
            nn.Dropout(0.1),
            nn.Linear(23, 19),
            nn.Tanh(),
            nn.Dropout(0.2),
            nn.Linear(19, 17),
            nn.Tanh(),
            nn.Linear(17, 8)
        )
        # Decoder: 8 -> 17 -> 19 -> 23 -> 31 with dropout after first two layers
        self.decoder = nn.Sequential(
            nn.Linear(8, 17),
            nn.Tanh(),
            nn.Dropout(0.2),
            nn.Linear(17, 19),
            nn.Tanh(),
            nn.Dropout(0.1),
            nn.Linear(19, 23),
            nn.Tanh(),
            nn.Linear(23, 31)
        )

    def forward(self, x):
        latent = self.encoder(x)
        reconstructed = self.decoder(latent)
        return reconstructed

# %%
fraud_data = data_train[data_train[:, -1] == 1]
non_fraud_data = data_train[data_train[:, -1] == 0]

legit_data_limited = non_fraud_data[np.random.choice(non_fraud_data.shape[0], fraud_data.shape[0], replace=False)]

train_dataset_SVM = np.vstack((legit_data_limited, fraud_data))
np.random.shuffle(train_dataset_SVM)
train_labels_SVM = train_dataset_SVM[:, -1]
train_dataset_SVM = train_dataset_SVM[:, :-1]

data_train_SVM, data_test_SVM, labels_train_SVM, labels_test_SVM = train_test_split(train_dataset_SVM, train_labels_SVM, test_size=0.2, random_state=42)
model = SVC(kernel='linear', C=1.0)
model.fit(data_train_SVM, labels_train_SVM)

labels_pred_test = model.predict(data_test_SVM)
labels_pred_train = model.predict(data_train_SVM)
accuracy_train = jnp.mean(labels_pred_train == labels_train_SVM)
accuracy_test = jnp.mean(labels_pred_test == labels_test_SVM)

print(f"Train Accuracy: {accuracy_train:.4f}")
print(f"Test Accuracy: {accuracy_test:.4f}")
# Out:
# Train Accuracy: 0.9578
# Test Accuracy: 0.9580

# %%
# load the model 
myModel = Autoencoder()

# Load the saved state dictionary
myModel.load_state_dict(torch.load("model/autoencoder/autoencoder.pth", map_location=torch.device('cpu'), weights_only=True))
myModel.eval()

alpha = 0.9

data_train_oversampled = data_train.copy()

while (len(data_train_oversampled[data_train_oversampled[:, -1] == 1]) < len(data_train_oversampled[data_train_oversampled[:, -1] == 0])):
    fraud_data = data_train_oversampled[data_train_oversampled[:, -1] == 1]

    # 2) Generate synthetic data by interpolating between fraud data points
    fraud_data_tensor = torch.tensor(fraud_data, dtype=torch.float32)

    latent_representations = myModel.encoder(fraud_data_tensor)

    noisy_vectors = []
    for _ in range(300):
        # Pick a random fraud vector
        i = np.random.randint(0, n)
        z_i = latent_representations[i]

        # Optionally pick a second random vector to interpolate
        j = np.random.randint(0, n)
        z_j = latent_representations[j]
        
        # Interpolation factor
        lambda_ = np.random.rand()
        z_ij = lambda_*z_i + (1 - lambda_)*z_j
        
        # Add Gaussian noise around that interpolation
        noise = torch.normal(mean=0.0, std=alpha, size=(latent_dim,))
        z_syn = z_ij + noise  # Both are tensors, so this should work directly

        noisy_vectors.append(z_syn.detach().numpy())

    noisy_vectors = np.array(noisy_vectors)

    # 3) Decode them to get synthetic data in original input space
    X_synthetic = myModel.decoder(torch.tensor(noisy_vectors, dtype=torch.float32)).detach().numpy()
    # remove label
    X_synthetic_to_predict = X_synthetic[:, :-1]
    # 4) Validate with SVM
    y_pred = model.predict(X_synthetic_to_predict)

    X_synthetic[:, -1] = y_pred

    # 5) Add the synthetic data to the training set
    X_synthetic_fraud = X_synthetic[X_synthetic[:, -1] == 1]

    data_train_oversampled = np.vstack((data_train_oversampled, X_synthetic_fraud))

    print("New synthetic data generated", len(X_synthetic_fraud))
    print(f"Number of fraud in the balanced dataset {len(data_train_oversampled[data_train_oversampled[:, -1] == 1])}/{len(data_train_oversampled[data_train_oversampled[:, -1] == 0])}")

# for i in range(len(data_train_oversampled[data_train_oversampled[:, -1] == 1]) - len(data_train_oversampled[data_train_oversampled[:, -1] == 0])):
#     noisy_vectors = []
#     for _ in range(n):
#         # Pick a random fraud vector
#         i = np.random.randint(0, n)
#         z_i = latent_representations[i]

#         # Optionally pick a second random vector to interpolate
#         j = np.random.randint(0, n)
#         z_j = latent_representations[j]
        
#         # Interpolation factor
#         lambda_ = np.random.rand()
#         z_ij = lambda_*z_i + (1 - lambda_)*z_j
        
#         # Add Gaussian noise around that interpolation
#         noise = torch.normal(mean=0.0, std=alpha, size=(latent_dim,))
#         z_syn = z_ij + noise  # Both are tensors, so this should work directly

#         noisy_vectors.append(z_syn.detach().numpy())

#     noisy_vectors = np.array(noisy_vectors)

#     # 3) Decode them to get synthetic data in original input space
#     X_synthetic = myModel.decoder(torch.tensor(noisy_vectors, dtype=torch.float32)).detach().numpy()
#     # remove label
#     X_synthetic_to_predict = X_synthetic[:, :-1]
#     # 4) Validate with SVM
#     y_pred = model.predict(X_synthetic_to_predict)

#     X_synthetic[:, -1] = y_pred

#     # 5) Add the synthetic data to the training set
#     X_synthetic_fraud = X_synthetic[X_synthetic[:, -1] == 1]

#     data_train_oversampled = np.vstack((data_train_oversampled, X_synthetic_fraud))

print(data_train_oversampled.shape)
print("Number of fraud in the balanced dataset", len(data_train_oversampled[data_train_oversampled[:, -1] == 1]))
print("Number of non-fraud in the balanced dataset", len(data_train_oversampled[data_train_oversampled[:, -1] == 0]))
# Out:
# New synthetic data generated 283
# Number of fraud in the balanced dataset 639/199008
# New synthetic data generated 288
# Number of fraud in the balanced dataset 927/199008
# New synthetic data generated 292
# Number of fraud in the balanced dataset 1219/199008
# New synthetic data generated 290
# Number of fraud in the balanced dataset 1509/199008
# New synthetic data generated 287
# Number of fraud in the balanced dataset 1796/199008
# New synthetic data generated 297
# Number of fraud in the balanced dataset 2093/199008
# New synthetic data generated 288
# Number of fraud in the balanced dataset 2381/199008
# New synthetic data generated 285
# Number of fraud in the balanced dataset 2666/199008
# New synthetic data generated 287
# Number of fraud in the balanced dataset 2953/199008
# New synthetic data generated 286
# Number of fraud in the balanced dataset 3239/199008
# New synthetic data generated 289
# Number of fraud in the balanced dataset 3528/199008
# New synthetic data generated 288
# Number of fraud in the balanced dataset 3816/199008
# New synthetic data generated 282
# Number of fraud in the balanced dataset 4098/199008
# New synthetic data generated 289
# Number of fraud in the balanced dataset 4387/199008
# New synthetic data generated 288
# Number of fraud in the balanced dataset 4675/199008
# New synthetic data generated 296
# Number of fraud in the balanced dataset 4971/199008
# New synthetic data generated 284
# Number of fraud in the balanced dataset 5255/199008
# New synthetic data generated 290
# Number of fraud in the balanced dataset 5545/199008
# New synthetic data generated 288
# Number of fraud in the balanced dataset 5833/199008
# New synthetic data generated 283
# Number of fraud in the balanced dataset 6116/199008
# New synthetic data generated 286
# Number of fraud in the balanced dataset 6402/199008
# New synthetic data generated 289
# Number of fraud in the balanced dataset 6691/199008
# New synthetic data generated 285
# Number of fraud in the balanced dataset 6976/199008
# New synthetic data generated 289
# Number of fraud in the balanced dataset 7265/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 7560/199008
# New synthetic data generated 286
# Number of fraud in the balanced dataset 7846/199008
# New synthetic data generated 288
# Number of fraud in the balanced dataset 8134/199008
# New synthetic data generated 288
# Number of fraud in the balanced dataset 8422/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 8717/199008
# New synthetic data generated 289
# Number of fraud in the balanced dataset 9006/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 9300/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 9594/199008
# New synthetic data generated 292
# Number of fraud in the balanced dataset 9886/199008
# New synthetic data generated 287
# Number of fraud in the balanced dataset 10173/199008
# New synthetic data generated 289
# Number of fraud in the balanced dataset 10462/199008
# New synthetic data generated 286
# Number of fraud in the balanced dataset 10748/199008
# New synthetic data generated 288
# Number of fraud in the balanced dataset 11036/199008
# New synthetic data generated 287
# Number of fraud in the balanced dataset 11323/199008
# New synthetic data generated 286
# Number of fraud in the balanced dataset 11609/199008
# New synthetic data generated 291
# Number of fraud in the balanced dataset 11900/199008
# New synthetic data generated 286
# Number of fraud in the balanced dataset 12186/199008
# New synthetic data generated 290
# Number of fraud in the balanced dataset 12476/199008
# New synthetic data generated 287
# Number of fraud in the balanced dataset 12763/199008
# New synthetic data generated 293
# Number of fraud in the balanced dataset 13056/199008
# New synthetic data generated 284
# Number of fraud in the balanced dataset 13340/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 13634/199008
# New synthetic data generated 287
# Number of fraud in the balanced dataset 13921/199008
# New synthetic data generated 288
# Number of fraud in the balanced dataset 14209/199008
# New synthetic data generated 288
# Number of fraud in the balanced dataset 14497/199008
# New synthetic data generated 288
# Number of fraud in the balanced dataset 14785/199008
# New synthetic data generated 293
# Number of fraud in the balanced dataset 15078/199008
# New synthetic data generated 293
# Number of fraud in the balanced dataset 15371/199008
# New synthetic data generated 296
# Number of fraud in the balanced dataset 15667/199008
# New synthetic data generated 288
# Number of fraud in the balanced dataset 15955/199008
# New synthetic data generated 291
# Number of fraud in the balanced dataset 16246/199008
# New synthetic data generated 291
# Number of fraud in the balanced dataset 16537/199008
# New synthetic data generated 289
# Number of fraud in the balanced dataset 16826/199008
# New synthetic data generated 290
# Number of fraud in the balanced dataset 17116/199008
# New synthetic data generated 285
# Number of fraud in the balanced dataset 17401/199008
# New synthetic data generated 284
# Number of fraud in the balanced dataset 17685/199008
# New synthetic data generated 293
# Number of fraud in the balanced dataset 17978/199008
# New synthetic data generated 288
# Number of fraud in the balanced dataset 18266/199008
# New synthetic data generated 287
# Number of fraud in the balanced dataset 18553/199008
# New synthetic data generated 287
# Number of fraud in the balanced dataset 18840/199008
# New synthetic data generated 287
# Number of fraud in the balanced dataset 19127/199008
# New synthetic data generated 289
# Number of fraud in the balanced dataset 19416/199008
# New synthetic data generated 290
# Number of fraud in the balanced dataset 19706/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 20000/199008
# New synthetic data generated 287
# Number of fraud in the balanced dataset 20287/199008
# New synthetic data generated 287
# Number of fraud in the balanced dataset 20574/199008
# New synthetic data generated 291
# Number of fraud in the balanced dataset 20865/199008
# New synthetic data generated 290
# Number of fraud in the balanced dataset 21155/199008
# New synthetic data generated 288
# Number of fraud in the balanced dataset 21443/199008
# New synthetic data generated 289
# Number of fraud in the balanced dataset 21732/199008
# New synthetic data generated 292
# Number of fraud in the balanced dataset 22024/199008
# New synthetic data generated 289
# Number of fraud in the balanced dataset 22313/199008
# New synthetic data generated 292
# Number of fraud in the balanced dataset 22605/199008
# New synthetic data generated 289
# Number of fraud in the balanced dataset 22894/199008
# New synthetic data generated 286
# Number of fraud in the balanced dataset 23180/199008
# New synthetic data generated 291
# Number of fraud in the balanced dataset 23471/199008
# New synthetic data generated 291
# Number of fraud in the balanced dataset 23762/199008
# New synthetic data generated 292
# Number of fraud in the balanced dataset 24054/199008
# New synthetic data generated 287
# Number of fraud in the balanced dataset 24341/199008
# New synthetic data generated 292
# Number of fraud in the balanced dataset 24633/199008
# New synthetic data generated 292
# Number of fraud in the balanced dataset 24925/199008
# New synthetic data generated 291
# Number of fraud in the balanced dataset 25216/199008
# New synthetic data generated 289
# Number of fraud in the balanced dataset 25505/199008
# New synthetic data generated 291
# Number of fraud in the balanced dataset 25796/199008
# New synthetic data generated 290
# Number of fraud in the balanced dataset 26086/199008
# New synthetic data generated 289
# Number of fraud in the balanced dataset 26375/199008
# New synthetic data generated 292
# Number of fraud in the balanced dataset 26667/199008
# New synthetic data generated 285
# Number of fraud in the balanced dataset 26952/199008
# New synthetic data generated 285
# Number of fraud in the balanced dataset 27237/199008
# New synthetic data generated 292
# Number of fraud in the balanced dataset 27529/199008
# New synthetic data generated 283
# Number of fraud in the balanced dataset 27812/199008
# New synthetic data generated 282
# Number of fraud in the balanced dataset 28094/199008
# New synthetic data generated 291
# Number of fraud in the balanced dataset 28385/199008
# New synthetic data generated 289
# Number of fraud in the balanced dataset 28674/199008
# New synthetic data generated 290
# Number of fraud in the balanced dataset 28964/199008
# New synthetic data generated 285
# Number of fraud in the balanced dataset 29249/199008
# New synthetic data generated 290
# Number of fraud in the balanced dataset 29539/199008
# New synthetic data generated 290
# Number of fraud in the balanced dataset 29829/199008
# New synthetic data generated 286
# Number of fraud in the balanced dataset 30115/199008
# New synthetic data generated 287
# Number of fraud in the balanced dataset 30402/199008
# New synthetic data generated 289
# Number of fraud in the balanced dataset 30691/199008
# New synthetic data generated 288
# Number of fraud in the balanced dataset 30979/199008
# New synthetic data generated 293
# Number of fraud in the balanced dataset 31272/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 31566/199008
# New synthetic data generated 286
# Number of fraud in the balanced dataset 31852/199008
# New synthetic data generated 286
# Number of fraud in the balanced dataset 32138/199008
# New synthetic data generated 291
# Number of fraud in the balanced dataset 32429/199008
# New synthetic data generated 290
# Number of fraud in the balanced dataset 32719/199008
# New synthetic data generated 288
# Number of fraud in the balanced dataset 33007/199008
# New synthetic data generated 289
# Number of fraud in the balanced dataset 33296/199008
# New synthetic data generated 283
# Number of fraud in the balanced dataset 33579/199008
# New synthetic data generated 288
# Number of fraud in the balanced dataset 33867/199008
# New synthetic data generated 288
# Number of fraud in the balanced dataset 34155/199008
# New synthetic data generated 288
# Number of fraud in the balanced dataset 34443/199008
# New synthetic data generated 278
# Number of fraud in the balanced dataset 34721/199008
# New synthetic data generated 292
# Number of fraud in the balanced dataset 35013/199008
# New synthetic data generated 285
# Number of fraud in the balanced dataset 35298/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 35592/199008
# New synthetic data generated 289
# Number of fraud in the balanced dataset 35881/199008
# New synthetic data generated 289
# Number of fraud in the balanced dataset 36170/199008
# New synthetic data generated 285
# Number of fraud in the balanced dataset 36455/199008
# New synthetic data generated 287
# Number of fraud in the balanced dataset 36742/199008
# New synthetic data generated 291
# Number of fraud in the balanced dataset 37033/199008
# New synthetic data generated 292
# Number of fraud in the balanced dataset 37325/199008
# New synthetic data generated 288
# Number of fraud in the balanced dataset 37613/199008
# New synthetic data generated 286
# Number of fraud in the balanced dataset 37899/199008
# New synthetic data generated 288
# Number of fraud in the balanced dataset 38187/199008
# New synthetic data generated 291
# Number of fraud in the balanced dataset 38478/199008
# New synthetic data generated 290
# Number of fraud in the balanced dataset 38768/199008
# New synthetic data generated 290
# Number of fraud in the balanced dataset 39058/199008
# New synthetic data generated 292
# Number of fraud in the balanced dataset 39350/199008
# New synthetic data generated 292
# Number of fraud in the balanced dataset 39642/199008
# New synthetic data generated 282
# Number of fraud in the balanced dataset 39924/199008
# New synthetic data generated 288
# Number of fraud in the balanced dataset 40212/199008
# New synthetic data generated 284
# Number of fraud in the balanced dataset 40496/199008
# New synthetic data generated 287
# Number of fraud in the balanced dataset 40783/199008
# New synthetic data generated 291
# Number of fraud in the balanced dataset 41074/199008
# New synthetic data generated 290
# Number of fraud in the balanced dataset 41364/199008
# New synthetic data generated 291
# Number of fraud in the balanced dataset 41655/199008
# New synthetic data generated 291
# Number of fraud in the balanced dataset 41946/199008
# New synthetic data generated 290
# Number of fraud in the balanced dataset 42236/199008
# New synthetic data generated 289
# Number of fraud in the balanced dataset 42525/199008
# New synthetic data generated 288
# Number of fraud in the balanced dataset 42813/199008
# New synthetic data generated 287
# Number of fraud in the balanced dataset 43100/199008
# New synthetic data generated 290
# Number of fraud in the balanced dataset 43390/199008
# New synthetic data generated 292
# Number of fraud in the balanced dataset 43682/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 43977/199008
# New synthetic data generated 285
# Number of fraud in the balanced dataset 44262/199008
# New synthetic data generated 288
# Number of fraud in the balanced dataset 44550/199008
# New synthetic data generated 286
# Number of fraud in the balanced dataset 44836/199008
# New synthetic data generated 286
# Number of fraud in the balanced dataset 45122/199008
# New synthetic data generated 289
# Number of fraud in the balanced dataset 45411/199008
# New synthetic data generated 290
# Number of fraud in the balanced dataset 45701/199008
# New synthetic data generated 288
# Number of fraud in the balanced dataset 45989/199008
# New synthetic data generated 290
# Number of fraud in the balanced dataset 46279/199008
# New synthetic data generated 291
# Number of fraud in the balanced dataset 46570/199008
# New synthetic data generated 292
# Number of fraud in the balanced dataset 46862/199008
# New synthetic data generated 292
# Number of fraud in the balanced dataset 47154/199008
# New synthetic data generated 289
# Number of fraud in the balanced dataset 47443/199008
# New synthetic data generated 289
# Number of fraud in the balanced dataset 47732/199008
# New synthetic data generated 286
# Number of fraud in the balanced dataset 48018/199008
# New synthetic data generated 292
# Number of fraud in the balanced dataset 48310/199008
# New synthetic data generated 291
# Number of fraud in the balanced dataset 48601/199008
# New synthetic data generated 290
# Number of fraud in the balanced dataset 48891/199008
# New synthetic data generated 292
# Number of fraud in the balanced dataset 49183/199008
# New synthetic data generated 288
# Number of fraud in the balanced dataset 49471/199008
# New synthetic data generated 289
# Number of fraud in the balanced dataset 49760/199008
# New synthetic data generated 282
# Number of fraud in the balanced dataset 50042/199008
# New synthetic data generated 290
# Number of fraud in the balanced dataset 50332/199008
# New synthetic data generated 285
# Number of fraud in the balanced dataset 50617/199008
# New synthetic data generated 286
# Number of fraud in the balanced dataset 50903/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 51197/199008
# New synthetic data generated 290
# Number of fraud in the balanced dataset 51487/199008
# New synthetic data generated 284
# Number of fraud in the balanced dataset 51771/199008
# New synthetic data generated 290
# Number of fraud in the balanced dataset 52061/199008
# New synthetic data generated 289
# Number of fraud in the balanced dataset 52350/199008
# New synthetic data generated 285
# Number of fraud in the balanced dataset 52635/199008
# New synthetic data generated 283
# Number of fraud in the balanced dataset 52918/199008
# New synthetic data generated 296
# Number of fraud in the balanced dataset 53214/199008
# New synthetic data generated 296
# Number of fraud in the balanced dataset 53510/199008
# New synthetic data generated 290
# Number of fraud in the balanced dataset 53800/199008
# New synthetic data generated 298
# Number of fraud in the balanced dataset 54098/199008
# New synthetic data generated 286
# Number of fraud in the balanced dataset 54384/199008
# New synthetic data generated 286
# Number of fraud in the balanced dataset 54670/199008
# New synthetic data generated 283
# Number of fraud in the balanced dataset 54953/199008
# New synthetic data generated 290
# Number of fraud in the balanced dataset 55243/199008
# New synthetic data generated 290
# Number of fraud in the balanced dataset 55533/199008
# New synthetic data generated 283
# Number of fraud in the balanced dataset 55816/199008
# New synthetic data generated 285
# Number of fraud in the balanced dataset 56101/199008
# New synthetic data generated 287
# Number of fraud in the balanced dataset 56388/199008
# New synthetic data generated 283
# Number of fraud in the balanced dataset 56671/199008
# New synthetic data generated 287
# Number of fraud in the balanced dataset 56958/199008
# New synthetic data generated 291
# Number of fraud in the balanced dataset 57249/199008
# New synthetic data generated 291
# Number of fraud in the balanced dataset 57540/199008
# New synthetic data generated 282
# Number of fraud in the balanced dataset 57822/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 58117/199008
# New synthetic data generated 284
# Number of fraud in the balanced dataset 58401/199008
# New synthetic data generated 281
# Number of fraud in the balanced dataset 58682/199008
# New synthetic data generated 287
# Number of fraud in the balanced dataset 58969/199008
# New synthetic data generated 292
# Number of fraud in the balanced dataset 59261/199008
# New synthetic data generated 289
# Number of fraud in the balanced dataset 59550/199008
# New synthetic data generated 287
# Number of fraud in the balanced dataset 59837/199008
# New synthetic data generated 288
# Number of fraud in the balanced dataset 60125/199008
# New synthetic data generated 293
# Number of fraud in the balanced dataset 60418/199008
# New synthetic data generated 277
# Number of fraud in the balanced dataset 60695/199008
# New synthetic data generated 289
# Number of fraud in the balanced dataset 60984/199008
# New synthetic data generated 292
# Number of fraud in the balanced dataset 61276/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 61571/199008
# New synthetic data generated 290
# Number of fraud in the balanced dataset 61861/199008
# New synthetic data generated 286
# Number of fraud in the balanced dataset 62147/199008
# New synthetic data generated 292
# Number of fraud in the balanced dataset 62439/199008
# New synthetic data generated 291
# Number of fraud in the balanced dataset 62730/199008
# New synthetic data generated 282
# Number of fraud in the balanced dataset 63012/199008
# New synthetic data generated 286
# Number of fraud in the balanced dataset 63298/199008
# New synthetic data generated 283
# Number of fraud in the balanced dataset 63581/199008
# New synthetic data generated 287
# Number of fraud in the balanced dataset 63868/199008
# New synthetic data generated 289
# Number of fraud in the balanced dataset 64157/199008
# New synthetic data generated 293
# Number of fraud in the balanced dataset 64450/199008
# New synthetic data generated 280
# Number of fraud in the balanced dataset 64730/199008
# New synthetic data generated 290
# Number of fraud in the balanced dataset 65020/199008
# New synthetic data generated 284
# Number of fraud in the balanced dataset 65304/199008
# New synthetic data generated 287
# Number of fraud in the balanced dataset 65591/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 65886/199008
# New synthetic data generated 288
# Number of fraud in the balanced dataset 66174/199008
# New synthetic data generated 291
# Number of fraud in the balanced dataset 66465/199008
# New synthetic data generated 289
# Number of fraud in the balanced dataset 66754/199008
# New synthetic data generated 286
# Number of fraud in the balanced dataset 67040/199008
# New synthetic data generated 289
# Number of fraud in the balanced dataset 67329/199008
# New synthetic data generated 291
# Number of fraud in the balanced dataset 67620/199008
# New synthetic data generated 289
# Number of fraud in the balanced dataset 67909/199008
# New synthetic data generated 288
# Number of fraud in the balanced dataset 68197/199008
# New synthetic data generated 284
# Number of fraud in the balanced dataset 68481/199008
# New synthetic data generated 287
# Number of fraud in the balanced dataset 68768/199008
# New synthetic data generated 292
# Number of fraud in the balanced dataset 69060/199008
# New synthetic data generated 290
# Number of fraud in the balanced dataset 69350/199008
# New synthetic data generated 278
# Number of fraud in the balanced dataset 69628/199008
# New synthetic data generated 290
# Number of fraud in the balanced dataset 69918/199008
# New synthetic data generated 290
# Number of fraud in the balanced dataset 70208/199008
# New synthetic data generated 289
# Number of fraud in the balanced dataset 70497/199008
# New synthetic data generated 293
# Number of fraud in the balanced dataset 70790/199008
# New synthetic data generated 283
# Number of fraud in the balanced dataset 71073/199008
# New synthetic data generated 290
# Number of fraud in the balanced dataset 71363/199008
# New synthetic data generated 293
# Number of fraud in the balanced dataset 71656/199008
# New synthetic data generated 288
# Number of fraud in the balanced dataset 71944/199008
# New synthetic data generated 288
# Number of fraud in the balanced dataset 72232/199008
# New synthetic data generated 288
# Number of fraud in the balanced dataset 72520/199008
# New synthetic data generated 293
# Number of fraud in the balanced dataset 72813/199008
# New synthetic data generated 291
# Number of fraud in the balanced dataset 73104/199008
# New synthetic data generated 289
# Number of fraud in the balanced dataset 73393/199008
# New synthetic data generated 286
# Number of fraud in the balanced dataset 73679/199008
# New synthetic data generated 292
# Number of fraud in the balanced dataset 73971/199008
# New synthetic data generated 291
# Number of fraud in the balanced dataset 74262/199008
# New synthetic data generated 291
# Number of fraud in the balanced dataset 74553/199008
# New synthetic data generated 290
# Number of fraud in the balanced dataset 74843/199008
# New synthetic data generated 286
# Number of fraud in the balanced dataset 75129/199008
# New synthetic data generated 287
# Number of fraud in the balanced dataset 75416/199008
# New synthetic data generated 292
# Number of fraud in the balanced dataset 75708/199008
# New synthetic data generated 291
# Number of fraud in the balanced dataset 75999/199008
# New synthetic data generated 287
# Number of fraud in the balanced dataset 76286/199008
# New synthetic data generated 286
# Number of fraud in the balanced dataset 76572/199008
# New synthetic data generated 292
# Number of fraud in the balanced dataset 76864/199008
# New synthetic data generated 284
# Number of fraud in the balanced dataset 77148/199008
# New synthetic data generated 289
# Number of fraud in the balanced dataset 77437/199008
# New synthetic data generated 290
# Number of fraud in the balanced dataset 77727/199008
# New synthetic data generated 287
# Number of fraud in the balanced dataset 78014/199008
# New synthetic data generated 288
# Number of fraud in the balanced dataset 78302/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 78596/199008
# New synthetic data generated 284
# Number of fraud in the balanced dataset 78880/199008
# New synthetic data generated 287
# Number of fraud in the balanced dataset 79167/199008
# New synthetic data generated 291
# Number of fraud in the balanced dataset 79458/199008
# New synthetic data generated 293
# Number of fraud in the balanced dataset 79751/199008
# New synthetic data generated 287
# Number of fraud in the balanced dataset 80038/199008
# New synthetic data generated 283
# Number of fraud in the balanced dataset 80321/199008
# New synthetic data generated 285
# Number of fraud in the balanced dataset 80606/199008
# New synthetic data generated 286
# Number of fraud in the balanced dataset 80892/199008
# New synthetic data generated 290
# Number of fraud in the balanced dataset 81182/199008
# New synthetic data generated 285
# Number of fraud in the balanced dataset 81467/199008
# New synthetic data generated 287
# Number of fraud in the balanced dataset 81754/199008
# New synthetic data generated 290
# Number of fraud in the balanced dataset 82044/199008
# New synthetic data generated 285
# Number of fraud in the balanced dataset 82329/199008
# New synthetic data generated 289
# Number of fraud in the balanced dataset 82618/199008
# New synthetic data generated 293
# Number of fraud in the balanced dataset 82911/199008
# New synthetic data generated 289
# Number of fraud in the balanced dataset 83200/199008
# New synthetic data generated 290
# Number of fraud in the balanced dataset 83490/199008
# New synthetic data generated 290
# Number of fraud in the balanced dataset 83780/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 84074/199008
# New synthetic data generated 293
# Number of fraud in the balanced dataset 84367/199008
# New synthetic data generated 285
# Number of fraud in the balanced dataset 84652/199008
# New synthetic data generated 289
# Number of fraud in the balanced dataset 84941/199008
# New synthetic data generated 288
# Number of fraud in the balanced dataset 85229/199008
# New synthetic data generated 293
# Number of fraud in the balanced dataset 85522/199008
# New synthetic data generated 288
# Number of fraud in the balanced dataset 85810/199008
# New synthetic data generated 290
# Number of fraud in the balanced dataset 86100/199008
# New synthetic data generated 290
# Number of fraud in the balanced dataset 86390/199008
# New synthetic data generated 291
# Number of fraud in the balanced dataset 86681/199008
# New synthetic data generated 285
# Number of fraud in the balanced dataset 86966/199008
# New synthetic data generated 289
# Number of fraud in the balanced dataset 87255/199008
# New synthetic data generated 288
# Number of fraud in the balanced dataset 87543/199008
# New synthetic data generated 291
# Number of fraud in the balanced dataset 87834/199008
# New synthetic data generated 286
# Number of fraud in the balanced dataset 88120/199008
# New synthetic data generated 286
# Number of fraud in the balanced dataset 88406/199008
# New synthetic data generated 285
# Number of fraud in the balanced dataset 88691/199008
# New synthetic data generated 279
# Number of fraud in the balanced dataset 88970/199008
# New synthetic data generated 291
# Number of fraud in the balanced dataset 89261/199008
# New synthetic data generated 287
# Number of fraud in the balanced dataset 89548/199008
# New synthetic data generated 287
# Number of fraud in the balanced dataset 89835/199008
# New synthetic data generated 289
# Number of fraud in the balanced dataset 90124/199008
# New synthetic data generated 289
# Number of fraud in the balanced dataset 90413/199008
# New synthetic data generated 293
# Number of fraud in the balanced dataset 90706/199008
# New synthetic data generated 286
# Number of fraud in the balanced dataset 90992/199008
# New synthetic data generated 285
# Number of fraud in the balanced dataset 91277/199008
# New synthetic data generated 284
# Number of fraud in the balanced dataset 91561/199008
# New synthetic data generated 285
# Number of fraud in the balanced dataset 91846/199008
# New synthetic data generated 290
# Number of fraud in the balanced dataset 92136/199008
# New synthetic data generated 287
# Number of fraud in the balanced dataset 92423/199008
# New synthetic data generated 291
# Number of fraud in the balanced dataset 92714/199008
# New synthetic data generated 287
# Number of fraud in the balanced dataset 93001/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 93296/199008
# New synthetic data generated 291
# Number of fraud in the balanced dataset 93587/199008
# New synthetic data generated 290
# Number of fraud in the balanced dataset 93877/199008
# New synthetic data generated 284
# Number of fraud in the balanced dataset 94161/199008
# New synthetic data generated 291
# Number of fraud in the balanced dataset 94452/199008
# New synthetic data generated 288
# Number of fraud in the balanced dataset 94740/199008
# New synthetic data generated 284
# Number of fraud in the balanced dataset 95024/199008
# New synthetic data generated 289
# Number of fraud in the balanced dataset 95313/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 95607/199008
# New synthetic data generated 289
# Number of fraud in the balanced dataset 95896/199008
# New synthetic data generated 291
# Number of fraud in the balanced dataset 96187/199008
# New synthetic data generated 286
# Number of fraud in the balanced dataset 96473/199008
# New synthetic data generated 287
# Number of fraud in the balanced dataset 96760/199008
# New synthetic data generated 285
# Number of fraud in the balanced dataset 97045/199008
# New synthetic data generated 290
# Number of fraud in the balanced dataset 97335/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 97630/199008
# New synthetic data generated 290
# Number of fraud in the balanced dataset 97920/199008
# New synthetic data generated 289
# Number of fraud in the balanced dataset 98209/199008
# New synthetic data generated 286
# Number of fraud in the balanced dataset 98495/199008
# New synthetic data generated 285
# Number of fraud in the balanced dataset 98780/199008
# New synthetic data generated 284
# Number of fraud in the balanced dataset 99064/199008
# New synthetic data generated 291
# Number of fraud in the balanced dataset 99355/199008
# New synthetic data generated 287
# Number of fraud in the balanced dataset 99642/199008
# New synthetic data generated 291
# Number of fraud in the balanced dataset 99933/199008
# New synthetic data generated 288
# Number of fraud in the balanced dataset 100221/199008
# New synthetic data generated 285
# Number of fraud in the balanced dataset 100506/199008
# New synthetic data generated 291
# Number of fraud in the balanced dataset 100797/199008
# New synthetic data generated 284
# Number of fraud in the balanced dataset 101081/199008
# New synthetic data generated 290
# Number of fraud in the balanced dataset 101371/199008
# New synthetic data generated 296
# Number of fraud in the balanced dataset 101667/199008
# New synthetic data generated 290
# Number of fraud in the balanced dataset 101957/199008
# New synthetic data generated 284
# Number of fraud in the balanced dataset 102241/199008
# New synthetic data generated 286
# Number of fraud in the balanced dataset 102527/199008
# New synthetic data generated 290
# Number of fraud in the balanced dataset 102817/199008
# New synthetic data generated 293
# Number of fraud in the balanced dataset 103110/199008
# New synthetic data generated 288
# Number of fraud in the balanced dataset 103398/199008
# New synthetic data generated 293
# Number of fraud in the balanced dataset 103691/199008
# New synthetic data generated 289
# Number of fraud in the balanced dataset 103980/199008
# New synthetic data generated 289
# Number of fraud in the balanced dataset 104269/199008
# New synthetic data generated 286
# Number of fraud in the balanced dataset 104555/199008
# New synthetic data generated 286
# Number of fraud in the balanced dataset 104841/199008
# New synthetic data generated 293
# Number of fraud in the balanced dataset 105134/199008
# New synthetic data generated 285
# Number of fraud in the balanced dataset 105419/199008
# New synthetic data generated 285
# Number of fraud in the balanced dataset 105704/199008
# New synthetic data generated 286
# Number of fraud in the balanced dataset 105990/199008
# New synthetic data generated 285
# Number of fraud in the balanced dataset 106275/199008
# New synthetic data generated 288
# Number of fraud in the balanced dataset 106563/199008
# New synthetic data generated 296
# Number of fraud in the balanced dataset 106859/199008
# New synthetic data generated 285
# Number of fraud in the balanced dataset 107144/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 107439/199008
# New synthetic data generated 289
# Number of fraud in the balanced dataset 107728/199008
# New synthetic data generated 292
# Number of fraud in the balanced dataset 108020/199008
# New synthetic data generated 286
# Number of fraud in the balanced dataset 108306/199008
# New synthetic data generated 292
# Number of fraud in the balanced dataset 108598/199008
# New synthetic data generated 286
# Number of fraud in the balanced dataset 108884/199008
# New synthetic data generated 292
# Number of fraud in the balanced dataset 109176/199008
# New synthetic data generated 287
# Number of fraud in the balanced dataset 109463/199008
# New synthetic data generated 288
# Number of fraud in the balanced dataset 109751/199008
# New synthetic data generated 288
# Number of fraud in the balanced dataset 110039/199008
# New synthetic data generated 283
# Number of fraud in the balanced dataset 110322/199008
# New synthetic data generated 287
# Number of fraud in the balanced dataset 110609/199008
# New synthetic data generated 285
# Number of fraud in the balanced dataset 110894/199008
# New synthetic data generated 281
# Number of fraud in the balanced dataset 111175/199008
# New synthetic data generated 290
# Number of fraud in the balanced dataset 111465/199008
# New synthetic data generated 290
# Number of fraud in the balanced dataset 111755/199008
# New synthetic data generated 287
# Number of fraud in the balanced dataset 112042/199008
# New synthetic data generated 289
# Number of fraud in the balanced dataset 112331/199008
# New synthetic data generated 291
# Number of fraud in the balanced dataset 112622/199008
# New synthetic data generated 290
# Number of fraud in the balanced dataset 112912/199008
# New synthetic data generated 289
# Number of fraud in the balanced dataset 113201/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 113495/199008
# New synthetic data generated 285
# Number of fraud in the balanced dataset 113780/199008
# New synthetic data generated 285
# Number of fraud in the balanced dataset 114065/199008
# New synthetic data generated 293
# Number of fraud in the balanced dataset 114358/199008
# New synthetic data generated 290
# Number of fraud in the balanced dataset 114648/199008
# New synthetic data generated 285
# Number of fraud in the balanced dataset 114933/199008
# New synthetic data generated 291
# Number of fraud in the balanced dataset 115224/199008
# New synthetic data generated 290
# Number of fraud in the balanced dataset 115514/199008
# New synthetic data generated 287
# Number of fraud in the balanced dataset 115801/199008
# New synthetic data generated 291
# Number of fraud in the balanced dataset 116092/199008
# New synthetic data generated 282
# Number of fraud in the balanced dataset 116374/199008
# New synthetic data generated 283
# Number of fraud in the balanced dataset 116657/199008
# New synthetic data generated 288
# Number of fraud in the balanced dataset 116945/199008
# New synthetic data generated 297
# Number of fraud in the balanced dataset 117242/199008
# New synthetic data generated 284
# Number of fraud in the balanced dataset 117526/199008
# New synthetic data generated 290
# Number of fraud in the balanced dataset 117816/199008
# New synthetic data generated 293
# Number of fraud in the balanced dataset 118109/199008
# New synthetic data generated 287
# Number of fraud in the balanced dataset 118396/199008
# New synthetic data generated 278
# Number of fraud in the balanced dataset 118674/199008
# New synthetic data generated 287
# Number of fraud in the balanced dataset 118961/199008
# New synthetic data generated 284
# Number of fraud in the balanced dataset 119245/199008
# New synthetic data generated 291
# Number of fraud in the balanced dataset 119536/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 119831/199008
# New synthetic data generated 290
# Number of fraud in the balanced dataset 120121/199008
# New synthetic data generated 287
# Number of fraud in the balanced dataset 120408/199008
# New synthetic data generated 287
# Number of fraud in the balanced dataset 120695/199008
# New synthetic data generated 286
# Number of fraud in the balanced dataset 120981/199008
# New synthetic data generated 291
# Number of fraud in the balanced dataset 121272/199008
# New synthetic data generated 292
# Number of fraud in the balanced dataset 121564/199008
# New synthetic data generated 289
# Number of fraud in the balanced dataset 121853/199008
# New synthetic data generated 290
# Number of fraud in the balanced dataset 122143/199008
# New synthetic data generated 286
# Number of fraud in the balanced dataset 122429/199008
# New synthetic data generated 287
# Number of fraud in the balanced dataset 122716/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 123011/199008
# New synthetic data generated 290
# Number of fraud in the balanced dataset 123301/199008
# New synthetic data generated 286
# Number of fraud in the balanced dataset 123587/199008
# New synthetic data generated 280
# Number of fraud in the balanced dataset 123867/199008
# New synthetic data generated 280
# Number of fraud in the balanced dataset 124147/199008
# New synthetic data generated 287
# Number of fraud in the balanced dataset 124434/199008
# New synthetic data generated 288
# Number of fraud in the balanced dataset 124722/199008
# New synthetic data generated 283
# Number of fraud in the balanced dataset 125005/199008
# New synthetic data generated 292
# Number of fraud in the balanced dataset 125297/199008
# New synthetic data generated 287
# Number of fraud in the balanced dataset 125584/199008
# New synthetic data generated 290
# Number of fraud in the balanced dataset 125874/199008
# New synthetic data generated 293
# Number of fraud in the balanced dataset 126167/199008
# New synthetic data generated 287
# Number of fraud in the balanced dataset 126454/199008
# New synthetic data generated 289
# Number of fraud in the balanced dataset 126743/199008
# New synthetic data generated 288
# Number of fraud in the balanced dataset 127031/199008
# New synthetic data generated 292
# Number of fraud in the balanced dataset 127323/199008
# New synthetic data generated 287
# Number of fraud in the balanced dataset 127610/199008
# New synthetic data generated 289
# Number of fraud in the balanced dataset 127899/199008
# New synthetic data generated 290
# Number of fraud in the balanced dataset 128189/199008
# New synthetic data generated 285
# Number of fraud in the balanced dataset 128474/199008
# New synthetic data generated 284
# Number of fraud in the balanced dataset 128758/199008
# New synthetic data generated 287
# Number of fraud in the balanced dataset 129045/199008
# New synthetic data generated 288
# Number of fraud in the balanced dataset 129333/199008
# New synthetic data generated 293
# Number of fraud in the balanced dataset 129626/199008
# New synthetic data generated 292
# Number of fraud in the balanced dataset 129918/199008
# New synthetic data generated 292
# Number of fraud in the balanced dataset 130210/199008
# New synthetic data generated 293
# Number of fraud in the balanced dataset 130503/199008
# New synthetic data generated 284
# Number of fraud in the balanced dataset 130787/199008
# New synthetic data generated 290
# Number of fraud in the balanced dataset 131077/199008
# New synthetic data generated 284
# Number of fraud in the balanced dataset 131361/199008
# New synthetic data generated 290
# Number of fraud in the balanced dataset 131651/199008
# New synthetic data generated 292
# Number of fraud in the balanced dataset 131943/199008
# New synthetic data generated 287
# Number of fraud in the balanced dataset 132230/199008
# New synthetic data generated 290
# Number of fraud in the balanced dataset 132520/199008
# New synthetic data generated 293
# Number of fraud in the balanced dataset 132813/199008
# New synthetic data generated 290
# Number of fraud in the balanced dataset 133103/199008
# New synthetic data generated 289
# Number of fraud in the balanced dataset 133392/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 133686/199008
# New synthetic data generated 287
# Number of fraud in the balanced dataset 133973/199008
# New synthetic data generated 293
# Number of fraud in the balanced dataset 134266/199008
# New synthetic data generated 289
# Number of fraud in the balanced dataset 134555/199008
# New synthetic data generated 279
# Number of fraud in the balanced dataset 134834/199008
# New synthetic data generated 293
# Number of fraud in the balanced dataset 135127/199008
# New synthetic data generated 288
# Number of fraud in the balanced dataset 135415/199008
# New synthetic data generated 290
# Number of fraud in the balanced dataset 135705/199008
# New synthetic data generated 291
# Number of fraud in the balanced dataset 135996/199008
# New synthetic data generated 290
# Number of fraud in the balanced dataset 136286/199008
# New synthetic data generated 283
# Number of fraud in the balanced dataset 136569/199008
# New synthetic data generated 287
# Number of fraud in the balanced dataset 136856/199008
# New synthetic data generated 291
# Number of fraud in the balanced dataset 137147/199008
# New synthetic data generated 292
# Number of fraud in the balanced dataset 137439/199008
# New synthetic data generated 288
# Number of fraud in the balanced dataset 137727/199008
# New synthetic data generated 289
# Number of fraud in the balanced dataset 138016/199008
# New synthetic data generated 286
# Number of fraud in the balanced dataset 138302/199008
# New synthetic data generated 288
# Number of fraud in the balanced dataset 138590/199008
# New synthetic data generated 283
# Number of fraud in the balanced dataset 138873/199008
# New synthetic data generated 286
# Number of fraud in the balanced dataset 139159/199008
# New synthetic data generated 289
# Number of fraud in the balanced dataset 139448/199008
# New synthetic data generated 286
# Number of fraud in the balanced dataset 139734/199008
# New synthetic data generated 282
# Number of fraud in the balanced dataset 140016/199008
# New synthetic data generated 290
# Number of fraud in the balanced dataset 140306/199008
# New synthetic data generated 286
# Number of fraud in the balanced dataset 140592/199008
# New synthetic data generated 282
# Number of fraud in the balanced dataset 140874/199008
# New synthetic data generated 289
# Number of fraud in the balanced dataset 141163/199008
# New synthetic data generated 289
# Number of fraud in the balanced dataset 141452/199008
# New synthetic data generated 291
# Number of fraud in the balanced dataset 141743/199008
# New synthetic data generated 290
# Number of fraud in the balanced dataset 142033/199008
# New synthetic data generated 289
# Number of fraud in the balanced dataset 142322/199008
# New synthetic data generated 289
# Number of fraud in the balanced dataset 142611/199008
# New synthetic data generated 286
# Number of fraud in the balanced dataset 142897/199008
# New synthetic data generated 284
# Number of fraud in the balanced dataset 143181/199008
# New synthetic data generated 285
# Number of fraud in the balanced dataset 143466/199008
# New synthetic data generated 290
# Number of fraud in the balanced dataset 143756/199008
# New synthetic data generated 286
# Number of fraud in the balanced dataset 144042/199008
# New synthetic data generated 288
# Number of fraud in the balanced dataset 144330/199008
# New synthetic data generated 290
# Number of fraud in the balanced dataset 144620/199008
# New synthetic data generated 287
# Number of fraud in the balanced dataset 144907/199008
# New synthetic data generated 282
# Number of fraud in the balanced dataset 145189/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 145483/199008
# New synthetic data generated 287
# Number of fraud in the balanced dataset 145770/199008
# New synthetic data generated 284
# Number of fraud in the balanced dataset 146054/199008
# New synthetic data generated 287
# Number of fraud in the balanced dataset 146341/199008
# New synthetic data generated 290
# Number of fraud in the balanced dataset 146631/199008
# New synthetic data generated 292
# Number of fraud in the balanced dataset 146923/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 147217/199008
# New synthetic data generated 287
# Number of fraud in the balanced dataset 147504/199008
# New synthetic data generated 285
# Number of fraud in the balanced dataset 147789/199008
# New synthetic data generated 287
# Number of fraud in the balanced dataset 148076/199008
# New synthetic data generated 280
# Number of fraud in the balanced dataset 148356/199008
# New synthetic data generated 284
# Number of fraud in the balanced dataset 148640/199008
# New synthetic data generated 290
# Number of fraud in the balanced dataset 148930/199008
# New synthetic data generated 286
# Number of fraud in the balanced dataset 149216/199008
# New synthetic data generated 288
# Number of fraud in the balanced dataset 149504/199008
# New synthetic data generated 286
# Number of fraud in the balanced dataset 149790/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 150085/199008
# New synthetic data generated 289
# Number of fraud in the balanced dataset 150374/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 150668/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 150962/199008
# New synthetic data generated 293
# Number of fraud in the balanced dataset 151255/199008
# New synthetic data generated 293
# Number of fraud in the balanced dataset 151548/199008
# New synthetic data generated 285
# Number of fraud in the balanced dataset 151833/199008
# New synthetic data generated 292
# Number of fraud in the balanced dataset 152125/199008
# New synthetic data generated 291
# Number of fraud in the balanced dataset 152416/199008
# New synthetic data generated 286
# Number of fraud in the balanced dataset 152702/199008
# New synthetic data generated 288
# Number of fraud in the balanced dataset 152990/199008
# New synthetic data generated 285
# Number of fraud in the balanced dataset 153275/199008
# New synthetic data generated 288
# Number of fraud in the balanced dataset 153563/199008
# New synthetic data generated 285
# Number of fraud in the balanced dataset 153848/199008
# New synthetic data generated 286
# Number of fraud in the balanced dataset 154134/199008
# New synthetic data generated 282
# Number of fraud in the balanced dataset 154416/199008
# New synthetic data generated 282
# Number of fraud in the balanced dataset 154698/199008
# New synthetic data generated 289
# Number of fraud in the balanced dataset 154987/199008
# New synthetic data generated 293
# Number of fraud in the balanced dataset 155280/199008
# New synthetic data generated 291
# Number of fraud in the balanced dataset 155571/199008
# New synthetic data generated 291
# Number of fraud in the balanced dataset 155862/199008
# New synthetic data generated 289
# Number of fraud in the balanced dataset 156151/199008
# New synthetic data generated 296
# Number of fraud in the balanced dataset 156447/199008
# New synthetic data generated 280
# Number of fraud in the balanced dataset 156727/199008
# New synthetic data generated 287
# Number of fraud in the balanced dataset 157014/199008
# New synthetic data generated 290
# Number of fraud in the balanced dataset 157304/199008
# New synthetic data generated 278
# Number of fraud in the balanced dataset 157582/199008
# New synthetic data generated 284
# Number of fraud in the balanced dataset 157866/199008
# New synthetic data generated 287
# Number of fraud in the balanced dataset 158153/199008
# New synthetic data generated 290
# Number of fraud in the balanced dataset 158443/199008
# New synthetic data generated 292
# Number of fraud in the balanced dataset 158735/199008
# New synthetic data generated 291
# Number of fraud in the balanced dataset 159026/199008
# New synthetic data generated 291
# Number of fraud in the balanced dataset 159317/199008
# New synthetic data generated 291
# Number of fraud in the balanced dataset 159608/199008
# New synthetic data generated 291
# Number of fraud in the balanced dataset 159899/199008
# New synthetic data generated 292
# Number of fraud in the balanced dataset 160191/199008
# New synthetic data generated 283
# Number of fraud in the balanced dataset 160474/199008
# New synthetic data generated 291
# Number of fraud in the balanced dataset 160765/199008
# New synthetic data generated 286
# Number of fraud in the balanced dataset 161051/199008
# New synthetic data generated 290
# Number of fraud in the balanced dataset 161341/199008
# New synthetic data generated 281
# Number of fraud in the balanced dataset 161622/199008
# New synthetic data generated 282
# Number of fraud in the balanced dataset 161904/199008
# New synthetic data generated 290
# Number of fraud in the balanced dataset 162194/199008
# New synthetic data generated 287
# Number of fraud in the balanced dataset 162481/199008
# New synthetic data generated 289
# Number of fraud in the balanced dataset 162770/199008
# New synthetic data generated 286
# Number of fraud in the balanced dataset 163056/199008
# New synthetic data generated 290
# Number of fraud in the balanced dataset 163346/199008
# New synthetic data generated 291
# Number of fraud in the balanced dataset 163637/199008
# New synthetic data generated 287
# Number of fraud in the balanced dataset 163924/199008
# New synthetic data generated 292
# Number of fraud in the balanced dataset 164216/199008
# New synthetic data generated 286
# Number of fraud in the balanced dataset 164502/199008
# New synthetic data generated 285
# Number of fraud in the balanced dataset 164787/199008
# New synthetic data generated 284
# Number of fraud in the balanced dataset 165071/199008
# New synthetic data generated 285
# Number of fraud in the balanced dataset 165356/199008
# New synthetic data generated 289
# Number of fraud in the balanced dataset 165645/199008
# New synthetic data generated 290
# Number of fraud in the balanced dataset 165935/199008
# New synthetic data generated 285
# Number of fraud in the balanced dataset 166220/199008
# New synthetic data generated 290
# Number of fraud in the balanced dataset 166510/199008
# New synthetic data generated 286
# Number of fraud in the balanced dataset 166796/199008
# New synthetic data generated 289
# Number of fraud in the balanced dataset 167085/199008
# New synthetic data generated 288
# Number of fraud in the balanced dataset 167373/199008
# New synthetic data generated 283
# Number of fraud in the balanced dataset 167656/199008
# New synthetic data generated 292
# Number of fraud in the balanced dataset 167948/199008
# New synthetic data generated 291
# Number of fraud in the balanced dataset 168239/199008
# New synthetic data generated 293
# Number of fraud in the balanced dataset 168532/199008
# New synthetic data generated 285
# Number of fraud in the balanced dataset 168817/199008
# New synthetic data generated 291
# Number of fraud in the balanced dataset 169108/199008
# New synthetic data generated 293
# Number of fraud in the balanced dataset 169401/199008
# New synthetic data generated 284
# Number of fraud in the balanced dataset 169685/199008
# New synthetic data generated 287
# Number of fraud in the balanced dataset 169972/199008
# New synthetic data generated 284
# Number of fraud in the balanced dataset 170256/199008
# New synthetic data generated 287
# Number of fraud in the balanced dataset 170543/199008
# New synthetic data generated 291
# Number of fraud in the balanced dataset 170834/199008
# New synthetic data generated 289
# Number of fraud in the balanced dataset 171123/199008
# New synthetic data generated 288
# Number of fraud in the balanced dataset 171411/199008
# New synthetic data generated 290
# Number of fraud in the balanced dataset 171701/199008
# New synthetic data generated 291
# Number of fraud in the balanced dataset 171992/199008
# New synthetic data generated 292
# Number of fraud in the balanced dataset 172284/199008
# New synthetic data generated 292
# Number of fraud in the balanced dataset 172576/199008
# New synthetic data generated 290
# Number of fraud in the balanced dataset 172866/199008
# New synthetic data generated 290
# Number of fraud in the balanced dataset 173156/199008
# New synthetic data generated 289
# Number of fraud in the balanced dataset 173445/199008
# New synthetic data generated 289
# Number of fraud in the balanced dataset 173734/199008
# New synthetic data generated 291
# Number of fraud in the balanced dataset 174025/199008
# New synthetic data generated 290
# Number of fraud in the balanced dataset 174315/199008
# New synthetic data generated 286
# Number of fraud in the balanced dataset 174601/199008
# New synthetic data generated 279
# Number of fraud in the balanced dataset 174880/199008
# New synthetic data generated 287
# Number of fraud in the balanced dataset 175167/199008
# New synthetic data generated 296
# Number of fraud in the balanced dataset 175463/199008
# New synthetic data generated 290
# Number of fraud in the balanced dataset 175753/199008
# New synthetic data generated 285
# Number of fraud in the balanced dataset 176038/199008
# New synthetic data generated 291
# Number of fraud in the balanced dataset 176329/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 176623/199008
# New synthetic data generated 291
# Number of fraud in the balanced dataset 176914/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 177209/199008
# New synthetic data generated 287
# Number of fraud in the balanced dataset 177496/199008
# New synthetic data generated 286
# Number of fraud in the balanced dataset 177782/199008
# New synthetic data generated 284
# Number of fraud in the balanced dataset 178066/199008
# New synthetic data generated 287
# Number of fraud in the balanced dataset 178353/199008
# New synthetic data generated 286
# Number of fraud in the balanced dataset 178639/199008
# New synthetic data generated 288
# Number of fraud in the balanced dataset 178927/199008
# New synthetic data generated 288
# Number of fraud in the balanced dataset 179215/199008
# New synthetic data generated 283
# Number of fraud in the balanced dataset 179498/199008
# New synthetic data generated 290
# Number of fraud in the balanced dataset 179788/199008
# New synthetic data generated 289
# Number of fraud in the balanced dataset 180077/199008
# New synthetic data generated 292
# Number of fraud in the balanced dataset 180369/199008
# New synthetic data generated 289
# Number of fraud in the balanced dataset 180658/199008
# New synthetic data generated 293
# Number of fraud in the balanced dataset 180951/199008
# New synthetic data generated 293
# Number of fraud in the balanced dataset 181244/199008
# New synthetic data generated 286
# Number of fraud in the balanced dataset 181530/199008
# New synthetic data generated 288
# Number of fraud in the balanced dataset 181818/199008
# New synthetic data generated 286
# Number of fraud in the balanced dataset 182104/199008
# New synthetic data generated 290
# Number of fraud in the balanced dataset 182394/199008
# New synthetic data generated 290
# Number of fraud in the balanced dataset 182684/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 182978/199008
# New synthetic data generated 293
# Number of fraud in the balanced dataset 183271/199008
# New synthetic data generated 287
# Number of fraud in the balanced dataset 183558/199008
# New synthetic data generated 287
# Number of fraud in the balanced dataset 183845/199008
# New synthetic data generated 288
# Number of fraud in the balanced dataset 184133/199008
# New synthetic data generated 288
# Number of fraud in the balanced dataset 184421/199008
# New synthetic data generated 282
# Number of fraud in the balanced dataset 184703/199008
# New synthetic data generated 292
# Number of fraud in the balanced dataset 184995/199008
# New synthetic data generated 289
# Number of fraud in the balanced dataset 185284/199008
# New synthetic data generated 282
# Number of fraud in the balanced dataset 185566/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 185861/199008
# New synthetic data generated 288
# Number of fraud in the balanced dataset 186149/199008
# New synthetic data generated 284
# Number of fraud in the balanced dataset 186433/199008
# New synthetic data generated 287
# Number of fraud in the balanced dataset 186720/199008
# New synthetic data generated 285
# Number of fraud in the balanced dataset 187005/199008
# New synthetic data generated 287
# Number of fraud in the balanced dataset 187292/199008
# New synthetic data generated 290
# Number of fraud in the balanced dataset 187582/199008
# New synthetic data generated 287
# Number of fraud in the balanced dataset 187869/199008
# New synthetic data generated 290
# Number of fraud in the balanced dataset 188159/199008
# New synthetic data generated 291
# Number of fraud in the balanced dataset 188450/199008
# New synthetic data generated 287
# Number of fraud in the balanced dataset 188737/199008
# New synthetic data generated 287
# Number of fraud in the balanced dataset 189024/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 189318/199008
# New synthetic data generated 285
# Number of fraud in the balanced dataset 189603/199008
# New synthetic data generated 293
# Number of fraud in the balanced dataset 189896/199008
# New synthetic data generated 293
# Number of fraud in the balanced dataset 190189/199008
# New synthetic data generated 292
# Number of fraud in the balanced dataset 190481/199008
# New synthetic data generated 292
# Number of fraud in the balanced dataset 190773/199008
# New synthetic data generated 292
# Number of fraud in the balanced dataset 191065/199008
# New synthetic data generated 285
# Number of fraud in the balanced dataset 191350/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 191644/199008
# New synthetic data generated 293
# Number of fraud in the balanced dataset 191937/199008
# New synthetic data generated 289
# Number of fraud in the balanced dataset 192226/199008
# New synthetic data generated 291
# Number of fraud in the balanced dataset 192517/199008
# New synthetic data generated 290
# Number of fraud in the balanced dataset 192807/199008
# New synthetic data generated 291
# Number of fraud in the balanced dataset 193098/199008
# New synthetic data generated 289
# Number of fraud in the balanced dataset 193387/199008
# New synthetic data generated 285
# Number of fraud in the balanced dataset 193672/199008
# New synthetic data generated 290
# Number of fraud in the balanced dataset 193962/199008
# New synthetic data generated 286
# Number of fraud in the balanced dataset 194248/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 194542/199008
# New synthetic data generated 292
# Number of fraud in the balanced dataset 194834/199008
# New synthetic data generated 292
# Number of fraud in the balanced dataset 195126/199008
# New synthetic data generated 288
# Number of fraud in the balanced dataset 195414/199008
# New synthetic data generated 287
# Number of fraud in the balanced dataset 195701/199008
# New synthetic data generated 286
# Number of fraud in the balanced dataset 195987/199008
# New synthetic data generated 289
# Number of fraud in the balanced dataset 196276/199008
# New synthetic data generated 289
# Number of fraud in the balanced dataset 196565/199008
# New synthetic data generated 283
# Number of fraud in the balanced dataset 196848/199008
# New synthetic data generated 283
# Number of fraud in the balanced dataset 197131/199008
# New synthetic data generated 291
# Number of fraud in the balanced dataset 197422/199008
# New synthetic data generated 286
# Number of fraud in the balanced dataset 197708/199008
# New synthetic data generated 291
# Number of fraud in the balanced dataset 197999/199008
# New synthetic data generated 290
# Number of fraud in the balanced dataset 198289/199008
# New synthetic data generated 285
# Number of fraud in the balanced dataset 198574/199008
# New synthetic data generated 290
# Number of fraud in the balanced dataset 198864/199008
# New synthetic data generated 285
# Number of fraud in the balanced dataset 199149/199008
# (398157, 31)
# Number of fraud in the balanced dataset 199149
# Number of non-fraud in the balanced dataset 199008

# %%
# Create an LSTM layer
# Input dim is 3, output dim is 3
lstm = nn.LSTM(input_size=30, hidden_size=3, num_layers=1, batch_first=False)
