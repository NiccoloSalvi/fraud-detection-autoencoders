# %%
import numpy as np
import pandas as pd
import torch
import torch.nn as nn
from sklearn.preprocessing import RobustScaler
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
import jax.numpy as jnp
from torch.utils.data import DataLoader, TensorDataset

data = pd.read_csv('creditcard.csv')

dataset = data.to_numpy().astype(np.float32)  # Ensure data is float32 for PyTorch

scaler = RobustScaler(with_centering=True, with_scaling=True, quantile_range=(25.0, 75.0), unit_variance=False)
dataset[:, [0, 29]] = scaler.fit_transform(dataset[:, [0, 29]])

# %%
data_train, data_test = train_test_split(dataset, test_size=0.3, random_state=42)

# %%
# -----------------------------
# 3. Define the Autoencoder Model
# -----------------------------
class Autoencoder(nn.Module):
    def __init__(self):
        super(Autoencoder, self).__init__()
        # Encoder: 31 -> 23 -> 19 -> 17 -> 8 with dropout after first two hidden layers
        self.encoder = nn.Sequential(
            nn.Linear(31, 23),
            nn.Tanh(),
            nn.Dropout(0.1),
            nn.Linear(23, 19),
            nn.Tanh(),
            nn.Dropout(0.2),
            nn.Linear(19, 17),
            nn.Tanh(),
            nn.Linear(17, 8)
        )
        # Decoder: 8 -> 17 -> 19 -> 23 -> 31 with dropout after first two layers
        self.decoder = nn.Sequential(
            nn.Linear(8, 17),
            nn.Tanh(),
            nn.Dropout(0.2),
            nn.Linear(17, 19),
            nn.Tanh(),
            nn.Dropout(0.1),
            nn.Linear(19, 23),
            nn.Tanh(),
            nn.Linear(23, 31)
        )

    def forward(self, x):
        latent = self.encoder(x)
        reconstructed = self.decoder(latent)
        return reconstructed

# %%
fraud_data = data_train[data_train[:, -1] == 1]
non_fraud_data = data_train[data_train[:, -1] == 0]

legit_data_limited = non_fraud_data[np.random.choice(non_fraud_data.shape[0], fraud_data.shape[0], replace=False)]

train_dataset_SVM = np.vstack((legit_data_limited, fraud_data))
np.random.shuffle(train_dataset_SVM)
train_labels_SVM = train_dataset_SVM[:, -1]
train_dataset_SVM = train_dataset_SVM[:, :-1]

data_train_SVM, data_test_SVM, labels_train_SVM, labels_test_SVM = train_test_split(train_dataset_SVM, train_labels_SVM, test_size=0.2, random_state=42)
model = SVC(kernel='linear', C=1.0)
model.fit(data_train_SVM, labels_train_SVM)

labels_pred_test = model.predict(data_test_SVM)
labels_pred_train = model.predict(data_train_SVM)
accuracy_train = jnp.mean(labels_pred_train == labels_train_SVM)
accuracy_test = jnp.mean(labels_pred_test == labels_test_SVM)

print(f"Train Accuracy: {accuracy_train:.4f}")
print(f"Test Accuracy: {accuracy_test:.4f}")
# Out:
# Train Accuracy: 0.9473
# Test Accuracy: 0.9301

# %%
# load the model 
myModel = Autoencoder()

# Load the saved state dictionary
myModel.load_state_dict(torch.load("model/autoencoder/autoencoder.pth", map_location=torch.device('cpu'), weights_only=True))
myModel.eval()

alpha = 0.9

data_train_oversampled = data_train.copy()

while (len(data_train_oversampled[data_train_oversampled[:, -1] == 1]) < len(data_train_oversampled[data_train_oversampled[:, -1] == 0])):
    fraud_data = data_train_oversampled[data_train_oversampled[:, -1] == 1]

    # 2) Generate synthetic data by interpolating between fraud data points
    fraud_data_tensor = torch.tensor(fraud_data, dtype=torch.float32)

    latent_representations = myModel.encoder(fraud_data_tensor)

    noisy_vectors = []
    for _ in range(300):
        # Pick a random fraud vector
        i = np.random.randint(0, 300)
        z_i = latent_representations[i]

        # Optionally pick a second random vector to interpolate
        j = np.random.randint(0, 300)
        z_j = latent_representations[j]
        
        # Interpolation factor
        lambda_ = np.random.rand()
        z_ij = lambda_*z_i + (1 - lambda_)*z_j
        
        # Add Gaussian noise around that interpolation
        noise = torch.normal(mean=0.0, std=alpha, size=(8,))
        z_syn = z_ij + noise  # Both are tensors, so this should work directly

        noisy_vectors.append(z_syn.detach().numpy())

    noisy_vectors = np.array(noisy_vectors)

    # 3) Decode them to get synthetic data in original input space
    X_synthetic = myModel.decoder(torch.tensor(noisy_vectors, dtype=torch.float32)).detach().numpy()
    # remove label
    X_synthetic_to_predict = X_synthetic[:, :-1]
    # 4) Validate with SVM
    y_pred = model.predict(X_synthetic_to_predict)

    X_synthetic[:, -1] = y_pred

    # 5) Add the synthetic data to the training set
    X_synthetic_fraud = X_synthetic[X_synthetic[:, -1] == 1]

    data_train_oversampled = np.vstack((data_train_oversampled, X_synthetic_fraud))

    print("New synthetic data generated", len(X_synthetic_fraud))
    print(f"Number of fraud in the balanced dataset {len(data_train_oversampled[data_train_oversampled[:, -1] == 1])}/{len(data_train_oversampled[data_train_oversampled[:, -1] == 0])}")

# for i in range(len(data_train_oversampled[data_train_oversampled[:, -1] == 1]) - len(data_train_oversampled[data_train_oversampled[:, -1] == 0])):
#     noisy_vectors = []
#     for _ in range(n):
#         # Pick a random fraud vector
#         i = np.random.randint(0, n)
#         z_i = latent_representations[i]

#         # Optionally pick a second random vector to interpolate
#         j = np.random.randint(0, n)
#         z_j = latent_representations[j]
        
#         # Interpolation factor
#         lambda_ = np.random.rand()
#         z_ij = lambda_*z_i + (1 - lambda_)*z_j
        
#         # Add Gaussian noise around that interpolation
#         noise = torch.normal(mean=0.0, std=alpha, size=(latent_dim,))
#         z_syn = z_ij + noise  # Both are tensors, so this should work directly

#         noisy_vectors.append(z_syn.detach().numpy())

#     noisy_vectors = np.array(noisy_vectors)

#     # 3) Decode them to get synthetic data in original input space
#     X_synthetic = myModel.decoder(torch.tensor(noisy_vectors, dtype=torch.float32)).detach().numpy()
#     # remove label
#     X_synthetic_to_predict = X_synthetic[:, :-1]
#     # 4) Validate with SVM
#     y_pred = model.predict(X_synthetic_to_predict)

#     X_synthetic[:, -1] = y_pred

#     # 5) Add the synthetic data to the training set
#     X_synthetic_fraud = X_synthetic[X_synthetic[:, -1] == 1]

#     data_train_oversampled = np.vstack((data_train_oversampled, X_synthetic_fraud))

print(data_train_oversampled.shape)
print("Number of fraud in the balanced dataset", len(data_train_oversampled[data_train_oversampled[:, -1] == 1]))
print("Number of non-fraud in the balanced dataset", len(data_train_oversampled[data_train_oversampled[:, -1] == 0]))
# Out:
# New synthetic data generated 292
# Number of fraud in the balanced dataset 648/199008
# New synthetic data generated 297
# Number of fraud in the balanced dataset 945/199008
# New synthetic data generated 297
# Number of fraud in the balanced dataset 1242/199008
# New synthetic data generated 298
# Number of fraud in the balanced dataset 1540/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 1834/199008
# New synthetic data generated 296
# Number of fraud in the balanced dataset 2130/199008
# New synthetic data generated 296
# Number of fraud in the balanced dataset 2426/199008
# New synthetic data generated 297
# Number of fraud in the balanced dataset 2723/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 3018/199008
# New synthetic data generated 292
# Number of fraud in the balanced dataset 3310/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 3605/199008
# New synthetic data generated 292
# Number of fraud in the balanced dataset 3897/199008
# New synthetic data generated 296
# Number of fraud in the balanced dataset 4193/199008
# New synthetic data generated 292
# Number of fraud in the balanced dataset 4485/199008
# New synthetic data generated 296
# Number of fraud in the balanced dataset 4781/199008
# New synthetic data generated 293
# Number of fraud in the balanced dataset 5074/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 5368/199008
# New synthetic data generated 293
# Number of fraud in the balanced dataset 5661/199008
# New synthetic data generated 299
# Number of fraud in the balanced dataset 5960/199008
# New synthetic data generated 296
# Number of fraud in the balanced dataset 6256/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 6551/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 6845/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 7139/199008
# New synthetic data generated 296
# Number of fraud in the balanced dataset 7435/199008
# New synthetic data generated 293
# Number of fraud in the balanced dataset 7728/199008
# New synthetic data generated 296
# Number of fraud in the balanced dataset 8024/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 8318/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 8613/199008
# New synthetic data generated 298
# Number of fraud in the balanced dataset 8911/199008
# New synthetic data generated 296
# Number of fraud in the balanced dataset 9207/199008
# New synthetic data generated 292
# Number of fraud in the balanced dataset 9499/199008
# New synthetic data generated 297
# Number of fraud in the balanced dataset 9796/199008
# New synthetic data generated 293
# Number of fraud in the balanced dataset 10089/199008
# New synthetic data generated 293
# Number of fraud in the balanced dataset 10382/199008
# New synthetic data generated 297
# Number of fraud in the balanced dataset 10679/199008
# New synthetic data generated 296
# Number of fraud in the balanced dataset 10975/199008
# New synthetic data generated 296
# Number of fraud in the balanced dataset 11271/199008
# New synthetic data generated 299
# Number of fraud in the balanced dataset 11570/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 11864/199008
# New synthetic data generated 297
# Number of fraud in the balanced dataset 12161/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 12455/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 12749/199008
# New synthetic data generated 297
# Number of fraud in the balanced dataset 13046/199008
# New synthetic data generated 296
# Number of fraud in the balanced dataset 13342/199008
# New synthetic data generated 299
# Number of fraud in the balanced dataset 13641/199008
# New synthetic data generated 296
# Number of fraud in the balanced dataset 13937/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 14231/199008
# New synthetic data generated 297
# Number of fraud in the balanced dataset 14528/199008
# New synthetic data generated 297
# Number of fraud in the balanced dataset 14825/199008
# New synthetic data generated 299
# Number of fraud in the balanced dataset 15124/199008
# New synthetic data generated 296
# Number of fraud in the balanced dataset 15420/199008
# New synthetic data generated 297
# Number of fraud in the balanced dataset 15717/199008
# New synthetic data generated 298
# Number of fraud in the balanced dataset 16015/199008
# New synthetic data generated 299
# Number of fraud in the balanced dataset 16314/199008
# New synthetic data generated 299
# Number of fraud in the balanced dataset 16613/199008
# New synthetic data generated 297
# Number of fraud in the balanced dataset 16910/199008
# New synthetic data generated 291
# Number of fraud in the balanced dataset 17201/199008
# New synthetic data generated 297
# Number of fraud in the balanced dataset 17498/199008
# New synthetic data generated 297
# Number of fraud in the balanced dataset 17795/199008
# New synthetic data generated 297
# Number of fraud in the balanced dataset 18092/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 18387/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 18682/199008
# New synthetic data generated 299
# Number of fraud in the balanced dataset 18981/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 19276/199008
# New synthetic data generated 291
# Number of fraud in the balanced dataset 19567/199008
# New synthetic data generated 296
# Number of fraud in the balanced dataset 19863/199008
# New synthetic data generated 296
# Number of fraud in the balanced dataset 20159/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 20454/199008
# New synthetic data generated 297
# Number of fraud in the balanced dataset 20751/199008
# New synthetic data generated 296
# Number of fraud in the balanced dataset 21047/199008
# New synthetic data generated 296
# Number of fraud in the balanced dataset 21343/199008
# New synthetic data generated 296
# Number of fraud in the balanced dataset 21639/199008
# New synthetic data generated 296
# Number of fraud in the balanced dataset 21935/199008
# New synthetic data generated 296
# Number of fraud in the balanced dataset 22231/199008
# New synthetic data generated 296
# Number of fraud in the balanced dataset 22527/199008
# New synthetic data generated 296
# Number of fraud in the balanced dataset 22823/199008
# New synthetic data generated 298
# Number of fraud in the balanced dataset 23121/199008
# New synthetic data generated 298
# Number of fraud in the balanced dataset 23419/199008
# New synthetic data generated 297
# Number of fraud in the balanced dataset 23716/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 24010/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 24304/199008
# New synthetic data generated 296
# Number of fraud in the balanced dataset 24600/199008
# New synthetic data generated 296
# Number of fraud in the balanced dataset 24896/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 25190/199008
# New synthetic data generated 298
# Number of fraud in the balanced dataset 25488/199008
# New synthetic data generated 298
# Number of fraud in the balanced dataset 25786/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 26081/199008
# New synthetic data generated 296
# Number of fraud in the balanced dataset 26377/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 26672/199008
# New synthetic data generated 296
# Number of fraud in the balanced dataset 26968/199008
# New synthetic data generated 298
# Number of fraud in the balanced dataset 27266/199008
# New synthetic data generated 297
# Number of fraud in the balanced dataset 27563/199008
# New synthetic data generated 292
# Number of fraud in the balanced dataset 27855/199008
# New synthetic data generated 297
# Number of fraud in the balanced dataset 28152/199008
# New synthetic data generated 298
# Number of fraud in the balanced dataset 28450/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 28745/199008
# New synthetic data generated 298
# Number of fraud in the balanced dataset 29043/199008
# New synthetic data generated 296
# Number of fraud in the balanced dataset 29339/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 29634/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 29928/199008
# New synthetic data generated 299
# Number of fraud in the balanced dataset 30227/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 30522/199008
# New synthetic data generated 297
# Number of fraud in the balanced dataset 30819/199008
# New synthetic data generated 297
# Number of fraud in the balanced dataset 31116/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 31411/199008
# New synthetic data generated 298
# Number of fraud in the balanced dataset 31709/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 32003/199008
# New synthetic data generated 296
# Number of fraud in the balanced dataset 32299/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 32594/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 32888/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 33182/199008
# New synthetic data generated 298
# Number of fraud in the balanced dataset 33480/199008
# New synthetic data generated 293
# Number of fraud in the balanced dataset 33773/199008
# New synthetic data generated 297
# Number of fraud in the balanced dataset 34070/199008
# New synthetic data generated 297
# Number of fraud in the balanced dataset 34367/199008
# New synthetic data generated 297
# Number of fraud in the balanced dataset 34664/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 34958/199008
# New synthetic data generated 296
# Number of fraud in the balanced dataset 35254/199008
# New synthetic data generated 297
# Number of fraud in the balanced dataset 35551/199008
# New synthetic data generated 296
# Number of fraud in the balanced dataset 35847/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 36142/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 36436/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 36730/199008
# New synthetic data generated 297
# Number of fraud in the balanced dataset 37027/199008
# New synthetic data generated 297
# Number of fraud in the balanced dataset 37324/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 37619/199008
# New synthetic data generated 298
# Number of fraud in the balanced dataset 37917/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 38211/199008
# New synthetic data generated 299
# Number of fraud in the balanced dataset 38510/199008
# New synthetic data generated 297
# Number of fraud in the balanced dataset 38807/199008
# New synthetic data generated 297
# Number of fraud in the balanced dataset 39104/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 39398/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 39693/199008
# New synthetic data generated 297
# Number of fraud in the balanced dataset 39990/199008
# New synthetic data generated 291
# Number of fraud in the balanced dataset 40281/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 40575/199008
# New synthetic data generated 299
# Number of fraud in the balanced dataset 40874/199008
# New synthetic data generated 297
# Number of fraud in the balanced dataset 41171/199008
# New synthetic data generated 297
# Number of fraud in the balanced dataset 41468/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 41762/199008
# New synthetic data generated 296
# Number of fraud in the balanced dataset 42058/199008
# New synthetic data generated 296
# Number of fraud in the balanced dataset 42354/199008
# New synthetic data generated 298
# Number of fraud in the balanced dataset 42652/199008
# New synthetic data generated 296
# Number of fraud in the balanced dataset 42948/199008
# New synthetic data generated 299
# Number of fraud in the balanced dataset 43247/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 43541/199008
# New synthetic data generated 297
# Number of fraud in the balanced dataset 43838/199008
# New synthetic data generated 291
# Number of fraud in the balanced dataset 44129/199008
# New synthetic data generated 298
# Number of fraud in the balanced dataset 44427/199008
# New synthetic data generated 296
# Number of fraud in the balanced dataset 44723/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 45017/199008
# New synthetic data generated 296
# Number of fraud in the balanced dataset 45313/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 45607/199008
# New synthetic data generated 298
# Number of fraud in the balanced dataset 45905/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 46199/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 46494/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 46789/199008
# New synthetic data generated 291
# Number of fraud in the balanced dataset 47080/199008
# New synthetic data generated 296
# Number of fraud in the balanced dataset 47376/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 47670/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 47965/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 48260/199008
# New synthetic data generated 296
# Number of fraud in the balanced dataset 48556/199008
# New synthetic data generated 296
# Number of fraud in the balanced dataset 48852/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 49147/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 49441/199008
# New synthetic data generated 297
# Number of fraud in the balanced dataset 49738/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 50033/199008
# New synthetic data generated 292
# Number of fraud in the balanced dataset 50325/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 50619/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 50914/199008
# New synthetic data generated 296
# Number of fraud in the balanced dataset 51210/199008
# New synthetic data generated 297
# Number of fraud in the balanced dataset 51507/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 51802/199008
# New synthetic data generated 297
# Number of fraud in the balanced dataset 52099/199008
# New synthetic data generated 296
# Number of fraud in the balanced dataset 52395/199008
# New synthetic data generated 296
# Number of fraud in the balanced dataset 52691/199008
# New synthetic data generated 296
# Number of fraud in the balanced dataset 52987/199008
# New synthetic data generated 296
# Number of fraud in the balanced dataset 53283/199008
# New synthetic data generated 296
# Number of fraud in the balanced dataset 53579/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 53874/199008
# New synthetic data generated 296
# Number of fraud in the balanced dataset 54170/199008
# New synthetic data generated 297
# Number of fraud in the balanced dataset 54467/199008
# New synthetic data generated 297
# Number of fraud in the balanced dataset 54764/199008
# New synthetic data generated 297
# Number of fraud in the balanced dataset 55061/199008
# New synthetic data generated 298
# Number of fraud in the balanced dataset 55359/199008
# New synthetic data generated 293
# Number of fraud in the balanced dataset 55652/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 55946/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 56241/199008
# New synthetic data generated 296
# Number of fraud in the balanced dataset 56537/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 56831/199008
# New synthetic data generated 298
# Number of fraud in the balanced dataset 57129/199008
# New synthetic data generated 297
# Number of fraud in the balanced dataset 57426/199008
# New synthetic data generated 296
# Number of fraud in the balanced dataset 57722/199008
# New synthetic data generated 292
# Number of fraud in the balanced dataset 58014/199008
# New synthetic data generated 297
# Number of fraud in the balanced dataset 58311/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 58605/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 58899/199008
# New synthetic data generated 297
# Number of fraud in the balanced dataset 59196/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 59491/199008
# New synthetic data generated 293
# Number of fraud in the balanced dataset 59784/199008
# New synthetic data generated 296
# Number of fraud in the balanced dataset 60080/199008
# New synthetic data generated 291
# Number of fraud in the balanced dataset 60371/199008
# New synthetic data generated 291
# Number of fraud in the balanced dataset 60662/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 60956/199008
# New synthetic data generated 298
# Number of fraud in the balanced dataset 61254/199008
# New synthetic data generated 296
# Number of fraud in the balanced dataset 61550/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 61845/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 62139/199008
# New synthetic data generated 297
# Number of fraud in the balanced dataset 62436/199008
# New synthetic data generated 298
# Number of fraud in the balanced dataset 62734/199008
# New synthetic data generated 296
# Number of fraud in the balanced dataset 63030/199008
# New synthetic data generated 298
# Number of fraud in the balanced dataset 63328/199008
# New synthetic data generated 291
# Number of fraud in the balanced dataset 63619/199008
# New synthetic data generated 293
# Number of fraud in the balanced dataset 63912/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 64207/199008
# New synthetic data generated 300
# Number of fraud in the balanced dataset 64507/199008
# New synthetic data generated 296
# Number of fraud in the balanced dataset 64803/199008
# New synthetic data generated 291
# Number of fraud in the balanced dataset 65094/199008
# New synthetic data generated 298
# Number of fraud in the balanced dataset 65392/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 65686/199008
# New synthetic data generated 298
# Number of fraud in the balanced dataset 65984/199008
# New synthetic data generated 299
# Number of fraud in the balanced dataset 66283/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 66577/199008
# New synthetic data generated 293
# Number of fraud in the balanced dataset 66870/199008
# New synthetic data generated 296
# Number of fraud in the balanced dataset 67166/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 67460/199008
# New synthetic data generated 299
# Number of fraud in the balanced dataset 67759/199008
# New synthetic data generated 296
# Number of fraud in the balanced dataset 68055/199008
# New synthetic data generated 296
# Number of fraud in the balanced dataset 68351/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 68645/199008
# New synthetic data generated 297
# Number of fraud in the balanced dataset 68942/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 69236/199008
# New synthetic data generated 290
# Number of fraud in the balanced dataset 69526/199008
# New synthetic data generated 297
# Number of fraud in the balanced dataset 69823/199008
# New synthetic data generated 291
# Number of fraud in the balanced dataset 70114/199008
# New synthetic data generated 296
# Number of fraud in the balanced dataset 70410/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 70704/199008
# New synthetic data generated 299
# Number of fraud in the balanced dataset 71003/199008
# New synthetic data generated 296
# Number of fraud in the balanced dataset 71299/199008
# New synthetic data generated 297
# Number of fraud in the balanced dataset 71596/199008
# New synthetic data generated 292
# Number of fraud in the balanced dataset 71888/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 72182/199008
# New synthetic data generated 293
# Number of fraud in the balanced dataset 72475/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 72769/199008
# New synthetic data generated 297
# Number of fraud in the balanced dataset 73066/199008
# New synthetic data generated 297
# Number of fraud in the balanced dataset 73363/199008
# New synthetic data generated 296
# Number of fraud in the balanced dataset 73659/199008
# New synthetic data generated 297
# Number of fraud in the balanced dataset 73956/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 74250/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 74544/199008
# New synthetic data generated 298
# Number of fraud in the balanced dataset 74842/199008
# New synthetic data generated 298
# Number of fraud in the balanced dataset 75140/199008
# New synthetic data generated 298
# Number of fraud in the balanced dataset 75438/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 75732/199008
# New synthetic data generated 297
# Number of fraud in the balanced dataset 76029/199008
# New synthetic data generated 297
# Number of fraud in the balanced dataset 76326/199008
# New synthetic data generated 293
# Number of fraud in the balanced dataset 76619/199008
# New synthetic data generated 292
# Number of fraud in the balanced dataset 76911/199008
# New synthetic data generated 292
# Number of fraud in the balanced dataset 77203/199008
# New synthetic data generated 299
# Number of fraud in the balanced dataset 77502/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 77796/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 78090/199008
# New synthetic data generated 297
# Number of fraud in the balanced dataset 78387/199008
# New synthetic data generated 298
# Number of fraud in the balanced dataset 78685/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 78979/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 79274/199008
# New synthetic data generated 296
# Number of fraud in the balanced dataset 79570/199008
# New synthetic data generated 298
# Number of fraud in the balanced dataset 79868/199008
# New synthetic data generated 298
# Number of fraud in the balanced dataset 80166/199008
# New synthetic data generated 297
# Number of fraud in the balanced dataset 80463/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 80758/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 81052/199008
# New synthetic data generated 293
# Number of fraud in the balanced dataset 81345/199008
# New synthetic data generated 297
# Number of fraud in the balanced dataset 81642/199008
# New synthetic data generated 300
# Number of fraud in the balanced dataset 81942/199008
# New synthetic data generated 292
# Number of fraud in the balanced dataset 82234/199008
# New synthetic data generated 296
# Number of fraud in the balanced dataset 82530/199008
# New synthetic data generated 292
# Number of fraud in the balanced dataset 82822/199008
# New synthetic data generated 297
# Number of fraud in the balanced dataset 83119/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 83414/199008
# New synthetic data generated 298
# Number of fraud in the balanced dataset 83712/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 84007/199008
# New synthetic data generated 292
# Number of fraud in the balanced dataset 84299/199008
# New synthetic data generated 298
# Number of fraud in the balanced dataset 84597/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 84891/199008
# New synthetic data generated 297
# Number of fraud in the balanced dataset 85188/199008
# New synthetic data generated 297
# Number of fraud in the balanced dataset 85485/199008
# New synthetic data generated 296
# Number of fraud in the balanced dataset 85781/199008
# New synthetic data generated 296
# Number of fraud in the balanced dataset 86077/199008
# New synthetic data generated 299
# Number of fraud in the balanced dataset 86376/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 86670/199008
# New synthetic data generated 297
# Number of fraud in the balanced dataset 86967/199008
# New synthetic data generated 296
# Number of fraud in the balanced dataset 87263/199008
# New synthetic data generated 297
# Number of fraud in the balanced dataset 87560/199008
# New synthetic data generated 288
# Number of fraud in the balanced dataset 87848/199008
# New synthetic data generated 296
# Number of fraud in the balanced dataset 88144/199008
# New synthetic data generated 287
# Number of fraud in the balanced dataset 88431/199008
# New synthetic data generated 298
# Number of fraud in the balanced dataset 88729/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 89023/199008
# New synthetic data generated 292
# Number of fraud in the balanced dataset 89315/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 89610/199008
# New synthetic data generated 297
# Number of fraud in the balanced dataset 89907/199008
# New synthetic data generated 297
# Number of fraud in the balanced dataset 90204/199008
# New synthetic data generated 297
# Number of fraud in the balanced dataset 90501/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 90796/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 91090/199008
# New synthetic data generated 299
# Number of fraud in the balanced dataset 91389/199008
# New synthetic data generated 297
# Number of fraud in the balanced dataset 91686/199008
# New synthetic data generated 296
# Number of fraud in the balanced dataset 91982/199008
# New synthetic data generated 298
# Number of fraud in the balanced dataset 92280/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 92575/199008
# New synthetic data generated 298
# Number of fraud in the balanced dataset 92873/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 93168/199008
# New synthetic data generated 290
# Number of fraud in the balanced dataset 93458/199008
# New synthetic data generated 296
# Number of fraud in the balanced dataset 93754/199008
# New synthetic data generated 292
# Number of fraud in the balanced dataset 94046/199008
# New synthetic data generated 297
# Number of fraud in the balanced dataset 94343/199008
# New synthetic data generated 296
# Number of fraud in the balanced dataset 94639/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 94934/199008
# New synthetic data generated 298
# Number of fraud in the balanced dataset 95232/199008
# New synthetic data generated 296
# Number of fraud in the balanced dataset 95528/199008
# New synthetic data generated 296
# Number of fraud in the balanced dataset 95824/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 96119/199008
# New synthetic data generated 298
# Number of fraud in the balanced dataset 96417/199008
# New synthetic data generated 293
# Number of fraud in the balanced dataset 96710/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 97005/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 97300/199008
# New synthetic data generated 297
# Number of fraud in the balanced dataset 97597/199008
# New synthetic data generated 296
# Number of fraud in the balanced dataset 97893/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 98188/199008
# New synthetic data generated 292
# Number of fraud in the balanced dataset 98480/199008
# New synthetic data generated 297
# Number of fraud in the balanced dataset 98777/199008
# New synthetic data generated 291
# Number of fraud in the balanced dataset 99068/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 99363/199008
# New synthetic data generated 298
# Number of fraud in the balanced dataset 99661/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 99956/199008
# New synthetic data generated 297
# Number of fraud in the balanced dataset 100253/199008
# New synthetic data generated 296
# Number of fraud in the balanced dataset 100549/199008
# New synthetic data generated 298
# Number of fraud in the balanced dataset 100847/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 101141/199008
# New synthetic data generated 296
# Number of fraud in the balanced dataset 101437/199008
# New synthetic data generated 298
# Number of fraud in the balanced dataset 101735/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 102030/199008
# New synthetic data generated 296
# Number of fraud in the balanced dataset 102326/199008
# New synthetic data generated 293
# Number of fraud in the balanced dataset 102619/199008
# New synthetic data generated 299
# Number of fraud in the balanced dataset 102918/199008
# New synthetic data generated 299
# Number of fraud in the balanced dataset 103217/199008
# New synthetic data generated 290
# Number of fraud in the balanced dataset 103507/199008
# New synthetic data generated 299
# Number of fraud in the balanced dataset 103806/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 104101/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 104396/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 104691/199008
# New synthetic data generated 292
# Number of fraud in the balanced dataset 104983/199008
# New synthetic data generated 297
# Number of fraud in the balanced dataset 105280/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 105575/199008
# New synthetic data generated 298
# Number of fraud in the balanced dataset 105873/199008
# New synthetic data generated 297
# Number of fraud in the balanced dataset 106170/199008
# New synthetic data generated 296
# Number of fraud in the balanced dataset 106466/199008
# New synthetic data generated 291
# Number of fraud in the balanced dataset 106757/199008
# New synthetic data generated 296
# Number of fraud in the balanced dataset 107053/199008
# New synthetic data generated 297
# Number of fraud in the balanced dataset 107350/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 107645/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 107940/199008
# New synthetic data generated 296
# Number of fraud in the balanced dataset 108236/199008
# New synthetic data generated 296
# Number of fraud in the balanced dataset 108532/199008
# New synthetic data generated 292
# Number of fraud in the balanced dataset 108824/199008
# New synthetic data generated 296
# Number of fraud in the balanced dataset 109120/199008
# New synthetic data generated 296
# Number of fraud in the balanced dataset 109416/199008
# New synthetic data generated 292
# Number of fraud in the balanced dataset 109708/199008
# New synthetic data generated 296
# Number of fraud in the balanced dataset 110004/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 110298/199008
# New synthetic data generated 298
# Number of fraud in the balanced dataset 110596/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 110891/199008
# New synthetic data generated 297
# Number of fraud in the balanced dataset 111188/199008
# New synthetic data generated 296
# Number of fraud in the balanced dataset 111484/199008
# New synthetic data generated 296
# Number of fraud in the balanced dataset 111780/199008
# New synthetic data generated 290
# Number of fraud in the balanced dataset 112070/199008
# New synthetic data generated 297
# Number of fraud in the balanced dataset 112367/199008
# New synthetic data generated 299
# Number of fraud in the balanced dataset 112666/199008
# New synthetic data generated 298
# Number of fraud in the balanced dataset 112964/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 113259/199008
# New synthetic data generated 298
# Number of fraud in the balanced dataset 113557/199008
# New synthetic data generated 293
# Number of fraud in the balanced dataset 113850/199008
# New synthetic data generated 298
# Number of fraud in the balanced dataset 114148/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 114443/199008
# New synthetic data generated 297
# Number of fraud in the balanced dataset 114740/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 115034/199008
# New synthetic data generated 292
# Number of fraud in the balanced dataset 115326/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 115620/199008
# New synthetic data generated 296
# Number of fraud in the balanced dataset 115916/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 116211/199008
# New synthetic data generated 292
# Number of fraud in the balanced dataset 116503/199008
# New synthetic data generated 298
# Number of fraud in the balanced dataset 116801/199008
# New synthetic data generated 297
# Number of fraud in the balanced dataset 117098/199008
# New synthetic data generated 298
# Number of fraud in the balanced dataset 117396/199008
# New synthetic data generated 299
# Number of fraud in the balanced dataset 117695/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 117989/199008
# New synthetic data generated 291
# Number of fraud in the balanced dataset 118280/199008
# New synthetic data generated 298
# Number of fraud in the balanced dataset 118578/199008
# New synthetic data generated 296
# Number of fraud in the balanced dataset 118874/199008
# New synthetic data generated 296
# Number of fraud in the balanced dataset 119170/199008
# New synthetic data generated 297
# Number of fraud in the balanced dataset 119467/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 119762/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 120056/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 120351/199008
# New synthetic data generated 296
# Number of fraud in the balanced dataset 120647/199008
# New synthetic data generated 299
# Number of fraud in the balanced dataset 120946/199008
# New synthetic data generated 297
# Number of fraud in the balanced dataset 121243/199008
# New synthetic data generated 296
# Number of fraud in the balanced dataset 121539/199008
# New synthetic data generated 292
# Number of fraud in the balanced dataset 121831/199008
# New synthetic data generated 293
# Number of fraud in the balanced dataset 122124/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 122419/199008
# New synthetic data generated 293
# Number of fraud in the balanced dataset 122712/199008
# New synthetic data generated 299
# Number of fraud in the balanced dataset 123011/199008
# New synthetic data generated 297
# Number of fraud in the balanced dataset 123308/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 123603/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 123897/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 124192/199008
# New synthetic data generated 296
# Number of fraud in the balanced dataset 124488/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 124782/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 125077/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 125372/199008
# New synthetic data generated 293
# Number of fraud in the balanced dataset 125665/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 125959/199008
# New synthetic data generated 293
# Number of fraud in the balanced dataset 126252/199008
# New synthetic data generated 296
# Number of fraud in the balanced dataset 126548/199008
# New synthetic data generated 298
# Number of fraud in the balanced dataset 126846/199008
# New synthetic data generated 296
# Number of fraud in the balanced dataset 127142/199008
# New synthetic data generated 296
# Number of fraud in the balanced dataset 127438/199008
# New synthetic data generated 290
# Number of fraud in the balanced dataset 127728/199008
# New synthetic data generated 296
# Number of fraud in the balanced dataset 128024/199008
# New synthetic data generated 298
# Number of fraud in the balanced dataset 128322/199008
# New synthetic data generated 298
# Number of fraud in the balanced dataset 128620/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 128914/199008
# New synthetic data generated 293
# Number of fraud in the balanced dataset 129207/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 129502/199008
# New synthetic data generated 289
# Number of fraud in the balanced dataset 129791/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 130086/199008
# New synthetic data generated 296
# Number of fraud in the balanced dataset 130382/199008
# New synthetic data generated 292
# Number of fraud in the balanced dataset 130674/199008
# New synthetic data generated 296
# Number of fraud in the balanced dataset 130970/199008
# New synthetic data generated 297
# Number of fraud in the balanced dataset 131267/199008
# New synthetic data generated 296
# Number of fraud in the balanced dataset 131563/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 131858/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 132152/199008
# New synthetic data generated 299
# Number of fraud in the balanced dataset 132451/199008
# New synthetic data generated 293
# Number of fraud in the balanced dataset 132744/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 133039/199008
# New synthetic data generated 296
# Number of fraud in the balanced dataset 133335/199008
# New synthetic data generated 297
# Number of fraud in the balanced dataset 133632/199008
# New synthetic data generated 293
# Number of fraud in the balanced dataset 133925/199008
# New synthetic data generated 296
# Number of fraud in the balanced dataset 134221/199008
# New synthetic data generated 292
# Number of fraud in the balanced dataset 134513/199008
# New synthetic data generated 296
# Number of fraud in the balanced dataset 134809/199008
# New synthetic data generated 296
# Number of fraud in the balanced dataset 135105/199008
# New synthetic data generated 297
# Number of fraud in the balanced dataset 135402/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 135697/199008
# New synthetic data generated 297
# Number of fraud in the balanced dataset 135994/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 136289/199008
# New synthetic data generated 296
# Number of fraud in the balanced dataset 136585/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 136879/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 137173/199008
# New synthetic data generated 297
# Number of fraud in the balanced dataset 137470/199008
# New synthetic data generated 293
# Number of fraud in the balanced dataset 137763/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 138058/199008
# New synthetic data generated 293
# Number of fraud in the balanced dataset 138351/199008
# New synthetic data generated 296
# Number of fraud in the balanced dataset 138647/199008
# New synthetic data generated 297
# Number of fraud in the balanced dataset 138944/199008
# New synthetic data generated 299
# Number of fraud in the balanced dataset 139243/199008
# New synthetic data generated 296
# Number of fraud in the balanced dataset 139539/199008
# New synthetic data generated 298
# Number of fraud in the balanced dataset 139837/199008
# New synthetic data generated 292
# Number of fraud in the balanced dataset 140129/199008
# New synthetic data generated 297
# Number of fraud in the balanced dataset 140426/199008
# New synthetic data generated 292
# Number of fraud in the balanced dataset 140718/199008
# New synthetic data generated 298
# Number of fraud in the balanced dataset 141016/199008
# New synthetic data generated 293
# Number of fraud in the balanced dataset 141309/199008
# New synthetic data generated 298
# Number of fraud in the balanced dataset 141607/199008
# New synthetic data generated 296
# Number of fraud in the balanced dataset 141903/199008
# New synthetic data generated 300
# Number of fraud in the balanced dataset 142203/199008
# New synthetic data generated 289
# Number of fraud in the balanced dataset 142492/199008
# New synthetic data generated 300
# Number of fraud in the balanced dataset 142792/199008
# New synthetic data generated 296
# Number of fraud in the balanced dataset 143088/199008
# New synthetic data generated 297
# Number of fraud in the balanced dataset 143385/199008
# New synthetic data generated 289
# Number of fraud in the balanced dataset 143674/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 143969/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 144264/199008
# New synthetic data generated 296
# Number of fraud in the balanced dataset 144560/199008
# New synthetic data generated 297
# Number of fraud in the balanced dataset 144857/199008
# New synthetic data generated 293
# Number of fraud in the balanced dataset 145150/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 145445/199008
# New synthetic data generated 293
# Number of fraud in the balanced dataset 145738/199008
# New synthetic data generated 291
# Number of fraud in the balanced dataset 146029/199008
# New synthetic data generated 297
# Number of fraud in the balanced dataset 146326/199008
# New synthetic data generated 296
# Number of fraud in the balanced dataset 146622/199008
# New synthetic data generated 293
# Number of fraud in the balanced dataset 146915/199008
# New synthetic data generated 297
# Number of fraud in the balanced dataset 147212/199008
# New synthetic data generated 291
# Number of fraud in the balanced dataset 147503/199008
# New synthetic data generated 297
# Number of fraud in the balanced dataset 147800/199008
# New synthetic data generated 300
# Number of fraud in the balanced dataset 148100/199008
# New synthetic data generated 299
# Number of fraud in the balanced dataset 148399/199008
# New synthetic data generated 297
# Number of fraud in the balanced dataset 148696/199008
# New synthetic data generated 292
# Number of fraud in the balanced dataset 148988/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 149282/199008
# New synthetic data generated 292
# Number of fraud in the balanced dataset 149574/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 149868/199008
# New synthetic data generated 296
# Number of fraud in the balanced dataset 150164/199008
# New synthetic data generated 291
# Number of fraud in the balanced dataset 150455/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 150749/199008
# New synthetic data generated 297
# Number of fraud in the balanced dataset 151046/199008
# New synthetic data generated 293
# Number of fraud in the balanced dataset 151339/199008
# New synthetic data generated 293
# Number of fraud in the balanced dataset 151632/199008
# New synthetic data generated 293
# Number of fraud in the balanced dataset 151925/199008
# New synthetic data generated 291
# Number of fraud in the balanced dataset 152216/199008
# New synthetic data generated 293
# Number of fraud in the balanced dataset 152509/199008
# New synthetic data generated 298
# Number of fraud in the balanced dataset 152807/199008
# New synthetic data generated 297
# Number of fraud in the balanced dataset 153104/199008
# New synthetic data generated 296
# Number of fraud in the balanced dataset 153400/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 153694/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 153988/199008
# New synthetic data generated 296
# Number of fraud in the balanced dataset 154284/199008
# New synthetic data generated 297
# Number of fraud in the balanced dataset 154581/199008
# New synthetic data generated 292
# Number of fraud in the balanced dataset 154873/199008
# New synthetic data generated 297
# Number of fraud in the balanced dataset 155170/199008
# New synthetic data generated 297
# Number of fraud in the balanced dataset 155467/199008
# New synthetic data generated 299
# Number of fraud in the balanced dataset 155766/199008
# New synthetic data generated 297
# Number of fraud in the balanced dataset 156063/199008
# New synthetic data generated 296
# Number of fraud in the balanced dataset 156359/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 156653/199008
# New synthetic data generated 298
# Number of fraud in the balanced dataset 156951/199008
# New synthetic data generated 290
# Number of fraud in the balanced dataset 157241/199008
# New synthetic data generated 296
# Number of fraud in the balanced dataset 157537/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 157832/199008
# New synthetic data generated 296
# Number of fraud in the balanced dataset 158128/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 158423/199008
# New synthetic data generated 290
# Number of fraud in the balanced dataset 158713/199008
# New synthetic data generated 297
# Number of fraud in the balanced dataset 159010/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 159304/199008
# New synthetic data generated 293
# Number of fraud in the balanced dataset 159597/199008
# New synthetic data generated 293
# Number of fraud in the balanced dataset 159890/199008
# New synthetic data generated 298
# Number of fraud in the balanced dataset 160188/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 160482/199008
# New synthetic data generated 296
# Number of fraud in the balanced dataset 160778/199008
# New synthetic data generated 298
# Number of fraud in the balanced dataset 161076/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 161370/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 161665/199008
# New synthetic data generated 296
# Number of fraud in the balanced dataset 161961/199008
# New synthetic data generated 292
# Number of fraud in the balanced dataset 162253/199008
# New synthetic data generated 298
# Number of fraud in the balanced dataset 162551/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 162846/199008
# New synthetic data generated 298
# Number of fraud in the balanced dataset 163144/199008
# New synthetic data generated 296
# Number of fraud in the balanced dataset 163440/199008
# New synthetic data generated 296
# Number of fraud in the balanced dataset 163736/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 164031/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 164325/199008
# New synthetic data generated 297
# Number of fraud in the balanced dataset 164622/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 164917/199008
# New synthetic data generated 299
# Number of fraud in the balanced dataset 165216/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 165511/199008
# New synthetic data generated 298
# Number of fraud in the balanced dataset 165809/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 166103/199008
# New synthetic data generated 296
# Number of fraud in the balanced dataset 166399/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 166693/199008
# New synthetic data generated 296
# Number of fraud in the balanced dataset 166989/199008
# New synthetic data generated 297
# Number of fraud in the balanced dataset 167286/199008
# New synthetic data generated 297
# Number of fraud in the balanced dataset 167583/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 167877/199008
# New synthetic data generated 293
# Number of fraud in the balanced dataset 168170/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 168464/199008
# New synthetic data generated 296
# Number of fraud in the balanced dataset 168760/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 169055/199008
# New synthetic data generated 297
# Number of fraud in the balanced dataset 169352/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 169647/199008
# New synthetic data generated 296
# Number of fraud in the balanced dataset 169943/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 170238/199008
# New synthetic data generated 296
# Number of fraud in the balanced dataset 170534/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 170829/199008
# New synthetic data generated 297
# Number of fraud in the balanced dataset 171126/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 171420/199008
# New synthetic data generated 296
# Number of fraud in the balanced dataset 171716/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 172010/199008
# New synthetic data generated 298
# Number of fraud in the balanced dataset 172308/199008
# New synthetic data generated 296
# Number of fraud in the balanced dataset 172604/199008
# New synthetic data generated 293
# Number of fraud in the balanced dataset 172897/199008
# New synthetic data generated 293
# Number of fraud in the balanced dataset 173190/199008
# New synthetic data generated 297
# Number of fraud in the balanced dataset 173487/199008
# New synthetic data generated 297
# Number of fraud in the balanced dataset 173784/199008
# New synthetic data generated 296
# Number of fraud in the balanced dataset 174080/199008
# New synthetic data generated 292
# Number of fraud in the balanced dataset 174372/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 174667/199008
# New synthetic data generated 297
# Number of fraud in the balanced dataset 174964/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 175259/199008
# New synthetic data generated 297
# Number of fraud in the balanced dataset 175556/199008
# New synthetic data generated 297
# Number of fraud in the balanced dataset 175853/199008
# New synthetic data generated 299
# Number of fraud in the balanced dataset 176152/199008
# New synthetic data generated 296
# Number of fraud in the balanced dataset 176448/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 176743/199008
# New synthetic data generated 297
# Number of fraud in the balanced dataset 177040/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 177335/199008
# New synthetic data generated 296
# Number of fraud in the balanced dataset 177631/199008
# New synthetic data generated 293
# Number of fraud in the balanced dataset 177924/199008
# New synthetic data generated 296
# Number of fraud in the balanced dataset 178220/199008
# New synthetic data generated 293
# Number of fraud in the balanced dataset 178513/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 178808/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 179103/199008
# New synthetic data generated 291
# Number of fraud in the balanced dataset 179394/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 179689/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 179984/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 180279/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 180573/199008
# New synthetic data generated 296
# Number of fraud in the balanced dataset 180869/199008
# New synthetic data generated 297
# Number of fraud in the balanced dataset 181166/199008
# New synthetic data generated 297
# Number of fraud in the balanced dataset 181463/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 181757/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 182052/199008
# New synthetic data generated 291
# Number of fraud in the balanced dataset 182343/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 182638/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 182933/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 183227/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 183521/199008
# New synthetic data generated 297
# Number of fraud in the balanced dataset 183818/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 184113/199008
# New synthetic data generated 297
# Number of fraud in the balanced dataset 184410/199008
# New synthetic data generated 299
# Number of fraud in the balanced dataset 184709/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 185003/199008
# New synthetic data generated 292
# Number of fraud in the balanced dataset 185295/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 185590/199008
# New synthetic data generated 297
# Number of fraud in the balanced dataset 185887/199008
# New synthetic data generated 298
# Number of fraud in the balanced dataset 186185/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 186479/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 186774/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 187069/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 187364/199008
# New synthetic data generated 290
# Number of fraud in the balanced dataset 187654/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 187949/199008
# New synthetic data generated 297
# Number of fraud in the balanced dataset 188246/199008
# New synthetic data generated 299
# Number of fraud in the balanced dataset 188545/199008
# New synthetic data generated 297
# Number of fraud in the balanced dataset 188842/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 189136/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 189430/199008
# New synthetic data generated 296
# Number of fraud in the balanced dataset 189726/199008
# New synthetic data generated 293
# Number of fraud in the balanced dataset 190019/199008
# New synthetic data generated 298
# Number of fraud in the balanced dataset 190317/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 190612/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 190906/199008
# New synthetic data generated 296
# Number of fraud in the balanced dataset 191202/199008
# New synthetic data generated 298
# Number of fraud in the balanced dataset 191500/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 191794/199008
# New synthetic data generated 297
# Number of fraud in the balanced dataset 192091/199008
# New synthetic data generated 298
# Number of fraud in the balanced dataset 192389/199008
# New synthetic data generated 298
# Number of fraud in the balanced dataset 192687/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 192982/199008
# New synthetic data generated 292
# Number of fraud in the balanced dataset 193274/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 193568/199008
# New synthetic data generated 298
# Number of fraud in the balanced dataset 193866/199008
# New synthetic data generated 297
# Number of fraud in the balanced dataset 194163/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 194458/199008
# New synthetic data generated 296
# Number of fraud in the balanced dataset 194754/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 195049/199008
# New synthetic data generated 296
# Number of fraud in the balanced dataset 195345/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 195640/199008
# New synthetic data generated 296
# Number of fraud in the balanced dataset 195936/199008
# New synthetic data generated 297
# Number of fraud in the balanced dataset 196233/199008
# New synthetic data generated 296
# Number of fraud in the balanced dataset 196529/199008
# New synthetic data generated 292
# Number of fraud in the balanced dataset 196821/199008
# New synthetic data generated 297
# Number of fraud in the balanced dataset 197118/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 197412/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 197706/199008
# New synthetic data generated 299
# Number of fraud in the balanced dataset 198005/199008
# New synthetic data generated 293
# Number of fraud in the balanced dataset 198298/199008
# New synthetic data generated 296
# Number of fraud in the balanced dataset 198594/199008
# New synthetic data generated 296
# Number of fraud in the balanced dataset 198890/199008
# New synthetic data generated 298
# Number of fraud in the balanced dataset 199188/199008
# (398196, 31)
# Number of fraud in the balanced dataset 199188
# Number of non-fraud in the balanced dataset 199008

# %%
class Attention(nn.Module):
    def __init__(self, input_dim):
        super(Attention, self).__init__()
        self.attention_weights = nn.Linear(input_dim, 1, bias=False)  # Learnable attention weights

    def forward(self, lstm_output):
        # Compute attention scores (softmax over time dimension)
        attention_scores = torch.softmax(self.attention_weights(lstm_output), dim=1)  
        weighted_output = lstm_output * attention_scores  # Apply attention
        return torch.sum(weighted_output, dim=1)  # Sum over sequence length (time steps)

# %%
class ALSTM(nn.Module):
    def __init__(self, input_dim, hidden_dim):
        super(ALSTM, self).__init__()
        self.lstm = nn.LSTM(input_dim, hidden_dim, batch_first=True)  # Forward LSTM
        self.attention = Attention(hidden_dim)  # Attention Layer
        self.fc = nn.Linear(hidden_dim, 1)  # Fully connected output layer
        self.sigmoid = nn.Sigmoid()  # Sigmoid activation for binary classification

    def forward(self, x):
        lstm_output, _ = self.lstm(x)  # Get LSTM output
        attention_out = self.attention(lstm_output)  # Apply attention
        output = self.fc(attention_out)  # Fully connected layer
        return self.sigmoid(output)  # Sigmoid activation for probability output

# %%
# split data_train_oversampled in 20-80 split test-train
data_oversampled_labels = data_train_oversampled[:, -1]
data_train_oversampled = data_train_oversampled[:, :-1]
data_reshaped = data_train_oversampled.reshape(data_train_oversampled.shape[0], 1, data_train_oversampled.shape[1])

# Convert to PyTorch tensors
X_tensor = torch.tensor(data_reshaped, dtype=torch.float32)
y_tensor = torch.tensor(data_oversampled_labels, dtype=torch.float32)

# Split into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X_tensor, y_tensor, test_size=0.2, random_state=42)

# Create DataLoader for PyTorch
train_dataset = TensorDataset(X_train, y_train)
test_dataset = TensorDataset(X_test, y_test)

train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=32, shuffle=False)

# %%
input_dim = data_reshaped.shape[2]  # Number of features per transaction
hidden_dim = 128 # da cercare il valore migliore

# Initialize model, loss function, and optimizer
ALSTMmodel = ALSTM(input_dim, hidden_dim)
criterion = nn.BCELoss()  # Binary Cross Entropy for classification
optimizer = torch.optim.Adam(ALSTMmodel.parameters(), lr=0.001)

# Move model to GPU if available
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
ALSTMmodel.to(device)
# Out:
# ALSTM(
#   (lstm): LSTM(29, 128, batch_first=True)
#   (attention): Attention(
#     (attention_weights): Linear(in_features=128, out_features=1, bias=False)
#   )
#   (fc): Linear(in_features=128, out_features=1, bias=True)
#   (sigmoid): Sigmoid()
# )

# %%
def train_ALSTM(model, train_loader, residual):
    num_epochs = 10
    for epoch in range(num_epochs):
        model.train()
        epoch_loss = 0

        for X_batch, _ in train_loader:
            # transform residual in tensor
            residual = torch.tensor(residual, dtype=torch.float32)
            X_batch, residual = X_batch.to(device), residual.to(device)

            optimizer.zero_grad()  # Reset gradients
            y_pred = model(X_batch).squeeze()
        
            loss = criterion(y_pred, residual)  # Compute loss
            loss.backward()  # Backpropagation
            optimizer.step()  # Update weights

            epoch_loss += loss.item()
    
        print(f"Epoch [{epoch+1}/{num_epochs}], Loss: {epoch_loss:.4f}")
        
    return model

# %%
def loss(y, y_hat):
    return 1/2 * np.sum((y - y_hat)**2)

# %%
h_x = loss(data_oversampled_labels, 0)

for _ in range(6):

    residual = (data_oversampled_labels - h_x)
    ALSTMmodel = train_ALSTM(ALSTMmodel, train_loader, residual)
    y_pred = ALSTMmodel(train_loader).squeeze().detach().numpy()
    step_length = np.argmin(loss(data_oversampled_labels, h_x + step_length * y_pred))
    h_x += step_length * y_pred
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[17], line 6
#       3 for _ in range(6):
#       5     residual = (data_oversampled_labels - h_x)
# ----> 6     ALSTMmodel = train_ALSTM(ALSTMmodel, train_loader, residual)
#       7     y_pred = ALSTMmodel(train_loader).squeeze().detach().numpy()
#       8     step_length = np.argmin(loss(data_oversampled_labels, h_x + step_length * y_pred))
#
# Cell In[15], line 15, in train_ALSTM(model, train_loader, residual)
#      12 optimizer.zero_grad()  # Reset gradients
#      13 y_pred = model(X_batch).squeeze()
# ---> 15 loss = criterion(y_pred, residual)  # Compute loss
#      16 loss.backward()  # Backpropagation
#      17 optimizer.step()  # Update weights
#
# File ~/Desktop/pythonProject/.venv/lib/python3.10/site-packages/torch/nn/modules/module.py:1739, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1737     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738 else:
# -> 1739     return self._call_impl(*args, **kwargs)
#
# File ~/Desktop/pythonProject/.venv/lib/python3.10/site-packages/torch/nn/modules/module.py:1750, in Module._call_impl(self, *args, **kwargs)
#    1745 # If we don't have any hooks, we want to skip the rest of the logic in
#    1746 # this function, and just call forward.
#    1747 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1748         or _global_backward_pre_hooks or _global_backward_hooks
#    1749         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750     return forward_call(*args, **kwargs)
#    1752 result = None
#    1753 called_always_called_hooks = set()
#
# File ~/Desktop/pythonProject/.venv/lib/python3.10/site-packages/torch/nn/modules/loss.py:699, in BCELoss.forward(self, input, target)
#     698 def forward(self, input: Tensor, target: Tensor) -> Tensor:
# --> 699     return F.binary_cross_entropy(
#     700         input, target, weight=self.weight, reduction=self.reduction
#     701     )
#
# File ~/Desktop/pythonProject/.venv/lib/python3.10/site-packages/torch/nn/functional.py:3560, in binary_cross_entropy(input, target, weight, size_average, reduce, reduction)
#    3558     reduction_enum = _Reduction.get_enum(reduction)
#    3559 if target.size() != input.size():
# -> 3560     raise ValueError(
#    3561         f"Using a target size ({target.size()}) that is different to the input size ({input.size()}) is deprecated. "
#    3562         "Please ensure they have the same size."
#    3563     )
#    3565 if weight is not None:
#    3566     new_size = _infer_size(target.size(), weight.size())
#
# ValueError: Using a target size (torch.Size([398196])) that is different to the input size (torch.Size([32])) is deprecated. Please ensure they have the same size.

# %%
ALSTMmodel.eval()  # Set model to evaluation mode

correct = 0
total = 0

with torch.no_grad():  # No gradients needed for evaluation
    for X_batch, y_batch in test_loader:
        X_batch, y_batch = X_batch.to(device), y_batch.to(device)
        y_pred = ALSTMmodel(X_batch).squeeze()
        y_pred_labels = (y_pred > 0.5).float()  # Convert probabilities to binary labels
        
        correct += (y_pred_labels == y_batch).sum().item()
        total += y_batch.size(0)

accuracy = correct / total
print(f"Test Accuracy: {accuracy:.4f}")
