# %%
import numpy as np
import pandas as pd
import torch
import torch.nn as nn
from sklearn.preprocessing import RobustScaler
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
import jax.numpy as jnp
from torch.utils.data import DataLoader, TensorDataset

data = pd.read_csv('creditcard.csv')

dataset = data.to_numpy().astype(np.float32)  # Ensure data is float32 for PyTorch

scaler = RobustScaler(with_centering=True, with_scaling=True, quantile_range=(25.0, 75.0), unit_variance=False)
dataset[:, [0, 29]] = scaler.fit_transform(dataset[:, [0, 29]])

# %%
data_train, data_test = train_test_split(dataset, test_size=0.3, random_state=42)

# %%
# -----------------------------
# 3. Define the Autoencoder Model
# -----------------------------
class Autoencoder(nn.Module):
    def __init__(self):
        super(Autoencoder, self).__init__()
        # Encoder: 31 -> 23 -> 19 -> 17 -> 8 with dropout after first two hidden layers
        self.encoder = nn.Sequential(
            nn.Linear(31, 23),
            nn.Tanh(),
            nn.Dropout(0.1),
            nn.Linear(23, 19),
            nn.Tanh(),
            nn.Dropout(0.2),
            nn.Linear(19, 17),
            nn.Tanh(),
            nn.Linear(17, 8)
        )
        # Decoder: 8 -> 17 -> 19 -> 23 -> 31 with dropout after first two layers
        self.decoder = nn.Sequential(
            nn.Linear(8, 17),
            nn.Tanh(),
            nn.Dropout(0.2),
            nn.Linear(17, 19),
            nn.Tanh(),
            nn.Dropout(0.1),
            nn.Linear(19, 23),
            nn.Tanh(),
            nn.Linear(23, 31)
        )

    def forward(self, x):
        latent = self.encoder(x)
        reconstructed = self.decoder(latent)
        return reconstructed

# %%
fraud_data = data_train[data_train[:, -1] == 1]
non_fraud_data = data_train[data_train[:, -1] == 0]

legit_data_limited = non_fraud_data[np.random.choice(non_fraud_data.shape[0], fraud_data.shape[0], replace=False)]

train_dataset_SVM = np.vstack((legit_data_limited, fraud_data))
np.random.shuffle(train_dataset_SVM)
train_labels_SVM = train_dataset_SVM[:, -1]
train_dataset_SVM = train_dataset_SVM[:, :-1]

data_train_SVM, data_test_SVM, labels_train_SVM, labels_test_SVM = train_test_split(train_dataset_SVM, train_labels_SVM, test_size=0.2, random_state=42)
model = SVC(kernel='linear', C=1.0)
model.fit(data_train_SVM, labels_train_SVM)

labels_pred_test = model.predict(data_test_SVM)
labels_pred_train = model.predict(data_train_SVM)
accuracy_train = jnp.mean(labels_pred_train == labels_train_SVM)
accuracy_test = jnp.mean(labels_pred_test == labels_test_SVM)

print(f"Train Accuracy: {accuracy_train:.4f}")
print(f"Test Accuracy: {accuracy_test:.4f}")
# Out:
# Train Accuracy: 0.9613
# Test Accuracy: 0.9301

# %%
# load the model 
myModel = Autoencoder()

# Load the saved state dictionary
myModel.load_state_dict(torch.load("model/autoencoder/autoencoder.pth", map_location=torch.device('cpu'), weights_only=True))
myModel.eval()

alpha = 0.9

data_train_oversampled = data_train.copy()

while (len(data_train_oversampled[data_train_oversampled[:, -1] == 1]) < len(data_train_oversampled[data_train_oversampled[:, -1] == 0])):
    fraud_data = data_train_oversampled[data_train_oversampled[:, -1] == 1]

    # 2) Generate synthetic data by interpolating between fraud data points
    fraud_data_tensor = torch.tensor(fraud_data, dtype=torch.float32)

    latent_representations = myModel.encoder(fraud_data_tensor)

    noisy_vectors = []
    for _ in range(300):
        # Pick a random fraud vector
        i = np.random.randint(0, 300)
        z_i = latent_representations[i]

        # Optionally pick a second random vector to interpolate
        j = np.random.randint(0, 300)
        z_j = latent_representations[j]
        
        # Interpolation factor
        lambda_ = np.random.rand()
        z_ij = lambda_*z_i + (1 - lambda_)*z_j
        
        # Add Gaussian noise around that interpolation
        noise = torch.normal(mean=0.0, std=alpha, size=(8,))
        z_syn = z_ij + noise  # Both are tensors, so this should work directly

        noisy_vectors.append(z_syn.detach().numpy())

    noisy_vectors = np.array(noisy_vectors)

    # 3) Decode them to get synthetic data in original input space
    X_synthetic = myModel.decoder(torch.tensor(noisy_vectors, dtype=torch.float32)).detach().numpy()
    # remove label
    X_synthetic_to_predict = X_synthetic[:, :-1]
    # 4) Validate with SVM
    y_pred = model.predict(X_synthetic_to_predict)

    X_synthetic[:, -1] = y_pred

    # 5) Add the synthetic data to the training set
    X_synthetic_fraud = X_synthetic[X_synthetic[:, -1] == 1]

    data_train_oversampled = np.vstack((data_train_oversampled, X_synthetic_fraud))

    print("New synthetic data generated", len(X_synthetic_fraud))
    print(f"Number of fraud in the balanced dataset {len(data_train_oversampled[data_train_oversampled[:, -1] == 1])}/{len(data_train_oversampled[data_train_oversampled[:, -1] == 0])}")

# for i in range(len(data_train_oversampled[data_train_oversampled[:, -1] == 1]) - len(data_train_oversampled[data_train_oversampled[:, -1] == 0])):
#     noisy_vectors = []
#     for _ in range(n):
#         # Pick a random fraud vector
#         i = np.random.randint(0, n)
#         z_i = latent_representations[i]

#         # Optionally pick a second random vector to interpolate
#         j = np.random.randint(0, n)
#         z_j = latent_representations[j]
        
#         # Interpolation factor
#         lambda_ = np.random.rand()
#         z_ij = lambda_*z_i + (1 - lambda_)*z_j
        
#         # Add Gaussian noise around that interpolation
#         noise = torch.normal(mean=0.0, std=alpha, size=(latent_dim,))
#         z_syn = z_ij + noise  # Both are tensors, so this should work directly

#         noisy_vectors.append(z_syn.detach().numpy())

#     noisy_vectors = np.array(noisy_vectors)

#     # 3) Decode them to get synthetic data in original input space
#     X_synthetic = myModel.decoder(torch.tensor(noisy_vectors, dtype=torch.float32)).detach().numpy()
#     # remove label
#     X_synthetic_to_predict = X_synthetic[:, :-1]
#     # 4) Validate with SVM
#     y_pred = model.predict(X_synthetic_to_predict)

#     X_synthetic[:, -1] = y_pred

#     # 5) Add the synthetic data to the training set
#     X_synthetic_fraud = X_synthetic[X_synthetic[:, -1] == 1]

#     data_train_oversampled = np.vstack((data_train_oversampled, X_synthetic_fraud))

print(data_train_oversampled.shape)
print("Number of fraud in the balanced dataset", len(data_train_oversampled[data_train_oversampled[:, -1] == 1]))
print("Number of non-fraud in the balanced dataset", len(data_train_oversampled[data_train_oversampled[:, -1] == 0]))
# Out:
# New synthetic data generated 295
# Number of fraud in the balanced dataset 651/199008
# New synthetic data generated 287
# Number of fraud in the balanced dataset 938/199008
# New synthetic data generated 291
# Number of fraud in the balanced dataset 1229/199008
# New synthetic data generated 289
# Number of fraud in the balanced dataset 1518/199008
# New synthetic data generated 291
# Number of fraud in the balanced dataset 1809/199008
# New synthetic data generated 292
# Number of fraud in the balanced dataset 2101/199008
# New synthetic data generated 292
# Number of fraud in the balanced dataset 2393/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 2687/199008
# New synthetic data generated 290
# Number of fraud in the balanced dataset 2977/199008
# New synthetic data generated 293
# Number of fraud in the balanced dataset 3270/199008
# New synthetic data generated 289
# Number of fraud in the balanced dataset 3559/199008
# New synthetic data generated 285
# Number of fraud in the balanced dataset 3844/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 4138/199008
# New synthetic data generated 290
# Number of fraud in the balanced dataset 4428/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 4723/199008
# New synthetic data generated 293
# Number of fraud in the balanced dataset 5016/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 5311/199008
# New synthetic data generated 286
# Number of fraud in the balanced dataset 5597/199008
# New synthetic data generated 293
# Number of fraud in the balanced dataset 5890/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 6184/199008
# New synthetic data generated 293
# Number of fraud in the balanced dataset 6477/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 6772/199008
# New synthetic data generated 296
# Number of fraud in the balanced dataset 7068/199008
# New synthetic data generated 291
# Number of fraud in the balanced dataset 7359/199008
# New synthetic data generated 289
# Number of fraud in the balanced dataset 7648/199008
# New synthetic data generated 293
# Number of fraud in the balanced dataset 7941/199008
# New synthetic data generated 291
# Number of fraud in the balanced dataset 8232/199008
# New synthetic data generated 292
# Number of fraud in the balanced dataset 8524/199008
# New synthetic data generated 290
# Number of fraud in the balanced dataset 8814/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 9109/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 9404/199008
# New synthetic data generated 288
# Number of fraud in the balanced dataset 9692/199008
# New synthetic data generated 292
# Number of fraud in the balanced dataset 9984/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 10278/199008
# New synthetic data generated 296
# Number of fraud in the balanced dataset 10574/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 10868/199008
# New synthetic data generated 288
# Number of fraud in the balanced dataset 11156/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 11450/199008
# New synthetic data generated 291
# Number of fraud in the balanced dataset 11741/199008
# New synthetic data generated 290
# Number of fraud in the balanced dataset 12031/199008
# New synthetic data generated 289
# Number of fraud in the balanced dataset 12320/199008
# New synthetic data generated 291
# Number of fraud in the balanced dataset 12611/199008
# New synthetic data generated 291
# Number of fraud in the balanced dataset 12902/199008
# New synthetic data generated 290
# Number of fraud in the balanced dataset 13192/199008
# New synthetic data generated 293
# Number of fraud in the balanced dataset 13485/199008
# New synthetic data generated 290
# Number of fraud in the balanced dataset 13775/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 14069/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 14363/199008
# New synthetic data generated 289
# Number of fraud in the balanced dataset 14652/199008
# New synthetic data generated 291
# Number of fraud in the balanced dataset 14943/199008
# New synthetic data generated 287
# Number of fraud in the balanced dataset 15230/199008
# New synthetic data generated 285
# Number of fraud in the balanced dataset 15515/199008
# New synthetic data generated 282
# Number of fraud in the balanced dataset 15797/199008
# New synthetic data generated 290
# Number of fraud in the balanced dataset 16087/199008
# New synthetic data generated 290
# Number of fraud in the balanced dataset 16377/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 16672/199008
# New synthetic data generated 291
# Number of fraud in the balanced dataset 16963/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 17257/199008
# New synthetic data generated 292
# Number of fraud in the balanced dataset 17549/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 17843/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 18137/199008
# New synthetic data generated 287
# Number of fraud in the balanced dataset 18424/199008
# New synthetic data generated 292
# Number of fraud in the balanced dataset 18716/199008
# New synthetic data generated 291
# Number of fraud in the balanced dataset 19007/199008
# New synthetic data generated 289
# Number of fraud in the balanced dataset 19296/199008
# New synthetic data generated 292
# Number of fraud in the balanced dataset 19588/199008
# New synthetic data generated 292
# Number of fraud in the balanced dataset 19880/199008
# New synthetic data generated 292
# Number of fraud in the balanced dataset 20172/199008
# New synthetic data generated 288
# Number of fraud in the balanced dataset 20460/199008
# New synthetic data generated 290
# Number of fraud in the balanced dataset 20750/199008
# New synthetic data generated 297
# Number of fraud in the balanced dataset 21047/199008
# New synthetic data generated 287
# Number of fraud in the balanced dataset 21334/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 21629/199008
# New synthetic data generated 292
# Number of fraud in the balanced dataset 21921/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 22215/199008
# New synthetic data generated 293
# Number of fraud in the balanced dataset 22508/199008
# New synthetic data generated 292
# Number of fraud in the balanced dataset 22800/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 23095/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 23390/199008
# New synthetic data generated 298
# Number of fraud in the balanced dataset 23688/199008
# New synthetic data generated 296
# Number of fraud in the balanced dataset 23984/199008
# New synthetic data generated 288
# Number of fraud in the balanced dataset 24272/199008
# New synthetic data generated 297
# Number of fraud in the balanced dataset 24569/199008
# New synthetic data generated 288
# Number of fraud in the balanced dataset 24857/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 25151/199008
# New synthetic data generated 288
# Number of fraud in the balanced dataset 25439/199008
# New synthetic data generated 287
# Number of fraud in the balanced dataset 25726/199008
# New synthetic data generated 293
# Number of fraud in the balanced dataset 26019/199008
# New synthetic data generated 290
# Number of fraud in the balanced dataset 26309/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 26603/199008
# New synthetic data generated 296
# Number of fraud in the balanced dataset 26899/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 27194/199008
# New synthetic data generated 292
# Number of fraud in the balanced dataset 27486/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 27781/199008
# New synthetic data generated 287
# Number of fraud in the balanced dataset 28068/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 28363/199008
# New synthetic data generated 292
# Number of fraud in the balanced dataset 28655/199008
# New synthetic data generated 292
# Number of fraud in the balanced dataset 28947/199008
# New synthetic data generated 290
# Number of fraud in the balanced dataset 29237/199008
# New synthetic data generated 296
# Number of fraud in the balanced dataset 29533/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 29827/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 30121/199008
# New synthetic data generated 296
# Number of fraud in the balanced dataset 30417/199008
# New synthetic data generated 292
# Number of fraud in the balanced dataset 30709/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 31003/199008
# New synthetic data generated 293
# Number of fraud in the balanced dataset 31296/199008
# New synthetic data generated 291
# Number of fraud in the balanced dataset 31587/199008
# New synthetic data generated 292
# Number of fraud in the balanced dataset 31879/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 32174/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 32469/199008
# New synthetic data generated 292
# Number of fraud in the balanced dataset 32761/199008
# New synthetic data generated 283
# Number of fraud in the balanced dataset 33044/199008
# New synthetic data generated 291
# Number of fraud in the balanced dataset 33335/199008
# New synthetic data generated 297
# Number of fraud in the balanced dataset 33632/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 33926/199008
# New synthetic data generated 292
# Number of fraud in the balanced dataset 34218/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 34513/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 34808/199008
# New synthetic data generated 286
# Number of fraud in the balanced dataset 35094/199008
# New synthetic data generated 296
# Number of fraud in the balanced dataset 35390/199008
# New synthetic data generated 293
# Number of fraud in the balanced dataset 35683/199008
# New synthetic data generated 293
# Number of fraud in the balanced dataset 35976/199008
# New synthetic data generated 296
# Number of fraud in the balanced dataset 36272/199008
# New synthetic data generated 298
# Number of fraud in the balanced dataset 36570/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 36864/199008
# New synthetic data generated 288
# Number of fraud in the balanced dataset 37152/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 37446/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 37740/199008
# New synthetic data generated 298
# Number of fraud in the balanced dataset 38038/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 38332/199008
# New synthetic data generated 289
# Number of fraud in the balanced dataset 38621/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 38915/199008
# New synthetic data generated 296
# Number of fraud in the balanced dataset 39211/199008
# New synthetic data generated 292
# Number of fraud in the balanced dataset 39503/199008
# New synthetic data generated 296
# Number of fraud in the balanced dataset 39799/199008
# New synthetic data generated 292
# Number of fraud in the balanced dataset 40091/199008
# New synthetic data generated 297
# Number of fraud in the balanced dataset 40388/199008
# New synthetic data generated 286
# Number of fraud in the balanced dataset 40674/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 40968/199008
# New synthetic data generated 290
# Number of fraud in the balanced dataset 41258/199008
# New synthetic data generated 292
# Number of fraud in the balanced dataset 41550/199008
# New synthetic data generated 298
# Number of fraud in the balanced dataset 41848/199008
# New synthetic data generated 291
# Number of fraud in the balanced dataset 42139/199008
# New synthetic data generated 289
# Number of fraud in the balanced dataset 42428/199008
# New synthetic data generated 292
# Number of fraud in the balanced dataset 42720/199008
# New synthetic data generated 290
# Number of fraud in the balanced dataset 43010/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 43304/199008
# New synthetic data generated 299
# Number of fraud in the balanced dataset 43603/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 43898/199008
# New synthetic data generated 292
# Number of fraud in the balanced dataset 44190/199008
# New synthetic data generated 288
# Number of fraud in the balanced dataset 44478/199008
# New synthetic data generated 290
# Number of fraud in the balanced dataset 44768/199008
# New synthetic data generated 292
# Number of fraud in the balanced dataset 45060/199008
# New synthetic data generated 292
# Number of fraud in the balanced dataset 45352/199008
# New synthetic data generated 291
# Number of fraud in the balanced dataset 45643/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 45938/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 46233/199008
# New synthetic data generated 287
# Number of fraud in the balanced dataset 46520/199008
# New synthetic data generated 290
# Number of fraud in the balanced dataset 46810/199008
# New synthetic data generated 290
# Number of fraud in the balanced dataset 47100/199008
# New synthetic data generated 291
# Number of fraud in the balanced dataset 47391/199008
# New synthetic data generated 293
# Number of fraud in the balanced dataset 47684/199008
# New synthetic data generated 293
# Number of fraud in the balanced dataset 47977/199008
# New synthetic data generated 293
# Number of fraud in the balanced dataset 48270/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 48564/199008
# New synthetic data generated 292
# Number of fraud in the balanced dataset 48856/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 49151/199008
# New synthetic data generated 292
# Number of fraud in the balanced dataset 49443/199008
# New synthetic data generated 292
# Number of fraud in the balanced dataset 49735/199008
# New synthetic data generated 293
# Number of fraud in the balanced dataset 50028/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 50323/199008
# New synthetic data generated 291
# Number of fraud in the balanced dataset 50614/199008
# New synthetic data generated 290
# Number of fraud in the balanced dataset 50904/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 51198/199008
# New synthetic data generated 289
# Number of fraud in the balanced dataset 51487/199008
# New synthetic data generated 292
# Number of fraud in the balanced dataset 51779/199008
# New synthetic data generated 290
# Number of fraud in the balanced dataset 52069/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 52363/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 52658/199008
# New synthetic data generated 291
# Number of fraud in the balanced dataset 52949/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 53244/199008
# New synthetic data generated 292
# Number of fraud in the balanced dataset 53536/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 53831/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 54126/199008
# New synthetic data generated 286
# Number of fraud in the balanced dataset 54412/199008
# New synthetic data generated 290
# Number of fraud in the balanced dataset 54702/199008
# New synthetic data generated 292
# Number of fraud in the balanced dataset 54994/199008
# New synthetic data generated 293
# Number of fraud in the balanced dataset 55287/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 55582/199008
# New synthetic data generated 293
# Number of fraud in the balanced dataset 55875/199008
# New synthetic data generated 290
# Number of fraud in the balanced dataset 56165/199008
# New synthetic data generated 293
# Number of fraud in the balanced dataset 56458/199008
# New synthetic data generated 289
# Number of fraud in the balanced dataset 56747/199008
# New synthetic data generated 289
# Number of fraud in the balanced dataset 57036/199008
# New synthetic data generated 288
# Number of fraud in the balanced dataset 57324/199008
# New synthetic data generated 287
# Number of fraud in the balanced dataset 57611/199008
# New synthetic data generated 289
# Number of fraud in the balanced dataset 57900/199008
# New synthetic data generated 289
# Number of fraud in the balanced dataset 58189/199008
# New synthetic data generated 292
# Number of fraud in the balanced dataset 58481/199008
# New synthetic data generated 292
# Number of fraud in the balanced dataset 58773/199008
# New synthetic data generated 293
# Number of fraud in the balanced dataset 59066/199008
# New synthetic data generated 288
# Number of fraud in the balanced dataset 59354/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 59649/199008
# New synthetic data generated 289
# Number of fraud in the balanced dataset 59938/199008
# New synthetic data generated 290
# Number of fraud in the balanced dataset 60228/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 60522/199008
# New synthetic data generated 292
# Number of fraud in the balanced dataset 60814/199008
# New synthetic data generated 286
# Number of fraud in the balanced dataset 61100/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 61395/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 61689/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 61984/199008
# New synthetic data generated 291
# Number of fraud in the balanced dataset 62275/199008
# New synthetic data generated 287
# Number of fraud in the balanced dataset 62562/199008
# New synthetic data generated 291
# Number of fraud in the balanced dataset 62853/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 63148/199008
# New synthetic data generated 292
# Number of fraud in the balanced dataset 63440/199008
# New synthetic data generated 291
# Number of fraud in the balanced dataset 63731/199008
# New synthetic data generated 292
# Number of fraud in the balanced dataset 64023/199008
# New synthetic data generated 290
# Number of fraud in the balanced dataset 64313/199008
# New synthetic data generated 293
# Number of fraud in the balanced dataset 64606/199008
# New synthetic data generated 293
# Number of fraud in the balanced dataset 64899/199008
# New synthetic data generated 293
# Number of fraud in the balanced dataset 65192/199008
# New synthetic data generated 285
# Number of fraud in the balanced dataset 65477/199008
# New synthetic data generated 293
# Number of fraud in the balanced dataset 65770/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 66064/199008
# New synthetic data generated 291
# Number of fraud in the balanced dataset 66355/199008
# New synthetic data generated 293
# Number of fraud in the balanced dataset 66648/199008
# New synthetic data generated 289
# Number of fraud in the balanced dataset 66937/199008
# New synthetic data generated 290
# Number of fraud in the balanced dataset 67227/199008
# New synthetic data generated 287
# Number of fraud in the balanced dataset 67514/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 67808/199008
# New synthetic data generated 288
# Number of fraud in the balanced dataset 68096/199008
# New synthetic data generated 292
# Number of fraud in the balanced dataset 68388/199008
# New synthetic data generated 296
# Number of fraud in the balanced dataset 68684/199008
# New synthetic data generated 292
# Number of fraud in the balanced dataset 68976/199008
# New synthetic data generated 289
# Number of fraud in the balanced dataset 69265/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 69560/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 69854/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 70149/199008
# New synthetic data generated 293
# Number of fraud in the balanced dataset 70442/199008
# New synthetic data generated 291
# Number of fraud in the balanced dataset 70733/199008
# New synthetic data generated 296
# Number of fraud in the balanced dataset 71029/199008
# New synthetic data generated 293
# Number of fraud in the balanced dataset 71322/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 71616/199008
# New synthetic data generated 289
# Number of fraud in the balanced dataset 71905/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 72200/199008
# New synthetic data generated 297
# Number of fraud in the balanced dataset 72497/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 72792/199008
# New synthetic data generated 289
# Number of fraud in the balanced dataset 73081/199008
# New synthetic data generated 292
# Number of fraud in the balanced dataset 73373/199008
# New synthetic data generated 291
# Number of fraud in the balanced dataset 73664/199008
# New synthetic data generated 296
# Number of fraud in the balanced dataset 73960/199008
# New synthetic data generated 293
# Number of fraud in the balanced dataset 74253/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 74548/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 74843/199008
# New synthetic data generated 292
# Number of fraud in the balanced dataset 75135/199008
# New synthetic data generated 287
# Number of fraud in the balanced dataset 75422/199008
# New synthetic data generated 288
# Number of fraud in the balanced dataset 75710/199008
# New synthetic data generated 290
# Number of fraud in the balanced dataset 76000/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 76294/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 76588/199008
# New synthetic data generated 292
# Number of fraud in the balanced dataset 76880/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 77175/199008
# New synthetic data generated 281
# Number of fraud in the balanced dataset 77456/199008
# New synthetic data generated 288
# Number of fraud in the balanced dataset 77744/199008
# New synthetic data generated 287
# Number of fraud in the balanced dataset 78031/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 78326/199008
# New synthetic data generated 292
# Number of fraud in the balanced dataset 78618/199008
# New synthetic data generated 287
# Number of fraud in the balanced dataset 78905/199008
# New synthetic data generated 288
# Number of fraud in the balanced dataset 79193/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 79487/199008
# New synthetic data generated 290
# Number of fraud in the balanced dataset 79777/199008
# New synthetic data generated 289
# Number of fraud in the balanced dataset 80066/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 80361/199008
# New synthetic data generated 297
# Number of fraud in the balanced dataset 80658/199008
# New synthetic data generated 289
# Number of fraud in the balanced dataset 80947/199008
# New synthetic data generated 291
# Number of fraud in the balanced dataset 81238/199008
# New synthetic data generated 293
# Number of fraud in the balanced dataset 81531/199008
# New synthetic data generated 292
# Number of fraud in the balanced dataset 81823/199008
# New synthetic data generated 293
# Number of fraud in the balanced dataset 82116/199008
# New synthetic data generated 291
# Number of fraud in the balanced dataset 82407/199008
# New synthetic data generated 291
# Number of fraud in the balanced dataset 82698/199008
# New synthetic data generated 286
# Number of fraud in the balanced dataset 82984/199008
# New synthetic data generated 296
# Number of fraud in the balanced dataset 83280/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 83574/199008
# New synthetic data generated 290
# Number of fraud in the balanced dataset 83864/199008
# New synthetic data generated 293
# Number of fraud in the balanced dataset 84157/199008
# New synthetic data generated 298
# Number of fraud in the balanced dataset 84455/199008
# New synthetic data generated 293
# Number of fraud in the balanced dataset 84748/199008
# New synthetic data generated 291
# Number of fraud in the balanced dataset 85039/199008
# New synthetic data generated 293
# Number of fraud in the balanced dataset 85332/199008
# New synthetic data generated 293
# Number of fraud in the balanced dataset 85625/199008
# New synthetic data generated 291
# Number of fraud in the balanced dataset 85916/199008
# New synthetic data generated 293
# Number of fraud in the balanced dataset 86209/199008
# New synthetic data generated 290
# Number of fraud in the balanced dataset 86499/199008
# New synthetic data generated 290
# Number of fraud in the balanced dataset 86789/199008
# New synthetic data generated 292
# Number of fraud in the balanced dataset 87081/199008
# New synthetic data generated 288
# Number of fraud in the balanced dataset 87369/199008
# New synthetic data generated 286
# Number of fraud in the balanced dataset 87655/199008
# New synthetic data generated 291
# Number of fraud in the balanced dataset 87946/199008
# New synthetic data generated 290
# Number of fraud in the balanced dataset 88236/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 88531/199008
# New synthetic data generated 289
# Number of fraud in the balanced dataset 88820/199008
# New synthetic data generated 296
# Number of fraud in the balanced dataset 89116/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 89410/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 89705/199008
# New synthetic data generated 292
# Number of fraud in the balanced dataset 89997/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 90292/199008
# New synthetic data generated 291
# Number of fraud in the balanced dataset 90583/199008
# New synthetic data generated 293
# Number of fraud in the balanced dataset 90876/199008
# New synthetic data generated 292
# Number of fraud in the balanced dataset 91168/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 91462/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 91756/199008
# New synthetic data generated 293
# Number of fraud in the balanced dataset 92049/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 92343/199008
# New synthetic data generated 291
# Number of fraud in the balanced dataset 92634/199008
# New synthetic data generated 290
# Number of fraud in the balanced dataset 92924/199008
# New synthetic data generated 293
# Number of fraud in the balanced dataset 93217/199008
# New synthetic data generated 292
# Number of fraud in the balanced dataset 93509/199008
# New synthetic data generated 292
# Number of fraud in the balanced dataset 93801/199008
# New synthetic data generated 293
# Number of fraud in the balanced dataset 94094/199008
# New synthetic data generated 298
# Number of fraud in the balanced dataset 94392/199008
# New synthetic data generated 292
# Number of fraud in the balanced dataset 94684/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 94978/199008
# New synthetic data generated 291
# Number of fraud in the balanced dataset 95269/199008
# New synthetic data generated 293
# Number of fraud in the balanced dataset 95562/199008
# New synthetic data generated 292
# Number of fraud in the balanced dataset 95854/199008
# New synthetic data generated 297
# Number of fraud in the balanced dataset 96151/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 96445/199008
# New synthetic data generated 291
# Number of fraud in the balanced dataset 96736/199008
# New synthetic data generated 288
# Number of fraud in the balanced dataset 97024/199008
# New synthetic data generated 291
# Number of fraud in the balanced dataset 97315/199008
# New synthetic data generated 291
# Number of fraud in the balanced dataset 97606/199008
# New synthetic data generated 299
# Number of fraud in the balanced dataset 97905/199008
# New synthetic data generated 291
# Number of fraud in the balanced dataset 98196/199008
# New synthetic data generated 291
# Number of fraud in the balanced dataset 98487/199008
# New synthetic data generated 291
# Number of fraud in the balanced dataset 98778/199008
# New synthetic data generated 284
# Number of fraud in the balanced dataset 99062/199008
# New synthetic data generated 291
# Number of fraud in the balanced dataset 99353/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 99647/199008
# New synthetic data generated 290
# Number of fraud in the balanced dataset 99937/199008
# New synthetic data generated 293
# Number of fraud in the balanced dataset 100230/199008
# New synthetic data generated 291
# Number of fraud in the balanced dataset 100521/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 100816/199008
# New synthetic data generated 292
# Number of fraud in the balanced dataset 101108/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 101402/199008
# New synthetic data generated 291
# Number of fraud in the balanced dataset 101693/199008
# New synthetic data generated 291
# Number of fraud in the balanced dataset 101984/199008
# New synthetic data generated 299
# Number of fraud in the balanced dataset 102283/199008
# New synthetic data generated 289
# Number of fraud in the balanced dataset 102572/199008
# New synthetic data generated 293
# Number of fraud in the balanced dataset 102865/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 103160/199008
# New synthetic data generated 292
# Number of fraud in the balanced dataset 103452/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 103747/199008
# New synthetic data generated 290
# Number of fraud in the balanced dataset 104037/199008
# New synthetic data generated 287
# Number of fraud in the balanced dataset 104324/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 104619/199008
# New synthetic data generated 293
# Number of fraud in the balanced dataset 104912/199008
# New synthetic data generated 288
# Number of fraud in the balanced dataset 105200/199008
# New synthetic data generated 296
# Number of fraud in the balanced dataset 105496/199008
# New synthetic data generated 288
# Number of fraud in the balanced dataset 105784/199008
# New synthetic data generated 291
# Number of fraud in the balanced dataset 106075/199008
# New synthetic data generated 293
# Number of fraud in the balanced dataset 106368/199008
# New synthetic data generated 293
# Number of fraud in the balanced dataset 106661/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 106956/199008
# New synthetic data generated 290
# Number of fraud in the balanced dataset 107246/199008
# New synthetic data generated 291
# Number of fraud in the balanced dataset 107537/199008
# New synthetic data generated 292
# Number of fraud in the balanced dataset 107829/199008
# New synthetic data generated 290
# Number of fraud in the balanced dataset 108119/199008
# New synthetic data generated 292
# Number of fraud in the balanced dataset 108411/199008
# New synthetic data generated 292
# Number of fraud in the balanced dataset 108703/199008
# New synthetic data generated 290
# Number of fraud in the balanced dataset 108993/199008
# New synthetic data generated 293
# Number of fraud in the balanced dataset 109286/199008
# New synthetic data generated 288
# Number of fraud in the balanced dataset 109574/199008
# New synthetic data generated 298
# Number of fraud in the balanced dataset 109872/199008
# New synthetic data generated 293
# Number of fraud in the balanced dataset 110165/199008
# New synthetic data generated 296
# Number of fraud in the balanced dataset 110461/199008
# New synthetic data generated 288
# Number of fraud in the balanced dataset 110749/199008
# New synthetic data generated 292
# Number of fraud in the balanced dataset 111041/199008
# New synthetic data generated 291
# Number of fraud in the balanced dataset 111332/199008
# New synthetic data generated 293
# Number of fraud in the balanced dataset 111625/199008
# New synthetic data generated 291
# Number of fraud in the balanced dataset 111916/199008
# New synthetic data generated 293
# Number of fraud in the balanced dataset 112209/199008
# New synthetic data generated 297
# Number of fraud in the balanced dataset 112506/199008
# New synthetic data generated 292
# Number of fraud in the balanced dataset 112798/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 113092/199008
# New synthetic data generated 292
# Number of fraud in the balanced dataset 113384/199008
# New synthetic data generated 291
# Number of fraud in the balanced dataset 113675/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 113969/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 114264/199008
# New synthetic data generated 298
# Number of fraud in the balanced dataset 114562/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 114856/199008
# New synthetic data generated 293
# Number of fraud in the balanced dataset 115149/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 115444/199008
# New synthetic data generated 290
# Number of fraud in the balanced dataset 115734/199008
# New synthetic data generated 291
# Number of fraud in the balanced dataset 116025/199008
# New synthetic data generated 287
# Number of fraud in the balanced dataset 116312/199008
# New synthetic data generated 293
# Number of fraud in the balanced dataset 116605/199008
# New synthetic data generated 289
# Number of fraud in the balanced dataset 116894/199008
# New synthetic data generated 291
# Number of fraud in the balanced dataset 117185/199008
# New synthetic data generated 291
# Number of fraud in the balanced dataset 117476/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 117770/199008
# New synthetic data generated 293
# Number of fraud in the balanced dataset 118063/199008
# New synthetic data generated 291
# Number of fraud in the balanced dataset 118354/199008
# New synthetic data generated 290
# Number of fraud in the balanced dataset 118644/199008
# New synthetic data generated 293
# Number of fraud in the balanced dataset 118937/199008
# New synthetic data generated 289
# Number of fraud in the balanced dataset 119226/199008
# New synthetic data generated 293
# Number of fraud in the balanced dataset 119519/199008
# New synthetic data generated 297
# Number of fraud in the balanced dataset 119816/199008
# New synthetic data generated 298
# Number of fraud in the balanced dataset 120114/199008
# New synthetic data generated 293
# Number of fraud in the balanced dataset 120407/199008
# New synthetic data generated 292
# Number of fraud in the balanced dataset 120699/199008
# New synthetic data generated 293
# Number of fraud in the balanced dataset 120992/199008
# New synthetic data generated 293
# Number of fraud in the balanced dataset 121285/199008
# New synthetic data generated 290
# Number of fraud in the balanced dataset 121575/199008
# New synthetic data generated 291
# Number of fraud in the balanced dataset 121866/199008
# New synthetic data generated 287
# Number of fraud in the balanced dataset 122153/199008
# New synthetic data generated 291
# Number of fraud in the balanced dataset 122444/199008
# New synthetic data generated 289
# Number of fraud in the balanced dataset 122733/199008
# New synthetic data generated 290
# Number of fraud in the balanced dataset 123023/199008
# New synthetic data generated 290
# Number of fraud in the balanced dataset 123313/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 123608/199008
# New synthetic data generated 291
# Number of fraud in the balanced dataset 123899/199008
# New synthetic data generated 287
# Number of fraud in the balanced dataset 124186/199008
# New synthetic data generated 293
# Number of fraud in the balanced dataset 124479/199008
# New synthetic data generated 293
# Number of fraud in the balanced dataset 124772/199008
# New synthetic data generated 292
# Number of fraud in the balanced dataset 125064/199008
# New synthetic data generated 291
# Number of fraud in the balanced dataset 125355/199008
# New synthetic data generated 290
# Number of fraud in the balanced dataset 125645/199008
# New synthetic data generated 289
# Number of fraud in the balanced dataset 125934/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 126229/199008
# New synthetic data generated 292
# Number of fraud in the balanced dataset 126521/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 126816/199008
# New synthetic data generated 291
# Number of fraud in the balanced dataset 127107/199008
# New synthetic data generated 289
# Number of fraud in the balanced dataset 127396/199008
# New synthetic data generated 293
# Number of fraud in the balanced dataset 127689/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 127984/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 128279/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 128573/199008
# New synthetic data generated 292
# Number of fraud in the balanced dataset 128865/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 129160/199008
# New synthetic data generated 290
# Number of fraud in the balanced dataset 129450/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 129745/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 130039/199008
# New synthetic data generated 292
# Number of fraud in the balanced dataset 130331/199008
# New synthetic data generated 297
# Number of fraud in the balanced dataset 130628/199008
# New synthetic data generated 289
# Number of fraud in the balanced dataset 130917/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 131211/199008
# New synthetic data generated 289
# Number of fraud in the balanced dataset 131500/199008
# New synthetic data generated 292
# Number of fraud in the balanced dataset 131792/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 132086/199008
# New synthetic data generated 293
# Number of fraud in the balanced dataset 132379/199008
# New synthetic data generated 289
# Number of fraud in the balanced dataset 132668/199008
# New synthetic data generated 292
# Number of fraud in the balanced dataset 132960/199008
# New synthetic data generated 296
# Number of fraud in the balanced dataset 133256/199008
# New synthetic data generated 296
# Number of fraud in the balanced dataset 133552/199008
# New synthetic data generated 292
# Number of fraud in the balanced dataset 133844/199008
# New synthetic data generated 290
# Number of fraud in the balanced dataset 134134/199008
# New synthetic data generated 293
# Number of fraud in the balanced dataset 134427/199008
# New synthetic data generated 293
# Number of fraud in the balanced dataset 134720/199008
# New synthetic data generated 293
# Number of fraud in the balanced dataset 135013/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 135308/199008
# New synthetic data generated 293
# Number of fraud in the balanced dataset 135601/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 135896/199008
# New synthetic data generated 291
# Number of fraud in the balanced dataset 136187/199008
# New synthetic data generated 292
# Number of fraud in the balanced dataset 136479/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 136773/199008
# New synthetic data generated 292
# Number of fraud in the balanced dataset 137065/199008
# New synthetic data generated 292
# Number of fraud in the balanced dataset 137357/199008
# New synthetic data generated 296
# Number of fraud in the balanced dataset 137653/199008
# New synthetic data generated 292
# Number of fraud in the balanced dataset 137945/199008
# New synthetic data generated 296
# Number of fraud in the balanced dataset 138241/199008
# New synthetic data generated 287
# Number of fraud in the balanced dataset 138528/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 138822/199008
# New synthetic data generated 292
# Number of fraud in the balanced dataset 139114/199008
# New synthetic data generated 290
# Number of fraud in the balanced dataset 139404/199008
# New synthetic data generated 292
# Number of fraud in the balanced dataset 139696/199008
# New synthetic data generated 290
# Number of fraud in the balanced dataset 139986/199008
# New synthetic data generated 291
# Number of fraud in the balanced dataset 140277/199008
# New synthetic data generated 289
# Number of fraud in the balanced dataset 140566/199008
# New synthetic data generated 293
# Number of fraud in the balanced dataset 140859/199008
# New synthetic data generated 290
# Number of fraud in the balanced dataset 141149/199008
# New synthetic data generated 293
# Number of fraud in the balanced dataset 141442/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 141736/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 142030/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 142324/199008
# New synthetic data generated 289
# Number of fraud in the balanced dataset 142613/199008
# New synthetic data generated 290
# Number of fraud in the balanced dataset 142903/199008
# New synthetic data generated 291
# Number of fraud in the balanced dataset 143194/199008
# New synthetic data generated 291
# Number of fraud in the balanced dataset 143485/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 143779/199008
# New synthetic data generated 287
# Number of fraud in the balanced dataset 144066/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 144361/199008
# New synthetic data generated 291
# Number of fraud in the balanced dataset 144652/199008
# New synthetic data generated 293
# Number of fraud in the balanced dataset 144945/199008
# New synthetic data generated 292
# Number of fraud in the balanced dataset 145237/199008
# New synthetic data generated 289
# Number of fraud in the balanced dataset 145526/199008
# New synthetic data generated 290
# Number of fraud in the balanced dataset 145816/199008
# New synthetic data generated 288
# Number of fraud in the balanced dataset 146104/199008
# New synthetic data generated 285
# Number of fraud in the balanced dataset 146389/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 146683/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 146978/199008
# New synthetic data generated 290
# Number of fraud in the balanced dataset 147268/199008
# New synthetic data generated 292
# Number of fraud in the balanced dataset 147560/199008
# New synthetic data generated 293
# Number of fraud in the balanced dataset 147853/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 148147/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 148441/199008
# New synthetic data generated 291
# Number of fraud in the balanced dataset 148732/199008
# New synthetic data generated 290
# Number of fraud in the balanced dataset 149022/199008
# New synthetic data generated 293
# Number of fraud in the balanced dataset 149315/199008
# New synthetic data generated 289
# Number of fraud in the balanced dataset 149604/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 149898/199008
# New synthetic data generated 291
# Number of fraud in the balanced dataset 150189/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 150484/199008
# New synthetic data generated 289
# Number of fraud in the balanced dataset 150773/199008
# New synthetic data generated 291
# Number of fraud in the balanced dataset 151064/199008
# New synthetic data generated 289
# Number of fraud in the balanced dataset 151353/199008
# New synthetic data generated 293
# Number of fraud in the balanced dataset 151646/199008
# New synthetic data generated 290
# Number of fraud in the balanced dataset 151936/199008
# New synthetic data generated 297
# Number of fraud in the balanced dataset 152233/199008
# New synthetic data generated 292
# Number of fraud in the balanced dataset 152525/199008
# New synthetic data generated 293
# Number of fraud in the balanced dataset 152818/199008
# New synthetic data generated 292
# Number of fraud in the balanced dataset 153110/199008
# New synthetic data generated 293
# Number of fraud in the balanced dataset 153403/199008
# New synthetic data generated 291
# Number of fraud in the balanced dataset 153694/199008
# New synthetic data generated 292
# Number of fraud in the balanced dataset 153986/199008
# New synthetic data generated 298
# Number of fraud in the balanced dataset 154284/199008
# New synthetic data generated 291
# Number of fraud in the balanced dataset 154575/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 154869/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 155164/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 155458/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 155752/199008
# New synthetic data generated 296
# Number of fraud in the balanced dataset 156048/199008
# New synthetic data generated 292
# Number of fraud in the balanced dataset 156340/199008
# New synthetic data generated 288
# Number of fraud in the balanced dataset 156628/199008
# New synthetic data generated 290
# Number of fraud in the balanced dataset 156918/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 157213/199008
# New synthetic data generated 291
# Number of fraud in the balanced dataset 157504/199008
# New synthetic data generated 296
# Number of fraud in the balanced dataset 157800/199008
# New synthetic data generated 298
# Number of fraud in the balanced dataset 158098/199008
# New synthetic data generated 291
# Number of fraud in the balanced dataset 158389/199008
# New synthetic data generated 292
# Number of fraud in the balanced dataset 158681/199008
# New synthetic data generated 290
# Number of fraud in the balanced dataset 158971/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 159265/199008
# New synthetic data generated 289
# Number of fraud in the balanced dataset 159554/199008
# New synthetic data generated 293
# Number of fraud in the balanced dataset 159847/199008
# New synthetic data generated 293
# Number of fraud in the balanced dataset 160140/199008
# New synthetic data generated 289
# Number of fraud in the balanced dataset 160429/199008
# New synthetic data generated 292
# Number of fraud in the balanced dataset 160721/199008
# New synthetic data generated 293
# Number of fraud in the balanced dataset 161014/199008
# New synthetic data generated 290
# Number of fraud in the balanced dataset 161304/199008
# New synthetic data generated 293
# Number of fraud in the balanced dataset 161597/199008
# New synthetic data generated 296
# Number of fraud in the balanced dataset 161893/199008
# New synthetic data generated 292
# Number of fraud in the balanced dataset 162185/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 162479/199008
# New synthetic data generated 292
# Number of fraud in the balanced dataset 162771/199008
# New synthetic data generated 292
# Number of fraud in the balanced dataset 163063/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 163357/199008
# New synthetic data generated 292
# Number of fraud in the balanced dataset 163649/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 163943/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 164237/199008
# New synthetic data generated 296
# Number of fraud in the balanced dataset 164533/199008
# New synthetic data generated 291
# Number of fraud in the balanced dataset 164824/199008
# New synthetic data generated 293
# Number of fraud in the balanced dataset 165117/199008
# New synthetic data generated 296
# Number of fraud in the balanced dataset 165413/199008
# New synthetic data generated 286
# Number of fraud in the balanced dataset 165699/199008
# New synthetic data generated 292
# Number of fraud in the balanced dataset 165991/199008
# New synthetic data generated 293
# Number of fraud in the balanced dataset 166284/199008
# New synthetic data generated 293
# Number of fraud in the balanced dataset 166577/199008
# New synthetic data generated 290
# Number of fraud in the balanced dataset 166867/199008
# New synthetic data generated 292
# Number of fraud in the balanced dataset 167159/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 167454/199008
# New synthetic data generated 293
# Number of fraud in the balanced dataset 167747/199008
# New synthetic data generated 291
# Number of fraud in the balanced dataset 168038/199008
# New synthetic data generated 293
# Number of fraud in the balanced dataset 168331/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 168625/199008
# New synthetic data generated 287
# Number of fraud in the balanced dataset 168912/199008
# New synthetic data generated 296
# Number of fraud in the balanced dataset 169208/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 169503/199008
# New synthetic data generated 293
# Number of fraud in the balanced dataset 169796/199008
# New synthetic data generated 298
# Number of fraud in the balanced dataset 170094/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 170388/199008
# New synthetic data generated 293
# Number of fraud in the balanced dataset 170681/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 170975/199008
# New synthetic data generated 292
# Number of fraud in the balanced dataset 171267/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 171562/199008
# New synthetic data generated 292
# Number of fraud in the balanced dataset 171854/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 172149/199008
# New synthetic data generated 292
# Number of fraud in the balanced dataset 172441/199008
# New synthetic data generated 293
# Number of fraud in the balanced dataset 172734/199008
# New synthetic data generated 298
# Number of fraud in the balanced dataset 173032/199008
# New synthetic data generated 293
# Number of fraud in the balanced dataset 173325/199008
# New synthetic data generated 291
# Number of fraud in the balanced dataset 173616/199008
# New synthetic data generated 293
# Number of fraud in the balanced dataset 173909/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 174203/199008
# New synthetic data generated 289
# Number of fraud in the balanced dataset 174492/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 174787/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 175081/199008
# New synthetic data generated 293
# Number of fraud in the balanced dataset 175374/199008
# New synthetic data generated 298
# Number of fraud in the balanced dataset 175672/199008
# New synthetic data generated 290
# Number of fraud in the balanced dataset 175962/199008
# New synthetic data generated 297
# Number of fraud in the balanced dataset 176259/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 176553/199008
# New synthetic data generated 296
# Number of fraud in the balanced dataset 176849/199008
# New synthetic data generated 292
# Number of fraud in the balanced dataset 177141/199008
# New synthetic data generated 293
# Number of fraud in the balanced dataset 177434/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 177729/199008
# New synthetic data generated 293
# Number of fraud in the balanced dataset 178022/199008
# New synthetic data generated 291
# Number of fraud in the balanced dataset 178313/199008
# New synthetic data generated 296
# Number of fraud in the balanced dataset 178609/199008
# New synthetic data generated 285
# Number of fraud in the balanced dataset 178894/199008
# New synthetic data generated 290
# Number of fraud in the balanced dataset 179184/199008
# New synthetic data generated 293
# Number of fraud in the balanced dataset 179477/199008
# New synthetic data generated 291
# Number of fraud in the balanced dataset 179768/199008
# New synthetic data generated 291
# Number of fraud in the balanced dataset 180059/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 180354/199008
# New synthetic data generated 297
# Number of fraud in the balanced dataset 180651/199008
# New synthetic data generated 292
# Number of fraud in the balanced dataset 180943/199008
# New synthetic data generated 290
# Number of fraud in the balanced dataset 181233/199008
# New synthetic data generated 289
# Number of fraud in the balanced dataset 181522/199008
# New synthetic data generated 293
# Number of fraud in the balanced dataset 181815/199008
# New synthetic data generated 286
# Number of fraud in the balanced dataset 182101/199008
# New synthetic data generated 289
# Number of fraud in the balanced dataset 182390/199008
# New synthetic data generated 291
# Number of fraud in the balanced dataset 182681/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 182975/199008
# New synthetic data generated 297
# Number of fraud in the balanced dataset 183272/199008
# New synthetic data generated 292
# Number of fraud in the balanced dataset 183564/199008
# New synthetic data generated 291
# Number of fraud in the balanced dataset 183855/199008
# New synthetic data generated 293
# Number of fraud in the balanced dataset 184148/199008
# New synthetic data generated 290
# Number of fraud in the balanced dataset 184438/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 184732/199008
# New synthetic data generated 297
# Number of fraud in the balanced dataset 185029/199008
# New synthetic data generated 291
# Number of fraud in the balanced dataset 185320/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 185614/199008
# New synthetic data generated 290
# Number of fraud in the balanced dataset 185904/199008
# New synthetic data generated 289
# Number of fraud in the balanced dataset 186193/199008
# New synthetic data generated 289
# Number of fraud in the balanced dataset 186482/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 186776/199008
# New synthetic data generated 290
# Number of fraud in the balanced dataset 187066/199008
# New synthetic data generated 288
# Number of fraud in the balanced dataset 187354/199008
# New synthetic data generated 293
# Number of fraud in the balanced dataset 187647/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 187942/199008
# New synthetic data generated 293
# Number of fraud in the balanced dataset 188235/199008
# New synthetic data generated 289
# Number of fraud in the balanced dataset 188524/199008
# New synthetic data generated 293
# Number of fraud in the balanced dataset 188817/199008
# New synthetic data generated 289
# Number of fraud in the balanced dataset 189106/199008
# New synthetic data generated 292
# Number of fraud in the balanced dataset 189398/199008
# New synthetic data generated 293
# Number of fraud in the balanced dataset 189691/199008
# New synthetic data generated 291
# Number of fraud in the balanced dataset 189982/199008
# New synthetic data generated 292
# Number of fraud in the balanced dataset 190274/199008
# New synthetic data generated 298
# Number of fraud in the balanced dataset 190572/199008
# New synthetic data generated 293
# Number of fraud in the balanced dataset 190865/199008
# New synthetic data generated 293
# Number of fraud in the balanced dataset 191158/199008
# New synthetic data generated 291
# Number of fraud in the balanced dataset 191449/199008
# New synthetic data generated 291
# Number of fraud in the balanced dataset 191740/199008
# New synthetic data generated 292
# Number of fraud in the balanced dataset 192032/199008
# New synthetic data generated 292
# Number of fraud in the balanced dataset 192324/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 192619/199008
# New synthetic data generated 290
# Number of fraud in the balanced dataset 192909/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 193203/199008
# New synthetic data generated 288
# Number of fraud in the balanced dataset 193491/199008
# New synthetic data generated 292
# Number of fraud in the balanced dataset 193783/199008
# New synthetic data generated 293
# Number of fraud in the balanced dataset 194076/199008
# New synthetic data generated 291
# Number of fraud in the balanced dataset 194367/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 194662/199008
# New synthetic data generated 296
# Number of fraud in the balanced dataset 194958/199008
# New synthetic data generated 287
# Number of fraud in the balanced dataset 195245/199008
# New synthetic data generated 289
# Number of fraud in the balanced dataset 195534/199008
# New synthetic data generated 292
# Number of fraud in the balanced dataset 195826/199008
# New synthetic data generated 298
# Number of fraud in the balanced dataset 196124/199008
# New synthetic data generated 291
# Number of fraud in the balanced dataset 196415/199008
# New synthetic data generated 293
# Number of fraud in the balanced dataset 196708/199008
# New synthetic data generated 292
# Number of fraud in the balanced dataset 197000/199008
# New synthetic data generated 292
# Number of fraud in the balanced dataset 197292/199008
# New synthetic data generated 296
# Number of fraud in the balanced dataset 197588/199008
# New synthetic data generated 290
# Number of fraud in the balanced dataset 197878/199008
# New synthetic data generated 293
# Number of fraud in the balanced dataset 198171/199008
# New synthetic data generated 292
# Number of fraud in the balanced dataset 198463/199008
# New synthetic data generated 287
# Number of fraud in the balanced dataset 198750/199008
# New synthetic data generated 289
# Number of fraud in the balanced dataset 199039/199008
# (398047, 31)
# Number of fraud in the balanced dataset 199039
# Number of non-fraud in the balanced dataset 199008

# %%
class Attention(nn.Module):
    def __init__(self, input_dim):
        super(Attention, self).__init__()
        self.attention_weights = nn.Linear(input_dim, 1, bias=False)  # Learnable attention weights

    def forward(self, lstm_output):
        # Compute attention scores (softmax over time dimension)
        attention_scores = torch.softmax(self.attention_weights(lstm_output), dim=1)  
        weighted_output = lstm_output * attention_scores  # Apply attention
        return torch.sum(weighted_output, dim=1)  # Sum over sequence length (time steps)

# %%
class ALSTM(nn.Module):
    def __init__(self, input_dim, hidden_dim):
        super(ALSTM, self).__init__()
        self.lstm = nn.LSTM(input_dim, hidden_dim, batch_first=True)  # Forward LSTM
        self.attention = Attention(hidden_dim)  # Attention Layer
        self.fc = nn.Linear(hidden_dim, 1)  # Fully connected output layer
        self.sigmoid = nn.Sigmoid()  # Sigmoid activation for binary classification

    def forward(self, x):
        lstm_output, _ = self.lstm(x)  # Get LSTM output
        attention_out = self.attention(lstm_output)  # Apply attention
        output = self.fc(attention_out)  # Fully connected layer
        return self.sigmoid(output)  # Sigmoid activation for probability output

# %%
# split data_train_oversampled in 20-80 split test-train
data_oversampled_labels = data_train_oversampled[:, -1]
data_train_oversampled = data_train_oversampled[:, :-1]
data_reshaped = data_train_oversampled.reshape(data_train_oversampled.shape[0], 1, data_train_oversampled.shape[1])

# Convert to PyTorch tensors
X_tensor = torch.tensor(data_reshaped, dtype=torch.float32)
y_tensor = torch.tensor(data_oversampled_labels, dtype=torch.float32)

# Split into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X_tensor, y_tensor, test_size=0.2, random_state=42)

# Create DataLoader for PyTorch
train_dataset = TensorDataset(X_train, y_train)
test_dataset = TensorDataset(X_test, y_test)

train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=32, shuffle=False)

# %%
input_dim = data_reshaped.shape[2]  # Number of features per transaction
hidden_dim = 128 # da cercare il valore migliore

# Initialize model, loss function, and optimizer
ALSTMmodel = ALSTM(input_dim, hidden_dim)
criterion = nn.BCELoss()  # Binary Cross Entropy for classification
optimizer = torch.optim.Adam(ALSTMmodel.parameters(), lr=0.001)

# Move model to GPU if available
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
ALSTMmodel.to(device)
# Out:
# ALSTM(
#   (lstm): LSTM(30, 128, batch_first=True)
#   (attention): Attention(
#     (attention_weights): Linear(in_features=128, out_features=1, bias=False)
#   )
#   (fc): Linear(in_features=128, out_features=1, bias=True)
#   (sigmoid): Sigmoid()
# )

# %%
def train_ALSTM(model, train_loader, residual):
    num_epochs = 10
    for epoch in range(num_epochs):
        model.train()
        epoch_loss = 0

        for X_batch, _ in train_loader:
            # transform residual in tensor
            residual = torch.tensor(residual, dtype=torch.float32)
            X_batch, residual = X_batch.to(device), residual.to(device)

            optimizer.zero_grad()  # Reset gradients
            y_pred = model(X_batch).squeeze()
        
            loss = criterion(y_pred, residual)  # Compute loss
            loss.backward()  # Backpropagation
            optimizer.step()  # Update weights

            epoch_loss += loss.item()
    
        print(f"Epoch [{epoch+1}/{num_epochs}], Loss: {epoch_loss:.4f}")
        
    return model

# %%
def loss(y, y_hat):
    return 1/2 * np.sum((y - y_hat)**2)

# %%
h_x = loss(data_oversampled_labels, 0)

for _ in range(6):

    residual = (data_oversampled_labels - h_x)
    ALSTMmodel = train_ALSTM(ALSTMmodel, train_loader, residual)
    y_pred = ALSTMmodel(train_loader).squeeze().detach().numpy()
    step_length = np.argmin(loss(data_oversampled_labels, h_x + step_length * y_pred))
    h_x += step_length * y_pred
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[13], line 6
#       3 for _ in range(6):
#       5     residual = (data_oversampled_labels - h_x)
# ----> 6     ALSTMmodel = train_ALSTM(ALSTMmodel, train_loader, residual)
#       7     y_pred = ALSTMmodel(train_loader).squeeze().detach().numpy()
#       8     step_length = np.argmin(loss(data_oversampled_labels, h_x + step_length * y_pred))
#
# Cell In[11], line 15, in train_ALSTM(model, train_loader, residual)
#      12 optimizer.zero_grad()  # Reset gradients
#      13 y_pred = model(X_batch).squeeze()
# ---> 15 loss = criterion(y_pred, residual)  # Compute loss
#      16 loss.backward()  # Backpropagation
#      17 optimizer.step()  # Update weights
#
# File ~/Desktop/pythonProject/.venv/lib/python3.10/site-packages/torch/nn/modules/module.py:1739, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1737     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738 else:
# -> 1739     return self._call_impl(*args, **kwargs)
#
# File ~/Desktop/pythonProject/.venv/lib/python3.10/site-packages/torch/nn/modules/module.py:1750, in Module._call_impl(self, *args, **kwargs)
#    1745 # If we don't have any hooks, we want to skip the rest of the logic in
#    1746 # this function, and just call forward.
#    1747 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1748         or _global_backward_pre_hooks or _global_backward_hooks
#    1749         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750     return forward_call(*args, **kwargs)
#    1752 result = None
#    1753 called_always_called_hooks = set()
#
# File ~/Desktop/pythonProject/.venv/lib/python3.10/site-packages/torch/nn/modules/loss.py:699, in BCELoss.forward(self, input, target)
#     698 def forward(self, input: Tensor, target: Tensor) -> Tensor:
# --> 699     return F.binary_cross_entropy(
#     700         input, target, weight=self.weight, reduction=self.reduction
#     701     )
#
# File ~/Desktop/pythonProject/.venv/lib/python3.10/site-packages/torch/nn/functional.py:3560, in binary_cross_entropy(input, target, weight, size_average, reduce, reduction)
#    3558     reduction_enum = _Reduction.get_enum(reduction)
#    3559 if target.size() != input.size():
# -> 3560     raise ValueError(
#    3561         f"Using a target size ({target.size()}) that is different to the input size ({input.size()}) is deprecated. "
#    3562         "Please ensure they have the same size."
#    3563     )
#    3565 if weight is not None:
#    3566     new_size = _infer_size(target.size(), weight.size())
#
# ValueError: Using a target size (torch.Size([398047])) that is different to the input size (torch.Size([32])) is deprecated. Please ensure they have the same size.

# %%
ALSTMmodel.eval()  # Set model to evaluation mode

correct = 0
total = 0

with torch.no_grad():  # No gradients needed for evaluation
    for X_batch, y_batch in test_loader:
        X_batch, y_batch = X_batch.to(device), y_batch.to(device)
        y_pred = ALSTMmodel(X_batch).squeeze()
        y_pred_labels = (y_pred > 0.5).float()  # Convert probabilities to binary labels
        
        correct += (y_pred_labels == y_batch).sum().item()
        total += y_batch.size(0)

accuracy = correct / total
print(f"Test Accuracy: {accuracy:.4f}")
