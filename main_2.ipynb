# %%
import numpy as np
import pandas as pd
import torch
import torch.nn as nn
from sklearn.preprocessing import RobustScaler
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
import jax.numpy as jnp
from torch.utils.data import DataLoader, TensorDataset

data = pd.read_csv('creditcard.csv')

dataset = data.to_numpy().astype(np.float32)  # Ensure data is float32 for PyTorch

scaler = RobustScaler(with_centering=True, with_scaling=True, quantile_range=(25.0, 75.0), unit_variance=False)
dataset[:, [0, 29]] = scaler.fit_transform(dataset[:, [0, 29]])

# %%
data_train, data_test = train_test_split(dataset, test_size=0.3, random_state=42)

# %%
# -----------------------------
# 3. Define the Autoencoder Model
# -----------------------------
class Autoencoder(nn.Module):
    def __init__(self):
        super(Autoencoder, self).__init__()
        # Encoder: 31 -> 23 -> 19 -> 17 -> 8 with dropout after first two hidden layers
        self.encoder = nn.Sequential(
            nn.Linear(31, 23),
            nn.Tanh(),
            nn.Dropout(0.1),
            nn.Linear(23, 19),
            nn.Tanh(),
            nn.Dropout(0.2),
            nn.Linear(19, 17),
            nn.Tanh(),
            nn.Linear(17, 8)
        )
        # Decoder: 8 -> 17 -> 19 -> 23 -> 31 with dropout after first two layers
        self.decoder = nn.Sequential(
            nn.Linear(8, 17),
            nn.Tanh(),
            nn.Dropout(0.2),
            nn.Linear(17, 19),
            nn.Tanh(),
            nn.Dropout(0.1),
            nn.Linear(19, 23),
            nn.Tanh(),
            nn.Linear(23, 31)
        )

    def forward(self, x):
        latent = self.encoder(x)
        reconstructed = self.decoder(latent)
        return reconstructed

# %%
fraud_data = data_train[data_train[:, -1] == 1]
non_fraud_data = data_train[data_train[:, -1] == 0]

legit_data_limited = non_fraud_data[np.random.choice(non_fraud_data.shape[0], fraud_data.shape[0], replace=False)]

train_dataset_SVM = np.vstack((legit_data_limited, fraud_data))
np.random.shuffle(train_dataset_SVM)
train_labels_SVM = train_dataset_SVM[:, -1]
train_dataset_SVM = train_dataset_SVM[:, :-1]

data_train_SVM, data_test_SVM, labels_train_SVM, labels_test_SVM = train_test_split(train_dataset_SVM, train_labels_SVM, test_size=0.2, random_state=42)
model = SVC(kernel='linear', C=1.0)
model.fit(data_train_SVM, labels_train_SVM)

labels_pred_test = model.predict(data_test_SVM)
labels_pred_train = model.predict(data_train_SVM)
accuracy_train = jnp.mean(labels_pred_train == labels_train_SVM)
accuracy_test = jnp.mean(labels_pred_test == labels_test_SVM)

print(f"Train Accuracy: {accuracy_train:.4f}")
print(f"Test Accuracy: {accuracy_test:.4f}")
# Out:
# Train Accuracy: 0.9473
# Test Accuracy: 0.9580

# %%
# load the model 
myModel = Autoencoder()

# Load the saved state dictionary
myModel.load_state_dict(torch.load("model/autoencoder/autoencoder.pth", map_location=torch.device('cpu'), weights_only=True))
myModel.eval()

alpha = 0.9

data_train_oversampled = data_train.copy()

while (len(data_train_oversampled[data_train_oversampled[:, -1] == 1]) < len(data_train_oversampled[data_train_oversampled[:, -1] == 0])):
    fraud_data = data_train_oversampled[data_train_oversampled[:, -1] == 1]

    # 2) Generate synthetic data by interpolating between fraud data points
    fraud_data_tensor = torch.tensor(fraud_data, dtype=torch.float32)

    latent_representations = myModel.encoder(fraud_data_tensor)

    noisy_vectors = []
    for _ in range(300):
        # Pick a random fraud vector
        i = np.random.randint(0, 300)
        z_i = latent_representations[i]

        # Optionally pick a second random vector to interpolate
        j = np.random.randint(0, 300)
        z_j = latent_representations[j]
        
        # Interpolation factor
        lambda_ = np.random.rand()
        z_ij = lambda_*z_i + (1 - lambda_)*z_j
        
        # Add Gaussian noise around that interpolation
        noise = torch.normal(mean=0.0, std=alpha, size=(8,))
        z_syn = z_ij + noise  # Both are tensors, so this should work directly

        noisy_vectors.append(z_syn.detach().numpy())

    noisy_vectors = np.array(noisy_vectors)

    # 3) Decode them to get synthetic data in original input space
    X_synthetic = myModel.decoder(torch.tensor(noisy_vectors, dtype=torch.float32)).detach().numpy()
    # remove label
    X_synthetic_to_predict = X_synthetic[:, :-1]
    # 4) Validate with SVM
    y_pred = model.predict(X_synthetic_to_predict)

    X_synthetic[:, -1] = y_pred

    # 5) Add the synthetic data to the training set
    X_synthetic_fraud = X_synthetic[X_synthetic[:, -1] == 1]

    data_train_oversampled = np.vstack((data_train_oversampled, X_synthetic_fraud))

    print("New synthetic data generated", len(X_synthetic_fraud))
    print(f"Number of fraud in the balanced dataset {len(data_train_oversampled[data_train_oversampled[:, -1] == 1])}/{len(data_train_oversampled[data_train_oversampled[:, -1] == 0])}")

# for i in range(len(data_train_oversampled[data_train_oversampled[:, -1] == 1]) - len(data_train_oversampled[data_train_oversampled[:, -1] == 0])):
#     noisy_vectors = []
#     for _ in range(n):
#         # Pick a random fraud vector
#         i = np.random.randint(0, n)
#         z_i = latent_representations[i]

#         # Optionally pick a second random vector to interpolate
#         j = np.random.randint(0, n)
#         z_j = latent_representations[j]
        
#         # Interpolation factor
#         lambda_ = np.random.rand()
#         z_ij = lambda_*z_i + (1 - lambda_)*z_j
        
#         # Add Gaussian noise around that interpolation
#         noise = torch.normal(mean=0.0, std=alpha, size=(latent_dim,))
#         z_syn = z_ij + noise  # Both are tensors, so this should work directly

#         noisy_vectors.append(z_syn.detach().numpy())

#     noisy_vectors = np.array(noisy_vectors)

#     # 3) Decode them to get synthetic data in original input space
#     X_synthetic = myModel.decoder(torch.tensor(noisy_vectors, dtype=torch.float32)).detach().numpy()
#     # remove label
#     X_synthetic_to_predict = X_synthetic[:, :-1]
#     # 4) Validate with SVM
#     y_pred = model.predict(X_synthetic_to_predict)

#     X_synthetic[:, -1] = y_pred

#     # 5) Add the synthetic data to the training set
#     X_synthetic_fraud = X_synthetic[X_synthetic[:, -1] == 1]

#     data_train_oversampled = np.vstack((data_train_oversampled, X_synthetic_fraud))

print(data_train_oversampled.shape)
print("Number of fraud in the balanced dataset", len(data_train_oversampled[data_train_oversampled[:, -1] == 1]))
print("Number of non-fraud in the balanced dataset", len(data_train_oversampled[data_train_oversampled[:, -1] == 0]))
# Out:
# New synthetic data generated 293
# Number of fraud in the balanced dataset 649/199008
# New synthetic data generated 291
# Number of fraud in the balanced dataset 940/199008
# New synthetic data generated 292
# Number of fraud in the balanced dataset 1232/199008
# New synthetic data generated 291
# Number of fraud in the balanced dataset 1523/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 1817/199008
# New synthetic data generated 297
# Number of fraud in the balanced dataset 2114/199008
# New synthetic data generated 290
# Number of fraud in the balanced dataset 2404/199008
# New synthetic data generated 293
# Number of fraud in the balanced dataset 2697/199008
# New synthetic data generated 293
# Number of fraud in the balanced dataset 2990/199008
# New synthetic data generated 289
# Number of fraud in the balanced dataset 3279/199008
# New synthetic data generated 290
# Number of fraud in the balanced dataset 3569/199008
# New synthetic data generated 290
# Number of fraud in the balanced dataset 3859/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 4153/199008
# New synthetic data generated 292
# Number of fraud in the balanced dataset 4445/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 4739/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 5034/199008
# New synthetic data generated 291
# Number of fraud in the balanced dataset 5325/199008
# New synthetic data generated 289
# Number of fraud in the balanced dataset 5614/199008
# New synthetic data generated 297
# Number of fraud in the balanced dataset 5911/199008
# New synthetic data generated 290
# Number of fraud in the balanced dataset 6201/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 6496/199008
# New synthetic data generated 293
# Number of fraud in the balanced dataset 6789/199008
# New synthetic data generated 281
# Number of fraud in the balanced dataset 7070/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 7364/199008
# New synthetic data generated 288
# Number of fraud in the balanced dataset 7652/199008
# New synthetic data generated 292
# Number of fraud in the balanced dataset 7944/199008
# New synthetic data generated 289
# Number of fraud in the balanced dataset 8233/199008
# New synthetic data generated 293
# Number of fraud in the balanced dataset 8526/199008
# New synthetic data generated 288
# Number of fraud in the balanced dataset 8814/199008
# New synthetic data generated 293
# Number of fraud in the balanced dataset 9107/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 9401/199008
# New synthetic data generated 293
# Number of fraud in the balanced dataset 9694/199008
# New synthetic data generated 292
# Number of fraud in the balanced dataset 9986/199008
# New synthetic data generated 289
# Number of fraud in the balanced dataset 10275/199008
# New synthetic data generated 293
# Number of fraud in the balanced dataset 10568/199008
# New synthetic data generated 292
# Number of fraud in the balanced dataset 10860/199008
# New synthetic data generated 290
# Number of fraud in the balanced dataset 11150/199008
# New synthetic data generated 290
# Number of fraud in the balanced dataset 11440/199008
# New synthetic data generated 292
# Number of fraud in the balanced dataset 11732/199008
# New synthetic data generated 296
# Number of fraud in the balanced dataset 12028/199008
# New synthetic data generated 291
# Number of fraud in the balanced dataset 12319/199008
# New synthetic data generated 288
# Number of fraud in the balanced dataset 12607/199008
# New synthetic data generated 291
# Number of fraud in the balanced dataset 12898/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 13192/199008
# New synthetic data generated 290
# Number of fraud in the balanced dataset 13482/199008
# New synthetic data generated 292
# Number of fraud in the balanced dataset 13774/199008
# New synthetic data generated 290
# Number of fraud in the balanced dataset 14064/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 14358/199008
# New synthetic data generated 289
# Number of fraud in the balanced dataset 14647/199008
# New synthetic data generated 287
# Number of fraud in the balanced dataset 14934/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 15228/199008
# New synthetic data generated 296
# Number of fraud in the balanced dataset 15524/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 15818/199008
# New synthetic data generated 286
# Number of fraud in the balanced dataset 16104/199008
# New synthetic data generated 291
# Number of fraud in the balanced dataset 16395/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 16689/199008
# New synthetic data generated 289
# Number of fraud in the balanced dataset 16978/199008
# New synthetic data generated 290
# Number of fraud in the balanced dataset 17268/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 17563/199008
# New synthetic data generated 292
# Number of fraud in the balanced dataset 17855/199008
# New synthetic data generated 289
# Number of fraud in the balanced dataset 18144/199008
# New synthetic data generated 290
# Number of fraud in the balanced dataset 18434/199008
# New synthetic data generated 296
# Number of fraud in the balanced dataset 18730/199008
# New synthetic data generated 285
# Number of fraud in the balanced dataset 19015/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 19310/199008
# New synthetic data generated 288
# Number of fraud in the balanced dataset 19598/199008
# New synthetic data generated 290
# Number of fraud in the balanced dataset 19888/199008
# New synthetic data generated 292
# Number of fraud in the balanced dataset 20180/199008
# New synthetic data generated 291
# Number of fraud in the balanced dataset 20471/199008
# New synthetic data generated 290
# Number of fraud in the balanced dataset 20761/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 21055/199008
# New synthetic data generated 298
# Number of fraud in the balanced dataset 21353/199008
# New synthetic data generated 287
# Number of fraud in the balanced dataset 21640/199008
# New synthetic data generated 290
# Number of fraud in the balanced dataset 21930/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 22224/199008
# New synthetic data generated 291
# Number of fraud in the balanced dataset 22515/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 22810/199008
# New synthetic data generated 288
# Number of fraud in the balanced dataset 23098/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 23392/199008
# New synthetic data generated 290
# Number of fraud in the balanced dataset 23682/199008
# New synthetic data generated 296
# Number of fraud in the balanced dataset 23978/199008
# New synthetic data generated 290
# Number of fraud in the balanced dataset 24268/199008
# New synthetic data generated 290
# Number of fraud in the balanced dataset 24558/199008
# New synthetic data generated 290
# Number of fraud in the balanced dataset 24848/199008
# New synthetic data generated 292
# Number of fraud in the balanced dataset 25140/199008
# New synthetic data generated 292
# Number of fraud in the balanced dataset 25432/199008
# New synthetic data generated 287
# Number of fraud in the balanced dataset 25719/199008
# New synthetic data generated 290
# Number of fraud in the balanced dataset 26009/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 26303/199008
# New synthetic data generated 292
# Number of fraud in the balanced dataset 26595/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 26889/199008
# New synthetic data generated 287
# Number of fraud in the balanced dataset 27176/199008
# New synthetic data generated 290
# Number of fraud in the balanced dataset 27466/199008
# New synthetic data generated 291
# Number of fraud in the balanced dataset 27757/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 28052/199008
# New synthetic data generated 291
# Number of fraud in the balanced dataset 28343/199008
# New synthetic data generated 293
# Number of fraud in the balanced dataset 28636/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 28930/199008
# New synthetic data generated 293
# Number of fraud in the balanced dataset 29223/199008
# New synthetic data generated 287
# Number of fraud in the balanced dataset 29510/199008
# New synthetic data generated 289
# Number of fraud in the balanced dataset 29799/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 30093/199008
# New synthetic data generated 291
# Number of fraud in the balanced dataset 30384/199008
# New synthetic data generated 290
# Number of fraud in the balanced dataset 30674/199008
# New synthetic data generated 293
# Number of fraud in the balanced dataset 30967/199008
# New synthetic data generated 289
# Number of fraud in the balanced dataset 31256/199008
# New synthetic data generated 286
# Number of fraud in the balanced dataset 31542/199008
# New synthetic data generated 293
# Number of fraud in the balanced dataset 31835/199008
# New synthetic data generated 290
# Number of fraud in the balanced dataset 32125/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 32420/199008
# New synthetic data generated 289
# Number of fraud in the balanced dataset 32709/199008
# New synthetic data generated 291
# Number of fraud in the balanced dataset 33000/199008
# New synthetic data generated 290
# Number of fraud in the balanced dataset 33290/199008
# New synthetic data generated 292
# Number of fraud in the balanced dataset 33582/199008
# New synthetic data generated 292
# Number of fraud in the balanced dataset 33874/199008
# New synthetic data generated 296
# Number of fraud in the balanced dataset 34170/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 34465/199008
# New synthetic data generated 290
# Number of fraud in the balanced dataset 34755/199008
# New synthetic data generated 288
# Number of fraud in the balanced dataset 35043/199008
# New synthetic data generated 291
# Number of fraud in the balanced dataset 35334/199008
# New synthetic data generated 286
# Number of fraud in the balanced dataset 35620/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 35915/199008
# New synthetic data generated 289
# Number of fraud in the balanced dataset 36204/199008
# New synthetic data generated 293
# Number of fraud in the balanced dataset 36497/199008
# New synthetic data generated 293
# Number of fraud in the balanced dataset 36790/199008
# New synthetic data generated 287
# Number of fraud in the balanced dataset 37077/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 37371/199008
# New synthetic data generated 298
# Number of fraud in the balanced dataset 37669/199008
# New synthetic data generated 293
# Number of fraud in the balanced dataset 37962/199008
# New synthetic data generated 289
# Number of fraud in the balanced dataset 38251/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 38546/199008
# New synthetic data generated 291
# Number of fraud in the balanced dataset 38837/199008
# New synthetic data generated 291
# Number of fraud in the balanced dataset 39128/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 39422/199008
# New synthetic data generated 291
# Number of fraud in the balanced dataset 39713/199008
# New synthetic data generated 296
# Number of fraud in the balanced dataset 40009/199008
# New synthetic data generated 289
# Number of fraud in the balanced dataset 40298/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 40592/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 40887/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 41182/199008
# New synthetic data generated 289
# Number of fraud in the balanced dataset 41471/199008
# New synthetic data generated 291
# Number of fraud in the balanced dataset 41762/199008
# New synthetic data generated 292
# Number of fraud in the balanced dataset 42054/199008
# New synthetic data generated 290
# Number of fraud in the balanced dataset 42344/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 42638/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 42932/199008
# New synthetic data generated 288
# Number of fraud in the balanced dataset 43220/199008
# New synthetic data generated 298
# Number of fraud in the balanced dataset 43518/199008
# New synthetic data generated 288
# Number of fraud in the balanced dataset 43806/199008
# New synthetic data generated 296
# Number of fraud in the balanced dataset 44102/199008
# New synthetic data generated 293
# Number of fraud in the balanced dataset 44395/199008
# New synthetic data generated 287
# Number of fraud in the balanced dataset 44682/199008
# New synthetic data generated 289
# Number of fraud in the balanced dataset 44971/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 45265/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 45559/199008
# New synthetic data generated 289
# Number of fraud in the balanced dataset 45848/199008
# New synthetic data generated 291
# Number of fraud in the balanced dataset 46139/199008
# New synthetic data generated 288
# Number of fraud in the balanced dataset 46427/199008
# New synthetic data generated 289
# Number of fraud in the balanced dataset 46716/199008
# New synthetic data generated 290
# Number of fraud in the balanced dataset 47006/199008
# New synthetic data generated 293
# Number of fraud in the balanced dataset 47299/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 47594/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 47889/199008
# New synthetic data generated 291
# Number of fraud in the balanced dataset 48180/199008
# New synthetic data generated 285
# Number of fraud in the balanced dataset 48465/199008
# New synthetic data generated 288
# Number of fraud in the balanced dataset 48753/199008
# New synthetic data generated 289
# Number of fraud in the balanced dataset 49042/199008
# New synthetic data generated 292
# Number of fraud in the balanced dataset 49334/199008
# New synthetic data generated 291
# Number of fraud in the balanced dataset 49625/199008
# New synthetic data generated 297
# Number of fraud in the balanced dataset 49922/199008
# New synthetic data generated 288
# Number of fraud in the balanced dataset 50210/199008
# New synthetic data generated 285
# Number of fraud in the balanced dataset 50495/199008
# New synthetic data generated 289
# Number of fraud in the balanced dataset 50784/199008
# New synthetic data generated 289
# Number of fraud in the balanced dataset 51073/199008
# New synthetic data generated 290
# Number of fraud in the balanced dataset 51363/199008
# New synthetic data generated 293
# Number of fraud in the balanced dataset 51656/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 51950/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 52245/199008
# New synthetic data generated 292
# Number of fraud in the balanced dataset 52537/199008
# New synthetic data generated 290
# Number of fraud in the balanced dataset 52827/199008
# New synthetic data generated 291
# Number of fraud in the balanced dataset 53118/199008
# New synthetic data generated 297
# Number of fraud in the balanced dataset 53415/199008
# New synthetic data generated 291
# Number of fraud in the balanced dataset 53706/199008
# New synthetic data generated 291
# Number of fraud in the balanced dataset 53997/199008
# New synthetic data generated 290
# Number of fraud in the balanced dataset 54287/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 54581/199008
# New synthetic data generated 290
# Number of fraud in the balanced dataset 54871/199008
# New synthetic data generated 288
# Number of fraud in the balanced dataset 55159/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 55454/199008
# New synthetic data generated 292
# Number of fraud in the balanced dataset 55746/199008
# New synthetic data generated 297
# Number of fraud in the balanced dataset 56043/199008
# New synthetic data generated 291
# Number of fraud in the balanced dataset 56334/199008
# New synthetic data generated 290
# Number of fraud in the balanced dataset 56624/199008
# New synthetic data generated 291
# Number of fraud in the balanced dataset 56915/199008
# New synthetic data generated 292
# Number of fraud in the balanced dataset 57207/199008
# New synthetic data generated 289
# Number of fraud in the balanced dataset 57496/199008
# New synthetic data generated 296
# Number of fraud in the balanced dataset 57792/199008
# New synthetic data generated 293
# Number of fraud in the balanced dataset 58085/199008
# New synthetic data generated 293
# Number of fraud in the balanced dataset 58378/199008
# New synthetic data generated 289
# Number of fraud in the balanced dataset 58667/199008
# New synthetic data generated 286
# Number of fraud in the balanced dataset 58953/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 59247/199008
# New synthetic data generated 286
# Number of fraud in the balanced dataset 59533/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 59828/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 60123/199008
# New synthetic data generated 288
# Number of fraud in the balanced dataset 60411/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 60705/199008
# New synthetic data generated 290
# Number of fraud in the balanced dataset 60995/199008
# New synthetic data generated 287
# Number of fraud in the balanced dataset 61282/199008
# New synthetic data generated 291
# Number of fraud in the balanced dataset 61573/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 61868/199008
# New synthetic data generated 291
# Number of fraud in the balanced dataset 62159/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 62454/199008
# New synthetic data generated 296
# Number of fraud in the balanced dataset 62750/199008
# New synthetic data generated 292
# Number of fraud in the balanced dataset 63042/199008
# New synthetic data generated 293
# Number of fraud in the balanced dataset 63335/199008
# New synthetic data generated 290
# Number of fraud in the balanced dataset 63625/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 63919/199008
# New synthetic data generated 289
# Number of fraud in the balanced dataset 64208/199008
# New synthetic data generated 291
# Number of fraud in the balanced dataset 64499/199008
# New synthetic data generated 290
# Number of fraud in the balanced dataset 64789/199008
# New synthetic data generated 285
# Number of fraud in the balanced dataset 65074/199008
# New synthetic data generated 286
# Number of fraud in the balanced dataset 65360/199008
# New synthetic data generated 293
# Number of fraud in the balanced dataset 65653/199008
# New synthetic data generated 292
# Number of fraud in the balanced dataset 65945/199008
# New synthetic data generated 290
# Number of fraud in the balanced dataset 66235/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 66529/199008
# New synthetic data generated 289
# Number of fraud in the balanced dataset 66818/199008
# New synthetic data generated 293
# Number of fraud in the balanced dataset 67111/199008
# New synthetic data generated 291
# Number of fraud in the balanced dataset 67402/199008
# New synthetic data generated 289
# Number of fraud in the balanced dataset 67691/199008
# New synthetic data generated 299
# Number of fraud in the balanced dataset 67990/199008
# New synthetic data generated 297
# Number of fraud in the balanced dataset 68287/199008
# New synthetic data generated 291
# Number of fraud in the balanced dataset 68578/199008
# New synthetic data generated 296
# Number of fraud in the balanced dataset 68874/199008
# New synthetic data generated 289
# Number of fraud in the balanced dataset 69163/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 69457/199008
# New synthetic data generated 293
# Number of fraud in the balanced dataset 69750/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 70044/199008
# New synthetic data generated 293
# Number of fraud in the balanced dataset 70337/199008
# New synthetic data generated 287
# Number of fraud in the balanced dataset 70624/199008
# New synthetic data generated 291
# Number of fraud in the balanced dataset 70915/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 71209/199008
# New synthetic data generated 292
# Number of fraud in the balanced dataset 71501/199008
# New synthetic data generated 290
# Number of fraud in the balanced dataset 71791/199008
# New synthetic data generated 293
# Number of fraud in the balanced dataset 72084/199008
# New synthetic data generated 297
# Number of fraud in the balanced dataset 72381/199008
# New synthetic data generated 289
# Number of fraud in the balanced dataset 72670/199008
# New synthetic data generated 293
# Number of fraud in the balanced dataset 72963/199008
# New synthetic data generated 290
# Number of fraud in the balanced dataset 73253/199008
# New synthetic data generated 292
# Number of fraud in the balanced dataset 73545/199008
# New synthetic data generated 291
# Number of fraud in the balanced dataset 73836/199008
# New synthetic data generated 292
# Number of fraud in the balanced dataset 74128/199008
# New synthetic data generated 286
# Number of fraud in the balanced dataset 74414/199008
# New synthetic data generated 288
# Number of fraud in the balanced dataset 74702/199008
# New synthetic data generated 290
# Number of fraud in the balanced dataset 74992/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 75287/199008
# New synthetic data generated 291
# Number of fraud in the balanced dataset 75578/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 75872/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 76167/199008
# New synthetic data generated 290
# Number of fraud in the balanced dataset 76457/199008
# New synthetic data generated 293
# Number of fraud in the balanced dataset 76750/199008
# New synthetic data generated 291
# Number of fraud in the balanced dataset 77041/199008
# New synthetic data generated 291
# Number of fraud in the balanced dataset 77332/199008
# New synthetic data generated 288
# Number of fraud in the balanced dataset 77620/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 77914/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 78208/199008
# New synthetic data generated 288
# Number of fraud in the balanced dataset 78496/199008
# New synthetic data generated 293
# Number of fraud in the balanced dataset 78789/199008
# New synthetic data generated 289
# Number of fraud in the balanced dataset 79078/199008
# New synthetic data generated 292
# Number of fraud in the balanced dataset 79370/199008
# New synthetic data generated 286
# Number of fraud in the balanced dataset 79656/199008
# New synthetic data generated 292
# Number of fraud in the balanced dataset 79948/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 80242/199008
# New synthetic data generated 289
# Number of fraud in the balanced dataset 80531/199008
# New synthetic data generated 288
# Number of fraud in the balanced dataset 80819/199008
# New synthetic data generated 292
# Number of fraud in the balanced dataset 81111/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 81405/199008
# New synthetic data generated 290
# Number of fraud in the balanced dataset 81695/199008
# New synthetic data generated 291
# Number of fraud in the balanced dataset 81986/199008
# New synthetic data generated 290
# Number of fraud in the balanced dataset 82276/199008
# New synthetic data generated 289
# Number of fraud in the balanced dataset 82565/199008
# New synthetic data generated 286
# Number of fraud in the balanced dataset 82851/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 83145/199008
# New synthetic data generated 290
# Number of fraud in the balanced dataset 83435/199008
# New synthetic data generated 293
# Number of fraud in the balanced dataset 83728/199008
# New synthetic data generated 292
# Number of fraud in the balanced dataset 84020/199008
# New synthetic data generated 298
# Number of fraud in the balanced dataset 84318/199008
# New synthetic data generated 292
# Number of fraud in the balanced dataset 84610/199008
# New synthetic data generated 291
# Number of fraud in the balanced dataset 84901/199008
# New synthetic data generated 289
# Number of fraud in the balanced dataset 85190/199008
# New synthetic data generated 287
# Number of fraud in the balanced dataset 85477/199008
# New synthetic data generated 290
# Number of fraud in the balanced dataset 85767/199008
# New synthetic data generated 293
# Number of fraud in the balanced dataset 86060/199008
# New synthetic data generated 292
# Number of fraud in the balanced dataset 86352/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 86647/199008
# New synthetic data generated 292
# Number of fraud in the balanced dataset 86939/199008
# New synthetic data generated 291
# Number of fraud in the balanced dataset 87230/199008
# New synthetic data generated 290
# Number of fraud in the balanced dataset 87520/199008
# New synthetic data generated 293
# Number of fraud in the balanced dataset 87813/199008
# New synthetic data generated 290
# Number of fraud in the balanced dataset 88103/199008
# New synthetic data generated 292
# Number of fraud in the balanced dataset 88395/199008
# New synthetic data generated 288
# Number of fraud in the balanced dataset 88683/199008
# New synthetic data generated 291
# Number of fraud in the balanced dataset 88974/199008
# New synthetic data generated 291
# Number of fraud in the balanced dataset 89265/199008
# New synthetic data generated 291
# Number of fraud in the balanced dataset 89556/199008
# New synthetic data generated 290
# Number of fraud in the balanced dataset 89846/199008
# New synthetic data generated 292
# Number of fraud in the balanced dataset 90138/199008
# New synthetic data generated 289
# Number of fraud in the balanced dataset 90427/199008
# New synthetic data generated 293
# Number of fraud in the balanced dataset 90720/199008
# New synthetic data generated 288
# Number of fraud in the balanced dataset 91008/199008
# New synthetic data generated 289
# Number of fraud in the balanced dataset 91297/199008
# New synthetic data generated 290
# Number of fraud in the balanced dataset 91587/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 91882/199008
# New synthetic data generated 290
# Number of fraud in the balanced dataset 92172/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 92466/199008
# New synthetic data generated 291
# Number of fraud in the balanced dataset 92757/199008
# New synthetic data generated 293
# Number of fraud in the balanced dataset 93050/199008
# New synthetic data generated 296
# Number of fraud in the balanced dataset 93346/199008
# New synthetic data generated 289
# Number of fraud in the balanced dataset 93635/199008
# New synthetic data generated 291
# Number of fraud in the balanced dataset 93926/199008
# New synthetic data generated 292
# Number of fraud in the balanced dataset 94218/199008
# New synthetic data generated 291
# Number of fraud in the balanced dataset 94509/199008
# New synthetic data generated 285
# Number of fraud in the balanced dataset 94794/199008
# New synthetic data generated 292
# Number of fraud in the balanced dataset 95086/199008
# New synthetic data generated 290
# Number of fraud in the balanced dataset 95376/199008
# New synthetic data generated 293
# Number of fraud in the balanced dataset 95669/199008
# New synthetic data generated 292
# Number of fraud in the balanced dataset 95961/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 96256/199008
# New synthetic data generated 289
# Number of fraud in the balanced dataset 96545/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 96840/199008
# New synthetic data generated 291
# Number of fraud in the balanced dataset 97131/199008
# New synthetic data generated 290
# Number of fraud in the balanced dataset 97421/199008
# New synthetic data generated 292
# Number of fraud in the balanced dataset 97713/199008
# New synthetic data generated 292
# Number of fraud in the balanced dataset 98005/199008
# New synthetic data generated 291
# Number of fraud in the balanced dataset 98296/199008
# New synthetic data generated 286
# Number of fraud in the balanced dataset 98582/199008
# New synthetic data generated 288
# Number of fraud in the balanced dataset 98870/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 99165/199008
# New synthetic data generated 290
# Number of fraud in the balanced dataset 99455/199008
# New synthetic data generated 292
# Number of fraud in the balanced dataset 99747/199008
# New synthetic data generated 293
# Number of fraud in the balanced dataset 100040/199008
# New synthetic data generated 292
# Number of fraud in the balanced dataset 100332/199008
# New synthetic data generated 293
# Number of fraud in the balanced dataset 100625/199008
# New synthetic data generated 291
# Number of fraud in the balanced dataset 100916/199008
# New synthetic data generated 293
# Number of fraud in the balanced dataset 101209/199008
# New synthetic data generated 290
# Number of fraud in the balanced dataset 101499/199008
# New synthetic data generated 290
# Number of fraud in the balanced dataset 101789/199008
# New synthetic data generated 293
# Number of fraud in the balanced dataset 102082/199008
# New synthetic data generated 293
# Number of fraud in the balanced dataset 102375/199008
# New synthetic data generated 292
# Number of fraud in the balanced dataset 102667/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 102962/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 103256/199008
# New synthetic data generated 289
# Number of fraud in the balanced dataset 103545/199008
# New synthetic data generated 292
# Number of fraud in the balanced dataset 103837/199008
# New synthetic data generated 290
# Number of fraud in the balanced dataset 104127/199008
# New synthetic data generated 288
# Number of fraud in the balanced dataset 104415/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 104709/199008
# New synthetic data generated 293
# Number of fraud in the balanced dataset 105002/199008
# New synthetic data generated 288
# Number of fraud in the balanced dataset 105290/199008
# New synthetic data generated 290
# Number of fraud in the balanced dataset 105580/199008
# New synthetic data generated 291
# Number of fraud in the balanced dataset 105871/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 106165/199008
# New synthetic data generated 292
# Number of fraud in the balanced dataset 106457/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 106751/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 107046/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 107341/199008
# New synthetic data generated 292
# Number of fraud in the balanced dataset 107633/199008
# New synthetic data generated 293
# Number of fraud in the balanced dataset 107926/199008
# New synthetic data generated 288
# Number of fraud in the balanced dataset 108214/199008
# New synthetic data generated 290
# Number of fraud in the balanced dataset 108504/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 108799/199008
# New synthetic data generated 292
# Number of fraud in the balanced dataset 109091/199008
# New synthetic data generated 293
# Number of fraud in the balanced dataset 109384/199008
# New synthetic data generated 292
# Number of fraud in the balanced dataset 109676/199008
# New synthetic data generated 293
# Number of fraud in the balanced dataset 109969/199008
# New synthetic data generated 293
# Number of fraud in the balanced dataset 110262/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 110557/199008
# New synthetic data generated 287
# Number of fraud in the balanced dataset 110844/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 111139/199008
# New synthetic data generated 293
# Number of fraud in the balanced dataset 111432/199008
# New synthetic data generated 291
# Number of fraud in the balanced dataset 111723/199008
# New synthetic data generated 293
# Number of fraud in the balanced dataset 112016/199008
# New synthetic data generated 291
# Number of fraud in the balanced dataset 112307/199008
# New synthetic data generated 292
# Number of fraud in the balanced dataset 112599/199008
# New synthetic data generated 285
# Number of fraud in the balanced dataset 112884/199008
# New synthetic data generated 286
# Number of fraud in the balanced dataset 113170/199008
# New synthetic data generated 296
# Number of fraud in the balanced dataset 113466/199008
# New synthetic data generated 291
# Number of fraud in the balanced dataset 113757/199008
# New synthetic data generated 287
# Number of fraud in the balanced dataset 114044/199008
# New synthetic data generated 289
# Number of fraud in the balanced dataset 114333/199008
# New synthetic data generated 297
# Number of fraud in the balanced dataset 114630/199008
# New synthetic data generated 291
# Number of fraud in the balanced dataset 114921/199008
# New synthetic data generated 290
# Number of fraud in the balanced dataset 115211/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 115505/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 115799/199008
# New synthetic data generated 293
# Number of fraud in the balanced dataset 116092/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 116387/199008
# New synthetic data generated 289
# Number of fraud in the balanced dataset 116676/199008
# New synthetic data generated 291
# Number of fraud in the balanced dataset 116967/199008
# New synthetic data generated 293
# Number of fraud in the balanced dataset 117260/199008
# New synthetic data generated 291
# Number of fraud in the balanced dataset 117551/199008
# New synthetic data generated 293
# Number of fraud in the balanced dataset 117844/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 118138/199008
# New synthetic data generated 296
# Number of fraud in the balanced dataset 118434/199008
# New synthetic data generated 293
# Number of fraud in the balanced dataset 118727/199008
# New synthetic data generated 290
# Number of fraud in the balanced dataset 119017/199008
# New synthetic data generated 291
# Number of fraud in the balanced dataset 119308/199008
# New synthetic data generated 291
# Number of fraud in the balanced dataset 119599/199008
# New synthetic data generated 293
# Number of fraud in the balanced dataset 119892/199008
# New synthetic data generated 291
# Number of fraud in the balanced dataset 120183/199008
# New synthetic data generated 291
# Number of fraud in the balanced dataset 120474/199008
# New synthetic data generated 286
# Number of fraud in the balanced dataset 120760/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 121055/199008
# New synthetic data generated 291
# Number of fraud in the balanced dataset 121346/199008
# New synthetic data generated 292
# Number of fraud in the balanced dataset 121638/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 121932/199008
# New synthetic data generated 289
# Number of fraud in the balanced dataset 122221/199008
# New synthetic data generated 290
# Number of fraud in the balanced dataset 122511/199008
# New synthetic data generated 293
# Number of fraud in the balanced dataset 122804/199008
# New synthetic data generated 288
# Number of fraud in the balanced dataset 123092/199008
# New synthetic data generated 293
# Number of fraud in the balanced dataset 123385/199008
# New synthetic data generated 292
# Number of fraud in the balanced dataset 123677/199008
# New synthetic data generated 289
# Number of fraud in the balanced dataset 123966/199008
# New synthetic data generated 289
# Number of fraud in the balanced dataset 124255/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 124549/199008
# New synthetic data generated 291
# Number of fraud in the balanced dataset 124840/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 125134/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 125428/199008
# New synthetic data generated 296
# Number of fraud in the balanced dataset 125724/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 126018/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 126312/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 126607/199008
# New synthetic data generated 293
# Number of fraud in the balanced dataset 126900/199008
# New synthetic data generated 292
# Number of fraud in the balanced dataset 127192/199008
# New synthetic data generated 291
# Number of fraud in the balanced dataset 127483/199008
# New synthetic data generated 293
# Number of fraud in the balanced dataset 127776/199008
# New synthetic data generated 293
# Number of fraud in the balanced dataset 128069/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 128364/199008
# New synthetic data generated 292
# Number of fraud in the balanced dataset 128656/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 128951/199008
# New synthetic data generated 293
# Number of fraud in the balanced dataset 129244/199008
# New synthetic data generated 290
# Number of fraud in the balanced dataset 129534/199008
# New synthetic data generated 292
# Number of fraud in the balanced dataset 129826/199008
# New synthetic data generated 292
# Number of fraud in the balanced dataset 130118/199008
# New synthetic data generated 285
# Number of fraud in the balanced dataset 130403/199008
# New synthetic data generated 290
# Number of fraud in the balanced dataset 130693/199008
# New synthetic data generated 292
# Number of fraud in the balanced dataset 130985/199008
# New synthetic data generated 290
# Number of fraud in the balanced dataset 131275/199008
# New synthetic data generated 292
# Number of fraud in the balanced dataset 131567/199008
# New synthetic data generated 292
# Number of fraud in the balanced dataset 131859/199008
# New synthetic data generated 289
# Number of fraud in the balanced dataset 132148/199008
# New synthetic data generated 297
# Number of fraud in the balanced dataset 132445/199008
# New synthetic data generated 293
# Number of fraud in the balanced dataset 132738/199008
# New synthetic data generated 289
# Number of fraud in the balanced dataset 133027/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 133321/199008
# New synthetic data generated 293
# Number of fraud in the balanced dataset 133614/199008
# New synthetic data generated 296
# Number of fraud in the balanced dataset 133910/199008
# New synthetic data generated 292
# Number of fraud in the balanced dataset 134202/199008
# New synthetic data generated 291
# Number of fraud in the balanced dataset 134493/199008
# New synthetic data generated 293
# Number of fraud in the balanced dataset 134786/199008
# New synthetic data generated 288
# Number of fraud in the balanced dataset 135074/199008
# New synthetic data generated 296
# Number of fraud in the balanced dataset 135370/199008
# New synthetic data generated 291
# Number of fraud in the balanced dataset 135661/199008
# New synthetic data generated 285
# Number of fraud in the balanced dataset 135946/199008
# New synthetic data generated 296
# Number of fraud in the balanced dataset 136242/199008
# New synthetic data generated 291
# Number of fraud in the balanced dataset 136533/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 136827/199008
# New synthetic data generated 291
# Number of fraud in the balanced dataset 137118/199008
# New synthetic data generated 293
# Number of fraud in the balanced dataset 137411/199008
# New synthetic data generated 288
# Number of fraud in the balanced dataset 137699/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 137994/199008
# New synthetic data generated 290
# Number of fraud in the balanced dataset 138284/199008
# New synthetic data generated 290
# Number of fraud in the balanced dataset 138574/199008
# New synthetic data generated 291
# Number of fraud in the balanced dataset 138865/199008
# New synthetic data generated 290
# Number of fraud in the balanced dataset 139155/199008
# New synthetic data generated 284
# Number of fraud in the balanced dataset 139439/199008
# New synthetic data generated 292
# Number of fraud in the balanced dataset 139731/199008
# New synthetic data generated 290
# Number of fraud in the balanced dataset 140021/199008
# New synthetic data generated 286
# Number of fraud in the balanced dataset 140307/199008
# New synthetic data generated 284
# Number of fraud in the balanced dataset 140591/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 140885/199008
# New synthetic data generated 289
# Number of fraud in the balanced dataset 141174/199008
# New synthetic data generated 293
# Number of fraud in the balanced dataset 141467/199008
# New synthetic data generated 289
# Number of fraud in the balanced dataset 141756/199008
# New synthetic data generated 293
# Number of fraud in the balanced dataset 142049/199008
# New synthetic data generated 290
# Number of fraud in the balanced dataset 142339/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 142634/199008
# New synthetic data generated 293
# Number of fraud in the balanced dataset 142927/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 143222/199008
# New synthetic data generated 290
# Number of fraud in the balanced dataset 143512/199008
# New synthetic data generated 290
# Number of fraud in the balanced dataset 143802/199008
# New synthetic data generated 293
# Number of fraud in the balanced dataset 144095/199008
# New synthetic data generated 296
# Number of fraud in the balanced dataset 144391/199008
# New synthetic data generated 287
# Number of fraud in the balanced dataset 144678/199008
# New synthetic data generated 292
# Number of fraud in the balanced dataset 144970/199008
# New synthetic data generated 293
# Number of fraud in the balanced dataset 145263/199008
# New synthetic data generated 291
# Number of fraud in the balanced dataset 145554/199008
# New synthetic data generated 292
# Number of fraud in the balanced dataset 145846/199008
# New synthetic data generated 285
# Number of fraud in the balanced dataset 146131/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 146425/199008
# New synthetic data generated 293
# Number of fraud in the balanced dataset 146718/199008
# New synthetic data generated 291
# Number of fraud in the balanced dataset 147009/199008
# New synthetic data generated 288
# Number of fraud in the balanced dataset 147297/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 147591/199008
# New synthetic data generated 289
# Number of fraud in the balanced dataset 147880/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 148174/199008
# New synthetic data generated 291
# Number of fraud in the balanced dataset 148465/199008
# New synthetic data generated 281
# Number of fraud in the balanced dataset 148746/199008
# New synthetic data generated 288
# Number of fraud in the balanced dataset 149034/199008
# New synthetic data generated 290
# Number of fraud in the balanced dataset 149324/199008
# New synthetic data generated 293
# Number of fraud in the balanced dataset 149617/199008
# New synthetic data generated 292
# Number of fraud in the balanced dataset 149909/199008
# New synthetic data generated 293
# Number of fraud in the balanced dataset 150202/199008
# New synthetic data generated 292
# Number of fraud in the balanced dataset 150494/199008
# New synthetic data generated 284
# Number of fraud in the balanced dataset 150778/199008
# New synthetic data generated 293
# Number of fraud in the balanced dataset 151071/199008
# New synthetic data generated 293
# Number of fraud in the balanced dataset 151364/199008
# New synthetic data generated 292
# Number of fraud in the balanced dataset 151656/199008
# New synthetic data generated 291
# Number of fraud in the balanced dataset 151947/199008
# New synthetic data generated 290
# Number of fraud in the balanced dataset 152237/199008
# New synthetic data generated 285
# Number of fraud in the balanced dataset 152522/199008
# New synthetic data generated 292
# Number of fraud in the balanced dataset 152814/199008
# New synthetic data generated 286
# Number of fraud in the balanced dataset 153100/199008
# New synthetic data generated 290
# Number of fraud in the balanced dataset 153390/199008
# New synthetic data generated 290
# Number of fraud in the balanced dataset 153680/199008
# New synthetic data generated 291
# Number of fraud in the balanced dataset 153971/199008
# New synthetic data generated 289
# Number of fraud in the balanced dataset 154260/199008
# New synthetic data generated 287
# Number of fraud in the balanced dataset 154547/199008
# New synthetic data generated 292
# Number of fraud in the balanced dataset 154839/199008
# New synthetic data generated 291
# Number of fraud in the balanced dataset 155130/199008
# New synthetic data generated 292
# Number of fraud in the balanced dataset 155422/199008
# New synthetic data generated 287
# Number of fraud in the balanced dataset 155709/199008
# New synthetic data generated 290
# Number of fraud in the balanced dataset 155999/199008
# New synthetic data generated 296
# Number of fraud in the balanced dataset 156295/199008
# New synthetic data generated 290
# Number of fraud in the balanced dataset 156585/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 156879/199008
# New synthetic data generated 287
# Number of fraud in the balanced dataset 157166/199008
# New synthetic data generated 297
# Number of fraud in the balanced dataset 157463/199008
# New synthetic data generated 291
# Number of fraud in the balanced dataset 157754/199008
# New synthetic data generated 292
# Number of fraud in the balanced dataset 158046/199008
# New synthetic data generated 293
# Number of fraud in the balanced dataset 158339/199008
# New synthetic data generated 291
# Number of fraud in the balanced dataset 158630/199008
# New synthetic data generated 288
# Number of fraud in the balanced dataset 158918/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 159212/199008
# New synthetic data generated 292
# Number of fraud in the balanced dataset 159504/199008
# New synthetic data generated 290
# Number of fraud in the balanced dataset 159794/199008
# New synthetic data generated 289
# Number of fraud in the balanced dataset 160083/199008
# New synthetic data generated 286
# Number of fraud in the balanced dataset 160369/199008
# New synthetic data generated 292
# Number of fraud in the balanced dataset 160661/199008
# New synthetic data generated 286
# Number of fraud in the balanced dataset 160947/199008
# New synthetic data generated 290
# Number of fraud in the balanced dataset 161237/199008
# New synthetic data generated 291
# Number of fraud in the balanced dataset 161528/199008
# New synthetic data generated 288
# Number of fraud in the balanced dataset 161816/199008
# New synthetic data generated 291
# Number of fraud in the balanced dataset 162107/199008
# New synthetic data generated 288
# Number of fraud in the balanced dataset 162395/199008
# New synthetic data generated 291
# Number of fraud in the balanced dataset 162686/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 162980/199008
# New synthetic data generated 291
# Number of fraud in the balanced dataset 163271/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 163565/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 163859/199008
# New synthetic data generated 291
# Number of fraud in the balanced dataset 164150/199008
# New synthetic data generated 292
# Number of fraud in the balanced dataset 164442/199008
# New synthetic data generated 286
# Number of fraud in the balanced dataset 164728/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 165022/199008
# New synthetic data generated 290
# Number of fraud in the balanced dataset 165312/199008
# New synthetic data generated 290
# Number of fraud in the balanced dataset 165602/199008
# New synthetic data generated 287
# Number of fraud in the balanced dataset 165889/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 166184/199008
# New synthetic data generated 292
# Number of fraud in the balanced dataset 166476/199008
# New synthetic data generated 285
# Number of fraud in the balanced dataset 166761/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 167056/199008
# New synthetic data generated 293
# Number of fraud in the balanced dataset 167349/199008
# New synthetic data generated 292
# Number of fraud in the balanced dataset 167641/199008
# New synthetic data generated 291
# Number of fraud in the balanced dataset 167932/199008
# New synthetic data generated 296
# Number of fraud in the balanced dataset 168228/199008
# New synthetic data generated 290
# Number of fraud in the balanced dataset 168518/199008
# New synthetic data generated 289
# Number of fraud in the balanced dataset 168807/199008
# New synthetic data generated 289
# Number of fraud in the balanced dataset 169096/199008
# New synthetic data generated 293
# Number of fraud in the balanced dataset 169389/199008
# New synthetic data generated 292
# Number of fraud in the balanced dataset 169681/199008
# New synthetic data generated 292
# Number of fraud in the balanced dataset 169973/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 170267/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 170561/199008
# New synthetic data generated 291
# Number of fraud in the balanced dataset 170852/199008
# New synthetic data generated 292
# Number of fraud in the balanced dataset 171144/199008
# New synthetic data generated 288
# Number of fraud in the balanced dataset 171432/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 171726/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 172021/199008
# New synthetic data generated 292
# Number of fraud in the balanced dataset 172313/199008
# New synthetic data generated 289
# Number of fraud in the balanced dataset 172602/199008
# New synthetic data generated 289
# Number of fraud in the balanced dataset 172891/199008
# New synthetic data generated 293
# Number of fraud in the balanced dataset 173184/199008
# New synthetic data generated 293
# Number of fraud in the balanced dataset 173477/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 173772/199008
# New synthetic data generated 290
# Number of fraud in the balanced dataset 174062/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 174356/199008
# New synthetic data generated 293
# Number of fraud in the balanced dataset 174649/199008
# New synthetic data generated 293
# Number of fraud in the balanced dataset 174942/199008
# New synthetic data generated 292
# Number of fraud in the balanced dataset 175234/199008
# New synthetic data generated 290
# Number of fraud in the balanced dataset 175524/199008
# New synthetic data generated 288
# Number of fraud in the balanced dataset 175812/199008
# New synthetic data generated 292
# Number of fraud in the balanced dataset 176104/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 176398/199008
# New synthetic data generated 291
# Number of fraud in the balanced dataset 176689/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 176984/199008
# New synthetic data generated 292
# Number of fraud in the balanced dataset 177276/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 177570/199008
# New synthetic data generated 293
# Number of fraud in the balanced dataset 177863/199008
# New synthetic data generated 288
# Number of fraud in the balanced dataset 178151/199008
# New synthetic data generated 289
# Number of fraud in the balanced dataset 178440/199008
# New synthetic data generated 291
# Number of fraud in the balanced dataset 178731/199008
# New synthetic data generated 291
# Number of fraud in the balanced dataset 179022/199008
# New synthetic data generated 289
# Number of fraud in the balanced dataset 179311/199008
# New synthetic data generated 288
# Number of fraud in the balanced dataset 179599/199008
# New synthetic data generated 287
# Number of fraud in the balanced dataset 179886/199008
# New synthetic data generated 292
# Number of fraud in the balanced dataset 180178/199008
# New synthetic data generated 289
# Number of fraud in the balanced dataset 180467/199008
# New synthetic data generated 287
# Number of fraud in the balanced dataset 180754/199008
# New synthetic data generated 296
# Number of fraud in the balanced dataset 181050/199008
# New synthetic data generated 287
# Number of fraud in the balanced dataset 181337/199008
# New synthetic data generated 292
# Number of fraud in the balanced dataset 181629/199008
# New synthetic data generated 288
# Number of fraud in the balanced dataset 181917/199008
# New synthetic data generated 292
# Number of fraud in the balanced dataset 182209/199008
# New synthetic data generated 289
# Number of fraud in the balanced dataset 182498/199008
# New synthetic data generated 285
# Number of fraud in the balanced dataset 182783/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 183078/199008
# New synthetic data generated 292
# Number of fraud in the balanced dataset 183370/199008
# New synthetic data generated 296
# Number of fraud in the balanced dataset 183666/199008
# New synthetic data generated 292
# Number of fraud in the balanced dataset 183958/199008
# New synthetic data generated 291
# Number of fraud in the balanced dataset 184249/199008
# New synthetic data generated 289
# Number of fraud in the balanced dataset 184538/199008
# New synthetic data generated 293
# Number of fraud in the balanced dataset 184831/199008
# New synthetic data generated 290
# Number of fraud in the balanced dataset 185121/199008
# New synthetic data generated 292
# Number of fraud in the balanced dataset 185413/199008
# New synthetic data generated 292
# Number of fraud in the balanced dataset 185705/199008
# New synthetic data generated 291
# Number of fraud in the balanced dataset 185996/199008
# New synthetic data generated 290
# Number of fraud in the balanced dataset 186286/199008
# New synthetic data generated 289
# Number of fraud in the balanced dataset 186575/199008
# New synthetic data generated 291
# Number of fraud in the balanced dataset 186866/199008
# New synthetic data generated 290
# Number of fraud in the balanced dataset 187156/199008
# New synthetic data generated 291
# Number of fraud in the balanced dataset 187447/199008
# New synthetic data generated 287
# Number of fraud in the balanced dataset 187734/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 188028/199008
# New synthetic data generated 293
# Number of fraud in the balanced dataset 188321/199008
# New synthetic data generated 296
# Number of fraud in the balanced dataset 188617/199008
# New synthetic data generated 291
# Number of fraud in the balanced dataset 188908/199008
# New synthetic data generated 290
# Number of fraud in the balanced dataset 189198/199008
# New synthetic data generated 289
# Number of fraud in the balanced dataset 189487/199008
# New synthetic data generated 296
# Number of fraud in the balanced dataset 189783/199008
# New synthetic data generated 290
# Number of fraud in the balanced dataset 190073/199008
# New synthetic data generated 298
# Number of fraud in the balanced dataset 190371/199008
# New synthetic data generated 292
# Number of fraud in the balanced dataset 190663/199008
# New synthetic data generated 296
# Number of fraud in the balanced dataset 190959/199008
# New synthetic data generated 292
# Number of fraud in the balanced dataset 191251/199008
# New synthetic data generated 290
# Number of fraud in the balanced dataset 191541/199008
# New synthetic data generated 291
# Number of fraud in the balanced dataset 191832/199008
# New synthetic data generated 293
# Number of fraud in the balanced dataset 192125/199008
# New synthetic data generated 291
# Number of fraud in the balanced dataset 192416/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 192710/199008
# New synthetic data generated 293
# Number of fraud in the balanced dataset 193003/199008
# New synthetic data generated 292
# Number of fraud in the balanced dataset 193295/199008
# New synthetic data generated 291
# Number of fraud in the balanced dataset 193586/199008
# New synthetic data generated 293
# Number of fraud in the balanced dataset 193879/199008
# New synthetic data generated 291
# Number of fraud in the balanced dataset 194170/199008
# New synthetic data generated 292
# Number of fraud in the balanced dataset 194462/199008
# New synthetic data generated 291
# Number of fraud in the balanced dataset 194753/199008
# New synthetic data generated 290
# Number of fraud in the balanced dataset 195043/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 195338/199008
# New synthetic data generated 293
# Number of fraud in the balanced dataset 195631/199008
# New synthetic data generated 291
# Number of fraud in the balanced dataset 195922/199008
# New synthetic data generated 296
# Number of fraud in the balanced dataset 196218/199008
# New synthetic data generated 297
# Number of fraud in the balanced dataset 196515/199008
# New synthetic data generated 292
# Number of fraud in the balanced dataset 196807/199008
# New synthetic data generated 293
# Number of fraud in the balanced dataset 197100/199008
# New synthetic data generated 292
# Number of fraud in the balanced dataset 197392/199008
# New synthetic data generated 292
# Number of fraud in the balanced dataset 197684/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 197978/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 198272/199008
# New synthetic data generated 292
# Number of fraud in the balanced dataset 198564/199008
# New synthetic data generated 297
# Number of fraud in the balanced dataset 198861/199008
# New synthetic data generated 290
# Number of fraud in the balanced dataset 199151/199008
# (398159, 31)
# Number of fraud in the balanced dataset 199151
# Number of non-fraud in the balanced dataset 199008

# %%
class Attention(nn.Module):
    def __init__(self, input_dim):
        super(Attention, self).__init__()
        self.attention_weights = nn.Linear(input_dim, 1, bias=False)  # Learnable attention weights

    def forward(self, lstm_output):
        # Compute attention scores (softmax over time dimension)
        attention_scores = torch.softmax(self.attention_weights(lstm_output), dim=1)  
        weighted_output = lstm_output * attention_scores  # Apply attention
        return torch.sum(weighted_output, dim=1)  # Sum over sequence length (time steps)

# %%
class ALSTM(nn.Module):
    def __init__(self, input_dim, hidden_dim):
        super(ALSTM, self).__init__()
        self.lstm = nn.LSTM(input_dim, hidden_dim, batch_first=True)  # Forward LSTM
        self.attention = Attention(hidden_dim)  # Attention Layer
        self.fc = nn.Linear(hidden_dim, 1)  # Fully connected output layer
        self.sigmoid = nn.Sigmoid()  # Sigmoid activation for binary classification

    def forward(self, x):
        lstm_output, _ = self.lstm(x)  # Get LSTM output
        attention_out = self.attention(lstm_output)  # Apply attention
        output = self.fc(attention_out)  # Fully connected layer
        return self.sigmoid(output)  # Sigmoid activation for probability output

# %%
# split data_train_oversampled in 20-80 split test-train
data_oversampled_labels = data_train_oversampled[:, -1]
data_train_oversampled = data_train_oversampled[:, :-1]
data_reshaped = data_train_oversampled.reshape(data_train_oversampled.shape[0], 1, data_train_oversampled.shape[1])

# Convert to PyTorch tensors
data_tensor = torch.tensor(data_reshaped, dtype=torch.float32)
labels_tensor = torch.tensor(data_oversampled_labels, dtype=torch.float32)

# Split into training and testing sets
data_train, data_test, labels_train, labels_test = train_test_split(data_tensor, labels_tensor, test_size=0.2, random_state=42)

# Create DataLoader for PyTorch
train_dataset = TensorDataset(data_train, labels_train)
test_dataset = TensorDataset(data_test, labels_test)

train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=32, shuffle=False)

# %%
input_dim = data_reshaped.shape[2]  # Number of features per transaction
hidden_dim = 10  # Number of LSTM units

# Initialize model, loss function, and optimizer
ALSTMmodel = ALSTM(input_dim, hidden_dim)
criterion = nn.BCELoss()  # Binary Cross Entropy for classification
optimizer = torch.optim.Adam(ALSTMmodel.parameters(), lr=0.001)

# Move model to GPU if available
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
ALSTMmodel.to(device)
# Out:
# ALSTM(
#   (lstm): LSTM(30, 10, batch_first=True)
#   (attention): Attention(
#     (attention_weights): Linear(in_features=10, out_features=1, bias=False)
#   )
#   (fc): Linear(in_features=10, out_features=1, bias=True)
#   (sigmoid): Sigmoid()
# )

# %%
num_epochs = 10

for epoch in range(num_epochs):
    ALSTMmodel.train()
    epoch_loss = 0
    correct = 0
    total = 0

    for X_batch, y_batch in train_loader:
        X_batch, y_batch = X_batch.to(device), y_batch.to(device)

        optimizer.zero_grad()  # Reset gradients
        y_pred = ALSTMmodel(X_batch).squeeze()
        
        loss = criterion(y_pred, y_batch)  # Compute loss
        loss.backward()  # Backpropagation
        optimizer.step()  # Update weights

        epoch_loss += loss.item()
    
    print(f"Epoch [{epoch+1}/{num_epochs}], Loss: {epoch_loss:.4f}")
# Out:
# Epoch [1/10], Loss: 220.3545
# Epoch [2/10], Loss: 18.5384
# Epoch [3/10], Loss: 16.2973
# Epoch [4/10], Loss: 14.5425
# Epoch [5/10], Loss: 13.4687
# Epoch [6/10], Loss: 13.1329
# Epoch [7/10], Loss: 11.8705
# Epoch [8/10], Loss: 11.8203

# %%
ALSTMmodel.eval()  # Set model to evaluation mode

correct = 0
total = 0

with torch.no_grad():  # No gradients needed for evaluation
    for X_batch, y_batch in test_loader:
        X_batch, y_batch = X_batch.to(device), y_batch.to(device)
        y_pred = ALSTMmodel(X_batch).squeeze()
        y_pred_labels = (y_pred > 0.5).float()  # Convert probabilities to binary labels
        
        correct += (y_pred_labels == y_batch).sum().item()
        total += y_batch.size(0)

accuracy = correct / total
print(f"Test Accuracy: {accuracy:.4f}")
# Out:
# Test Accuracy: 0.9997
