# %%
import numpy as np
import pandas as pd
import torch
import torch.nn as nn
from sklearn.preprocessing import RobustScaler
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
import jax.numpy as jnp
from torch.utils.data import DataLoader, TensorDataset

data = pd.read_csv('creditcard.csv')

dataset = data.to_numpy().astype(np.float32)  # Ensure data is float32 for PyTorch

scaler = RobustScaler(with_centering=True, with_scaling=True, quantile_range=(25.0, 75.0), unit_variance=False)
dataset[:, [0, 29]] = scaler.fit_transform(dataset[:, [0, 29]])

# %%
data_train, data_test = train_test_split(dataset, test_size=0.3, random_state=42)

# %%
# -----------------------------
# 3. Define the Autoencoder Model
# -----------------------------
class Autoencoder(nn.Module):
    def __init__(self):
        super(Autoencoder, self).__init__()
        # Encoder: 31 -> 23 -> 19 -> 17 -> 8 with dropout after first two hidden layers
        self.encoder = nn.Sequential(
            nn.Linear(31, 23),
            nn.Tanh(),
            nn.Dropout(0.1),
            nn.Linear(23, 19),
            nn.Tanh(),
            nn.Dropout(0.2),
            nn.Linear(19, 17),
            nn.Tanh(),
            nn.Linear(17, 8)
        )
        # Decoder: 8 -> 17 -> 19 -> 23 -> 31 with dropout after first two layers
        self.decoder = nn.Sequential(
            nn.Linear(8, 17),
            nn.Tanh(),
            nn.Dropout(0.2),
            nn.Linear(17, 19),
            nn.Tanh(),
            nn.Dropout(0.1),
            nn.Linear(19, 23),
            nn.Tanh(),
            nn.Linear(23, 31)
        )

    def forward(self, x):
        latent = self.encoder(x)
        reconstructed = self.decoder(latent)
        return reconstructed

# %%
fraud_data = data_train[data_train[:, -1] == 1]
non_fraud_data = data_train[data_train[:, -1] == 0]

legit_data_limited = non_fraud_data[np.random.choice(non_fraud_data.shape[0], fraud_data.shape[0], replace=False)]

train_dataset_SVM = np.vstack((legit_data_limited, fraud_data))
np.random.shuffle(train_dataset_SVM)
train_labels_SVM = train_dataset_SVM[:, -1]
train_dataset_SVM = train_dataset_SVM[:, :-1]

data_train_SVM, data_test_SVM, labels_train_SVM, labels_test_SVM = train_test_split(train_dataset_SVM, train_labels_SVM, test_size=0.2, random_state=42)
model = SVC(kernel='linear', C=1.0)
model.fit(data_train_SVM, labels_train_SVM)

labels_pred_test = model.predict(data_test_SVM)
labels_pred_train = model.predict(data_train_SVM)
accuracy_train = jnp.mean(labels_pred_train == labels_train_SVM)
accuracy_test = jnp.mean(labels_pred_test == labels_test_SVM)

print(f"Train Accuracy: {accuracy_train:.4f}")
print(f"Test Accuracy: {accuracy_test:.4f}")
# Out:
# Train Accuracy: 0.9525
# Test Accuracy: 0.9371

# %%
# load the model 
myModel = Autoencoder()

# Load the saved state dictionary
myModel.load_state_dict(torch.load("model/autoencoder/autoencoder.pth", map_location=torch.device('cpu'), weights_only=True))
myModel.eval()

alpha = 0.9

data_train_oversampled = data_train.copy()

while (len(data_train_oversampled[data_train_oversampled[:, -1] == 1]) < len(data_train_oversampled[data_train_oversampled[:, -1] == 0])):
    fraud_data = data_train_oversampled[data_train_oversampled[:, -1] == 1]

    # 2) Generate synthetic data by interpolating between fraud data points
    fraud_data_tensor = torch.tensor(fraud_data, dtype=torch.float32)

    latent_representations = myModel.encoder(fraud_data_tensor)

    noisy_vectors = []
    for _ in range(300):
        # Pick a random fraud vector
        i = np.random.randint(0, 300)
        z_i = latent_representations[i]

        # Optionally pick a second random vector to interpolate
        j = np.random.randint(0, 300)
        z_j = latent_representations[j]
        
        # Interpolation factor
        lambda_ = np.random.rand()
        z_ij = lambda_*z_i + (1 - lambda_)*z_j
        
        # Add Gaussian noise around that interpolation
        noise = torch.normal(mean=0.0, std=alpha, size=(8,))
        z_syn = z_ij + noise  # Both are tensors, so this should work directly

        noisy_vectors.append(z_syn.detach().numpy())

    noisy_vectors = np.array(noisy_vectors)

    # 3) Decode them to get synthetic data in original input space
    X_synthetic = myModel.decoder(torch.tensor(noisy_vectors, dtype=torch.float32)).detach().numpy()
    # remove label
    X_synthetic_to_predict = X_synthetic[:, :-1]
    # 4) Validate with SVM
    y_pred = model.predict(X_synthetic_to_predict)

    X_synthetic[:, -1] = y_pred

    # 5) Add the synthetic data to the training set
    X_synthetic_fraud = X_synthetic[X_synthetic[:, -1] == 1]

    data_train_oversampled = np.vstack((data_train_oversampled, X_synthetic_fraud))

    print("New synthetic data generated", len(X_synthetic_fraud))
    print(f"Number of fraud in the balanced dataset {len(data_train_oversampled[data_train_oversampled[:, -1] == 1])}/{len(data_train_oversampled[data_train_oversampled[:, -1] == 0])}")

# for i in range(len(data_train_oversampled[data_train_oversampled[:, -1] == 1]) - len(data_train_oversampled[data_train_oversampled[:, -1] == 0])):
#     noisy_vectors = []
#     for _ in range(n):
#         # Pick a random fraud vector
#         i = np.random.randint(0, n)
#         z_i = latent_representations[i]

#         # Optionally pick a second random vector to interpolate
#         j = np.random.randint(0, n)
#         z_j = latent_representations[j]
        
#         # Interpolation factor
#         lambda_ = np.random.rand()
#         z_ij = lambda_*z_i + (1 - lambda_)*z_j
        
#         # Add Gaussian noise around that interpolation
#         noise = torch.normal(mean=0.0, std=alpha, size=(latent_dim,))
#         z_syn = z_ij + noise  # Both are tensors, so this should work directly

#         noisy_vectors.append(z_syn.detach().numpy())

#     noisy_vectors = np.array(noisy_vectors)

#     # 3) Decode them to get synthetic data in original input space
#     X_synthetic = myModel.decoder(torch.tensor(noisy_vectors, dtype=torch.float32)).detach().numpy()
#     # remove label
#     X_synthetic_to_predict = X_synthetic[:, :-1]
#     # 4) Validate with SVM
#     y_pred = model.predict(X_synthetic_to_predict)

#     X_synthetic[:, -1] = y_pred

#     # 5) Add the synthetic data to the training set
#     X_synthetic_fraud = X_synthetic[X_synthetic[:, -1] == 1]

#     data_train_oversampled = np.vstack((data_train_oversampled, X_synthetic_fraud))

print(data_train_oversampled.shape)
print("Number of fraud in the balanced dataset", len(data_train_oversampled[data_train_oversampled[:, -1] == 1]))
print("Number of non-fraud in the balanced dataset", len(data_train_oversampled[data_train_oversampled[:, -1] == 0]))
# Out:
# New synthetic data generated 297
# Number of fraud in the balanced dataset 653/199008
# New synthetic data generated 296
# Number of fraud in the balanced dataset 949/199008
# New synthetic data generated 296
# Number of fraud in the balanced dataset 1245/199008
# New synthetic data generated 297
# Number of fraud in the balanced dataset 1542/199008
# New synthetic data generated 298
# Number of fraud in the balanced dataset 1840/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 2134/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 2428/199008
# New synthetic data generated 296
# Number of fraud in the balanced dataset 2724/199008
# New synthetic data generated 297
# Number of fraud in the balanced dataset 3021/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 3315/199008
# New synthetic data generated 290
# Number of fraud in the balanced dataset 3605/199008
# New synthetic data generated 296
# Number of fraud in the balanced dataset 3901/199008
# New synthetic data generated 297
# Number of fraud in the balanced dataset 4198/199008
# New synthetic data generated 297
# Number of fraud in the balanced dataset 4495/199008
# New synthetic data generated 296
# Number of fraud in the balanced dataset 4791/199008
# New synthetic data generated 293
# Number of fraud in the balanced dataset 5084/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 5379/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 5674/199008
# New synthetic data generated 297
# Number of fraud in the balanced dataset 5971/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 6265/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 6559/199008
# New synthetic data generated 292
# Number of fraud in the balanced dataset 6851/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 7145/199008
# New synthetic data generated 297
# Number of fraud in the balanced dataset 7442/199008
# New synthetic data generated 297
# Number of fraud in the balanced dataset 7739/199008
# New synthetic data generated 296
# Number of fraud in the balanced dataset 8035/199008
# New synthetic data generated 296
# Number of fraud in the balanced dataset 8331/199008
# New synthetic data generated 297
# Number of fraud in the balanced dataset 8628/199008
# New synthetic data generated 293
# Number of fraud in the balanced dataset 8921/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 9216/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 9511/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 9805/199008
# New synthetic data generated 296
# Number of fraud in the balanced dataset 10101/199008
# New synthetic data generated 293
# Number of fraud in the balanced dataset 10394/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 10689/199008
# New synthetic data generated 297
# Number of fraud in the balanced dataset 10986/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 11280/199008
# New synthetic data generated 296
# Number of fraud in the balanced dataset 11576/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 11871/199008
# New synthetic data generated 299
# Number of fraud in the balanced dataset 12170/199008
# New synthetic data generated 299
# Number of fraud in the balanced dataset 12469/199008
# New synthetic data generated 292
# Number of fraud in the balanced dataset 12761/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 13056/199008
# New synthetic data generated 296
# Number of fraud in the balanced dataset 13352/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 13647/199008
# New synthetic data generated 297
# Number of fraud in the balanced dataset 13944/199008
# New synthetic data generated 298
# Number of fraud in the balanced dataset 14242/199008
# New synthetic data generated 296
# Number of fraud in the balanced dataset 14538/199008
# New synthetic data generated 297
# Number of fraud in the balanced dataset 14835/199008
# New synthetic data generated 292
# Number of fraud in the balanced dataset 15127/199008
# New synthetic data generated 293
# Number of fraud in the balanced dataset 15420/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 15714/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 16009/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 16303/199008
# New synthetic data generated 297
# Number of fraud in the balanced dataset 16600/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 16895/199008
# New synthetic data generated 298
# Number of fraud in the balanced dataset 17193/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 17488/199008
# New synthetic data generated 292
# Number of fraud in the balanced dataset 17780/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 18075/199008
# New synthetic data generated 297
# Number of fraud in the balanced dataset 18372/199008
# New synthetic data generated 297
# Number of fraud in the balanced dataset 18669/199008
# New synthetic data generated 297
# Number of fraud in the balanced dataset 18966/199008
# New synthetic data generated 290
# Number of fraud in the balanced dataset 19256/199008
# New synthetic data generated 296
# Number of fraud in the balanced dataset 19552/199008
# New synthetic data generated 298
# Number of fraud in the balanced dataset 19850/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 20144/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 20439/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 20734/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 21029/199008
# New synthetic data generated 297
# Number of fraud in the balanced dataset 21326/199008
# New synthetic data generated 298
# Number of fraud in the balanced dataset 21624/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 21919/199008
# New synthetic data generated 296
# Number of fraud in the balanced dataset 22215/199008
# New synthetic data generated 298
# Number of fraud in the balanced dataset 22513/199008
# New synthetic data generated 293
# Number of fraud in the balanced dataset 22806/199008
# New synthetic data generated 296
# Number of fraud in the balanced dataset 23102/199008
# New synthetic data generated 299
# Number of fraud in the balanced dataset 23401/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 23695/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 23990/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 24285/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 24580/199008
# New synthetic data generated 297
# Number of fraud in the balanced dataset 24877/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 25172/199008
# New synthetic data generated 300
# Number of fraud in the balanced dataset 25472/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 25767/199008
# New synthetic data generated 298
# Number of fraud in the balanced dataset 26065/199008
# New synthetic data generated 293
# Number of fraud in the balanced dataset 26358/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 26653/199008
# New synthetic data generated 298
# Number of fraud in the balanced dataset 26951/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 27245/199008
# New synthetic data generated 298
# Number of fraud in the balanced dataset 27543/199008
# New synthetic data generated 296
# Number of fraud in the balanced dataset 27839/199008
# New synthetic data generated 298
# Number of fraud in the balanced dataset 28137/199008
# New synthetic data generated 297
# Number of fraud in the balanced dataset 28434/199008
# New synthetic data generated 297
# Number of fraud in the balanced dataset 28731/199008
# New synthetic data generated 296
# Number of fraud in the balanced dataset 29027/199008
# New synthetic data generated 297
# Number of fraud in the balanced dataset 29324/199008
# New synthetic data generated 296
# Number of fraud in the balanced dataset 29620/199008
# New synthetic data generated 296
# Number of fraud in the balanced dataset 29916/199008
# New synthetic data generated 296
# Number of fraud in the balanced dataset 30212/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 30506/199008
# New synthetic data generated 296
# Number of fraud in the balanced dataset 30802/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 31097/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 31391/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 31685/199008
# New synthetic data generated 296
# Number of fraud in the balanced dataset 31981/199008
# New synthetic data generated 297
# Number of fraud in the balanced dataset 32278/199008
# New synthetic data generated 298
# Number of fraud in the balanced dataset 32576/199008
# New synthetic data generated 296
# Number of fraud in the balanced dataset 32872/199008
# New synthetic data generated 298
# Number of fraud in the balanced dataset 33170/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 33464/199008
# New synthetic data generated 298
# Number of fraud in the balanced dataset 33762/199008
# New synthetic data generated 298
# Number of fraud in the balanced dataset 34060/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 34355/199008
# New synthetic data generated 291
# Number of fraud in the balanced dataset 34646/199008
# New synthetic data generated 299
# Number of fraud in the balanced dataset 34945/199008
# New synthetic data generated 293
# Number of fraud in the balanced dataset 35238/199008
# New synthetic data generated 298
# Number of fraud in the balanced dataset 35536/199008
# New synthetic data generated 297
# Number of fraud in the balanced dataset 35833/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 36128/199008
# New synthetic data generated 292
# Number of fraud in the balanced dataset 36420/199008
# New synthetic data generated 293
# Number of fraud in the balanced dataset 36713/199008
# New synthetic data generated 298
# Number of fraud in the balanced dataset 37011/199008
# New synthetic data generated 296
# Number of fraud in the balanced dataset 37307/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 37602/199008
# New synthetic data generated 292
# Number of fraud in the balanced dataset 37894/199008
# New synthetic data generated 296
# Number of fraud in the balanced dataset 38190/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 38485/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 38779/199008
# New synthetic data generated 296
# Number of fraud in the balanced dataset 39075/199008
# New synthetic data generated 291
# Number of fraud in the balanced dataset 39366/199008
# New synthetic data generated 293
# Number of fraud in the balanced dataset 39659/199008
# New synthetic data generated 299
# Number of fraud in the balanced dataset 39958/199008
# New synthetic data generated 298
# Number of fraud in the balanced dataset 40256/199008
# New synthetic data generated 293
# Number of fraud in the balanced dataset 40549/199008
# New synthetic data generated 297
# Number of fraud in the balanced dataset 40846/199008
# New synthetic data generated 298
# Number of fraud in the balanced dataset 41144/199008
# New synthetic data generated 297
# Number of fraud in the balanced dataset 41441/199008
# New synthetic data generated 297
# Number of fraud in the balanced dataset 41738/199008
# New synthetic data generated 292
# Number of fraud in the balanced dataset 42030/199008
# New synthetic data generated 293
# Number of fraud in the balanced dataset 42323/199008
# New synthetic data generated 296
# Number of fraud in the balanced dataset 42619/199008
# New synthetic data generated 296
# Number of fraud in the balanced dataset 42915/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 43210/199008
# New synthetic data generated 293
# Number of fraud in the balanced dataset 43503/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 43798/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 44093/199008
# New synthetic data generated 297
# Number of fraud in the balanced dataset 44390/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 44685/199008
# New synthetic data generated 297
# Number of fraud in the balanced dataset 44982/199008
# New synthetic data generated 297
# Number of fraud in the balanced dataset 45279/199008
# New synthetic data generated 292
# Number of fraud in the balanced dataset 45571/199008
# New synthetic data generated 296
# Number of fraud in the balanced dataset 45867/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 46161/199008
# New synthetic data generated 299
# Number of fraud in the balanced dataset 46460/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 46755/199008
# New synthetic data generated 299
# Number of fraud in the balanced dataset 47054/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 47348/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 47642/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 47936/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 48231/199008
# New synthetic data generated 291
# Number of fraud in the balanced dataset 48522/199008
# New synthetic data generated 296
# Number of fraud in the balanced dataset 48818/199008
# New synthetic data generated 297
# Number of fraud in the balanced dataset 49115/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 49410/199008
# New synthetic data generated 297
# Number of fraud in the balanced dataset 49707/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 50002/199008
# New synthetic data generated 292
# Number of fraud in the balanced dataset 50294/199008
# New synthetic data generated 293
# Number of fraud in the balanced dataset 50587/199008
# New synthetic data generated 292
# Number of fraud in the balanced dataset 50879/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 51174/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 51469/199008
# New synthetic data generated 292
# Number of fraud in the balanced dataset 51761/199008
# New synthetic data generated 297
# Number of fraud in the balanced dataset 52058/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 52353/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 52647/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 52942/199008
# New synthetic data generated 297
# Number of fraud in the balanced dataset 53239/199008
# New synthetic data generated 293
# Number of fraud in the balanced dataset 53532/199008
# New synthetic data generated 297
# Number of fraud in the balanced dataset 53829/199008
# New synthetic data generated 298
# Number of fraud in the balanced dataset 54127/199008
# New synthetic data generated 296
# Number of fraud in the balanced dataset 54423/199008
# New synthetic data generated 296
# Number of fraud in the balanced dataset 54719/199008
# New synthetic data generated 296
# Number of fraud in the balanced dataset 55015/199008
# New synthetic data generated 298
# Number of fraud in the balanced dataset 55313/199008
# New synthetic data generated 296
# Number of fraud in the balanced dataset 55609/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 55904/199008
# New synthetic data generated 293
# Number of fraud in the balanced dataset 56197/199008
# New synthetic data generated 296
# Number of fraud in the balanced dataset 56493/199008
# New synthetic data generated 298
# Number of fraud in the balanced dataset 56791/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 57086/199008
# New synthetic data generated 299
# Number of fraud in the balanced dataset 57385/199008
# New synthetic data generated 298
# Number of fraud in the balanced dataset 57683/199008
# New synthetic data generated 296
# Number of fraud in the balanced dataset 57979/199008
# New synthetic data generated 293
# Number of fraud in the balanced dataset 58272/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 58567/199008
# New synthetic data generated 291
# Number of fraud in the balanced dataset 58858/199008
# New synthetic data generated 297
# Number of fraud in the balanced dataset 59155/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 59449/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 59744/199008
# New synthetic data generated 291
# Number of fraud in the balanced dataset 60035/199008
# New synthetic data generated 296
# Number of fraud in the balanced dataset 60331/199008
# New synthetic data generated 290
# Number of fraud in the balanced dataset 60621/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 60916/199008
# New synthetic data generated 297
# Number of fraud in the balanced dataset 61213/199008
# New synthetic data generated 297
# Number of fraud in the balanced dataset 61510/199008
# New synthetic data generated 296
# Number of fraud in the balanced dataset 61806/199008
# New synthetic data generated 296
# Number of fraud in the balanced dataset 62102/199008
# New synthetic data generated 293
# Number of fraud in the balanced dataset 62395/199008
# New synthetic data generated 297
# Number of fraud in the balanced dataset 62692/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 62987/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 63281/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 63576/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 63871/199008
# New synthetic data generated 298
# Number of fraud in the balanced dataset 64169/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 64464/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 64758/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 65052/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 65347/199008
# New synthetic data generated 299
# Number of fraud in the balanced dataset 65646/199008
# New synthetic data generated 293
# Number of fraud in the balanced dataset 65939/199008
# New synthetic data generated 299
# Number of fraud in the balanced dataset 66238/199008
# New synthetic data generated 290
# Number of fraud in the balanced dataset 66528/199008
# New synthetic data generated 297
# Number of fraud in the balanced dataset 66825/199008
# New synthetic data generated 297
# Number of fraud in the balanced dataset 67122/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 67417/199008
# New synthetic data generated 297
# Number of fraud in the balanced dataset 67714/199008
# New synthetic data generated 297
# Number of fraud in the balanced dataset 68011/199008
# New synthetic data generated 296
# Number of fraud in the balanced dataset 68307/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 68602/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 68897/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 69192/199008
# New synthetic data generated 291
# Number of fraud in the balanced dataset 69483/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 69778/199008
# New synthetic data generated 297
# Number of fraud in the balanced dataset 70075/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 70369/199008
# New synthetic data generated 297
# Number of fraud in the balanced dataset 70666/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 70961/199008
# New synthetic data generated 292
# Number of fraud in the balanced dataset 71253/199008
# New synthetic data generated 296
# Number of fraud in the balanced dataset 71549/199008
# New synthetic data generated 298
# Number of fraud in the balanced dataset 71847/199008
# New synthetic data generated 299
# Number of fraud in the balanced dataset 72146/199008
# New synthetic data generated 293
# Number of fraud in the balanced dataset 72439/199008
# New synthetic data generated 293
# Number of fraud in the balanced dataset 72732/199008
# New synthetic data generated 292
# Number of fraud in the balanced dataset 73024/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 73319/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 73614/199008
# New synthetic data generated 296
# Number of fraud in the balanced dataset 73910/199008
# New synthetic data generated 288
# Number of fraud in the balanced dataset 74198/199008
# New synthetic data generated 297
# Number of fraud in the balanced dataset 74495/199008
# New synthetic data generated 298
# Number of fraud in the balanced dataset 74793/199008
# New synthetic data generated 293
# Number of fraud in the balanced dataset 75086/199008
# New synthetic data generated 293
# Number of fraud in the balanced dataset 75379/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 75673/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 75968/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 76263/199008
# New synthetic data generated 297
# Number of fraud in the balanced dataset 76560/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 76855/199008
# New synthetic data generated 299
# Number of fraud in the balanced dataset 77154/199008
# New synthetic data generated 296
# Number of fraud in the balanced dataset 77450/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 77744/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 78038/199008
# New synthetic data generated 298
# Number of fraud in the balanced dataset 78336/199008
# New synthetic data generated 298
# Number of fraud in the balanced dataset 78634/199008
# New synthetic data generated 297
# Number of fraud in the balanced dataset 78931/199008
# New synthetic data generated 292
# Number of fraud in the balanced dataset 79223/199008
# New synthetic data generated 297
# Number of fraud in the balanced dataset 79520/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 79814/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 80109/199008
# New synthetic data generated 299
# Number of fraud in the balanced dataset 80408/199008
# New synthetic data generated 293
# Number of fraud in the balanced dataset 80701/199008
# New synthetic data generated 297
# Number of fraud in the balanced dataset 80998/199008
# New synthetic data generated 297
# Number of fraud in the balanced dataset 81295/199008
# New synthetic data generated 296
# Number of fraud in the balanced dataset 81591/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 81886/199008
# New synthetic data generated 297
# Number of fraud in the balanced dataset 82183/199008
# New synthetic data generated 298
# Number of fraud in the balanced dataset 82481/199008
# New synthetic data generated 291
# Number of fraud in the balanced dataset 82772/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 83067/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 83362/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 83657/199008
# New synthetic data generated 299
# Number of fraud in the balanced dataset 83956/199008
# New synthetic data generated 296
# Number of fraud in the balanced dataset 84252/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 84546/199008
# New synthetic data generated 296
# Number of fraud in the balanced dataset 84842/199008
# New synthetic data generated 297
# Number of fraud in the balanced dataset 85139/199008
# New synthetic data generated 298
# Number of fraud in the balanced dataset 85437/199008
# New synthetic data generated 297
# Number of fraud in the balanced dataset 85734/199008
# New synthetic data generated 297
# Number of fraud in the balanced dataset 86031/199008
# New synthetic data generated 297
# Number of fraud in the balanced dataset 86328/199008
# New synthetic data generated 298
# Number of fraud in the balanced dataset 86626/199008
# New synthetic data generated 297
# Number of fraud in the balanced dataset 86923/199008
# New synthetic data generated 296
# Number of fraud in the balanced dataset 87219/199008
# New synthetic data generated 291
# Number of fraud in the balanced dataset 87510/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 87805/199008
# New synthetic data generated 296
# Number of fraud in the balanced dataset 88101/199008
# New synthetic data generated 298
# Number of fraud in the balanced dataset 88399/199008
# New synthetic data generated 293
# Number of fraud in the balanced dataset 88692/199008
# New synthetic data generated 296
# Number of fraud in the balanced dataset 88988/199008
# New synthetic data generated 297
# Number of fraud in the balanced dataset 89285/199008
# New synthetic data generated 293
# Number of fraud in the balanced dataset 89578/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 89873/199008
# New synthetic data generated 297
# Number of fraud in the balanced dataset 90170/199008
# New synthetic data generated 299
# Number of fraud in the balanced dataset 90469/199008
# New synthetic data generated 297
# Number of fraud in the balanced dataset 90766/199008
# New synthetic data generated 296
# Number of fraud in the balanced dataset 91062/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 91357/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 91651/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 91945/199008
# New synthetic data generated 297
# Number of fraud in the balanced dataset 92242/199008
# New synthetic data generated 297
# Number of fraud in the balanced dataset 92539/199008
# New synthetic data generated 299
# Number of fraud in the balanced dataset 92838/199008
# New synthetic data generated 293
# Number of fraud in the balanced dataset 93131/199008
# New synthetic data generated 293
# Number of fraud in the balanced dataset 93424/199008
# New synthetic data generated 297
# Number of fraud in the balanced dataset 93721/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 94015/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 94310/199008
# New synthetic data generated 296
# Number of fraud in the balanced dataset 94606/199008
# New synthetic data generated 296
# Number of fraud in the balanced dataset 94902/199008
# New synthetic data generated 297
# Number of fraud in the balanced dataset 95199/199008
# New synthetic data generated 297
# Number of fraud in the balanced dataset 95496/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 95790/199008
# New synthetic data generated 296
# Number of fraud in the balanced dataset 96086/199008
# New synthetic data generated 298
# Number of fraud in the balanced dataset 96384/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 96679/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 96973/199008
# New synthetic data generated 297
# Number of fraud in the balanced dataset 97270/199008
# New synthetic data generated 298
# Number of fraud in the balanced dataset 97568/199008
# New synthetic data generated 296
# Number of fraud in the balanced dataset 97864/199008
# New synthetic data generated 297
# Number of fraud in the balanced dataset 98161/199008
# New synthetic data generated 297
# Number of fraud in the balanced dataset 98458/199008
# New synthetic data generated 296
# Number of fraud in the balanced dataset 98754/199008
# New synthetic data generated 296
# Number of fraud in the balanced dataset 99050/199008
# New synthetic data generated 296
# Number of fraud in the balanced dataset 99346/199008
# New synthetic data generated 296
# Number of fraud in the balanced dataset 99642/199008
# New synthetic data generated 298
# Number of fraud in the balanced dataset 99940/199008
# New synthetic data generated 296
# Number of fraud in the balanced dataset 100236/199008
# New synthetic data generated 296
# Number of fraud in the balanced dataset 100532/199008
# New synthetic data generated 296
# Number of fraud in the balanced dataset 100828/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 101123/199008
# New synthetic data generated 297
# Number of fraud in the balanced dataset 101420/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 101714/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 102008/199008
# New synthetic data generated 297
# Number of fraud in the balanced dataset 102305/199008
# New synthetic data generated 298
# Number of fraud in the balanced dataset 102603/199008
# New synthetic data generated 297
# Number of fraud in the balanced dataset 102900/199008
# New synthetic data generated 296
# Number of fraud in the balanced dataset 103196/199008
# New synthetic data generated 298
# Number of fraud in the balanced dataset 103494/199008
# New synthetic data generated 296
# Number of fraud in the balanced dataset 103790/199008
# New synthetic data generated 291
# Number of fraud in the balanced dataset 104081/199008
# New synthetic data generated 297
# Number of fraud in the balanced dataset 104378/199008
# New synthetic data generated 299
# Number of fraud in the balanced dataset 104677/199008
# New synthetic data generated 297
# Number of fraud in the balanced dataset 104974/199008
# New synthetic data generated 299
# Number of fraud in the balanced dataset 105273/199008
# New synthetic data generated 298
# Number of fraud in the balanced dataset 105571/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 105866/199008
# New synthetic data generated 298
# Number of fraud in the balanced dataset 106164/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 106459/199008
# New synthetic data generated 296
# Number of fraud in the balanced dataset 106755/199008
# New synthetic data generated 300
# Number of fraud in the balanced dataset 107055/199008
# New synthetic data generated 296
# Number of fraud in the balanced dataset 107351/199008
# New synthetic data generated 299
# Number of fraud in the balanced dataset 107650/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 107945/199008
# New synthetic data generated 293
# Number of fraud in the balanced dataset 108238/199008
# New synthetic data generated 296
# Number of fraud in the balanced dataset 108534/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 108828/199008
# New synthetic data generated 298
# Number of fraud in the balanced dataset 109126/199008
# New synthetic data generated 299
# Number of fraud in the balanced dataset 109425/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 109719/199008
# New synthetic data generated 293
# Number of fraud in the balanced dataset 110012/199008
# New synthetic data generated 298
# Number of fraud in the balanced dataset 110310/199008
# New synthetic data generated 296
# Number of fraud in the balanced dataset 110606/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 110900/199008
# New synthetic data generated 296
# Number of fraud in the balanced dataset 111196/199008
# New synthetic data generated 297
# Number of fraud in the balanced dataset 111493/199008
# New synthetic data generated 292
# Number of fraud in the balanced dataset 111785/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 112080/199008
# New synthetic data generated 298
# Number of fraud in the balanced dataset 112378/199008
# New synthetic data generated 296
# Number of fraud in the balanced dataset 112674/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 112968/199008
# New synthetic data generated 291
# Number of fraud in the balanced dataset 113259/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 113553/199008
# New synthetic data generated 296
# Number of fraud in the balanced dataset 113849/199008
# New synthetic data generated 292
# Number of fraud in the balanced dataset 114141/199008
# New synthetic data generated 297
# Number of fraud in the balanced dataset 114438/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 114733/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 115028/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 115323/199008
# New synthetic data generated 293
# Number of fraud in the balanced dataset 115616/199008
# New synthetic data generated 293
# Number of fraud in the balanced dataset 115909/199008
# New synthetic data generated 297
# Number of fraud in the balanced dataset 116206/199008
# New synthetic data generated 292
# Number of fraud in the balanced dataset 116498/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 116792/199008
# New synthetic data generated 296
# Number of fraud in the balanced dataset 117088/199008
# New synthetic data generated 297
# Number of fraud in the balanced dataset 117385/199008
# New synthetic data generated 296
# Number of fraud in the balanced dataset 117681/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 117975/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 118270/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 118564/199008
# New synthetic data generated 297
# Number of fraud in the balanced dataset 118861/199008
# New synthetic data generated 296
# Number of fraud in the balanced dataset 119157/199008
# New synthetic data generated 298
# Number of fraud in the balanced dataset 119455/199008
# New synthetic data generated 291
# Number of fraud in the balanced dataset 119746/199008
# New synthetic data generated 297
# Number of fraud in the balanced dataset 120043/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 120338/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 120633/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 120928/199008
# New synthetic data generated 290
# Number of fraud in the balanced dataset 121218/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 121513/199008
# New synthetic data generated 298
# Number of fraud in the balanced dataset 121811/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 122105/199008
# New synthetic data generated 297
# Number of fraud in the balanced dataset 122402/199008
# New synthetic data generated 297
# Number of fraud in the balanced dataset 122699/199008
# New synthetic data generated 293
# Number of fraud in the balanced dataset 122992/199008
# New synthetic data generated 298
# Number of fraud in the balanced dataset 123290/199008
# New synthetic data generated 297
# Number of fraud in the balanced dataset 123587/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 123881/199008
# New synthetic data generated 298
# Number of fraud in the balanced dataset 124179/199008
# New synthetic data generated 296
# Number of fraud in the balanced dataset 124475/199008
# New synthetic data generated 298
# Number of fraud in the balanced dataset 124773/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 125068/199008
# New synthetic data generated 298
# Number of fraud in the balanced dataset 125366/199008
# New synthetic data generated 296
# Number of fraud in the balanced dataset 125662/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 125956/199008
# New synthetic data generated 298
# Number of fraud in the balanced dataset 126254/199008
# New synthetic data generated 293
# Number of fraud in the balanced dataset 126547/199008
# New synthetic data generated 296
# Number of fraud in the balanced dataset 126843/199008
# New synthetic data generated 300
# Number of fraud in the balanced dataset 127143/199008
# New synthetic data generated 298
# Number of fraud in the balanced dataset 127441/199008
# New synthetic data generated 298
# Number of fraud in the balanced dataset 127739/199008
# New synthetic data generated 293
# Number of fraud in the balanced dataset 128032/199008
# New synthetic data generated 296
# Number of fraud in the balanced dataset 128328/199008
# New synthetic data generated 300
# Number of fraud in the balanced dataset 128628/199008
# New synthetic data generated 297
# Number of fraud in the balanced dataset 128925/199008
# New synthetic data generated 293
# Number of fraud in the balanced dataset 129218/199008
# New synthetic data generated 298
# Number of fraud in the balanced dataset 129516/199008
# New synthetic data generated 297
# Number of fraud in the balanced dataset 129813/199008
# New synthetic data generated 298
# Number of fraud in the balanced dataset 130111/199008
# New synthetic data generated 296
# Number of fraud in the balanced dataset 130407/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 130702/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 130996/199008
# New synthetic data generated 293
# Number of fraud in the balanced dataset 131289/199008
# New synthetic data generated 297
# Number of fraud in the balanced dataset 131586/199008
# New synthetic data generated 297
# Number of fraud in the balanced dataset 131883/199008
# New synthetic data generated 296
# Number of fraud in the balanced dataset 132179/199008
# New synthetic data generated 297
# Number of fraud in the balanced dataset 132476/199008
# New synthetic data generated 297
# Number of fraud in the balanced dataset 132773/199008
# New synthetic data generated 292
# Number of fraud in the balanced dataset 133065/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 133360/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 133655/199008
# New synthetic data generated 292
# Number of fraud in the balanced dataset 133947/199008
# New synthetic data generated 293
# Number of fraud in the balanced dataset 134240/199008
# New synthetic data generated 293
# Number of fraud in the balanced dataset 134533/199008
# New synthetic data generated 296
# Number of fraud in the balanced dataset 134829/199008
# New synthetic data generated 293
# Number of fraud in the balanced dataset 135122/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 135416/199008
# New synthetic data generated 296
# Number of fraud in the balanced dataset 135712/199008
# New synthetic data generated 297
# Number of fraud in the balanced dataset 136009/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 136304/199008
# New synthetic data generated 297
# Number of fraud in the balanced dataset 136601/199008
# New synthetic data generated 297
# Number of fraud in the balanced dataset 136898/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 137193/199008
# New synthetic data generated 298
# Number of fraud in the balanced dataset 137491/199008
# New synthetic data generated 298
# Number of fraud in the balanced dataset 137789/199008
# New synthetic data generated 296
# Number of fraud in the balanced dataset 138085/199008
# New synthetic data generated 298
# Number of fraud in the balanced dataset 138383/199008
# New synthetic data generated 299
# Number of fraud in the balanced dataset 138682/199008
# New synthetic data generated 296
# Number of fraud in the balanced dataset 138978/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 139272/199008
# New synthetic data generated 297
# Number of fraud in the balanced dataset 139569/199008
# New synthetic data generated 299
# Number of fraud in the balanced dataset 139868/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 140162/199008
# New synthetic data generated 296
# Number of fraud in the balanced dataset 140458/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 140752/199008
# New synthetic data generated 290
# Number of fraud in the balanced dataset 141042/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 141337/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 141632/199008
# New synthetic data generated 296
# Number of fraud in the balanced dataset 141928/199008
# New synthetic data generated 298
# Number of fraud in the balanced dataset 142226/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 142520/199008
# New synthetic data generated 298
# Number of fraud in the balanced dataset 142818/199008
# New synthetic data generated 290
# Number of fraud in the balanced dataset 143108/199008
# New synthetic data generated 296
# Number of fraud in the balanced dataset 143404/199008
# New synthetic data generated 293
# Number of fraud in the balanced dataset 143697/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 143992/199008
# New synthetic data generated 298
# Number of fraud in the balanced dataset 144290/199008
# New synthetic data generated 296
# Number of fraud in the balanced dataset 144586/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 144881/199008
# New synthetic data generated 296
# Number of fraud in the balanced dataset 145177/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 145472/199008
# New synthetic data generated 298
# Number of fraud in the balanced dataset 145770/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 146064/199008
# New synthetic data generated 297
# Number of fraud in the balanced dataset 146361/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 146656/199008
# New synthetic data generated 299
# Number of fraud in the balanced dataset 146955/199008
# New synthetic data generated 297
# Number of fraud in the balanced dataset 147252/199008
# New synthetic data generated 297
# Number of fraud in the balanced dataset 147549/199008
# New synthetic data generated 296
# Number of fraud in the balanced dataset 147845/199008
# New synthetic data generated 296
# Number of fraud in the balanced dataset 148141/199008
# New synthetic data generated 296
# Number of fraud in the balanced dataset 148437/199008
# New synthetic data generated 298
# Number of fraud in the balanced dataset 148735/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 149029/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 149324/199008
# New synthetic data generated 296
# Number of fraud in the balanced dataset 149620/199008
# New synthetic data generated 297
# Number of fraud in the balanced dataset 149917/199008
# New synthetic data generated 299
# Number of fraud in the balanced dataset 150216/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 150510/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 150804/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 151098/199008
# New synthetic data generated 296
# Number of fraud in the balanced dataset 151394/199008
# New synthetic data generated 293
# Number of fraud in the balanced dataset 151687/199008
# New synthetic data generated 298
# Number of fraud in the balanced dataset 151985/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 152280/199008
# New synthetic data generated 293
# Number of fraud in the balanced dataset 152573/199008
# New synthetic data generated 293
# Number of fraud in the balanced dataset 152866/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 153161/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 153456/199008
# New synthetic data generated 297
# Number of fraud in the balanced dataset 153753/199008
# New synthetic data generated 293
# Number of fraud in the balanced dataset 154046/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 154341/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 154636/199008
# New synthetic data generated 292
# Number of fraud in the balanced dataset 154928/199008
# New synthetic data generated 299
# Number of fraud in the balanced dataset 155227/199008
# New synthetic data generated 298
# Number of fraud in the balanced dataset 155525/199008
# New synthetic data generated 297
# Number of fraud in the balanced dataset 155822/199008
# New synthetic data generated 296
# Number of fraud in the balanced dataset 156118/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 156413/199008
# New synthetic data generated 297
# Number of fraud in the balanced dataset 156710/199008
# New synthetic data generated 297
# Number of fraud in the balanced dataset 157007/199008
# New synthetic data generated 300
# Number of fraud in the balanced dataset 157307/199008
# New synthetic data generated 296
# Number of fraud in the balanced dataset 157603/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 157897/199008
# New synthetic data generated 297
# Number of fraud in the balanced dataset 158194/199008
# New synthetic data generated 296
# Number of fraud in the balanced dataset 158490/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 158785/199008
# New synthetic data generated 296
# Number of fraud in the balanced dataset 159081/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 159376/199008
# New synthetic data generated 297
# Number of fraud in the balanced dataset 159673/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 159967/199008
# New synthetic data generated 299
# Number of fraud in the balanced dataset 160266/199008
# New synthetic data generated 296
# Number of fraud in the balanced dataset 160562/199008
# New synthetic data generated 293
# Number of fraud in the balanced dataset 160855/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 161150/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 161444/199008
# New synthetic data generated 297
# Number of fraud in the balanced dataset 161741/199008
# New synthetic data generated 298
# Number of fraud in the balanced dataset 162039/199008
# New synthetic data generated 292
# Number of fraud in the balanced dataset 162331/199008
# New synthetic data generated 299
# Number of fraud in the balanced dataset 162630/199008
# New synthetic data generated 298
# Number of fraud in the balanced dataset 162928/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 163222/199008
# New synthetic data generated 293
# Number of fraud in the balanced dataset 163515/199008
# New synthetic data generated 292
# Number of fraud in the balanced dataset 163807/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 164101/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 164395/199008
# New synthetic data generated 298
# Number of fraud in the balanced dataset 164693/199008
# New synthetic data generated 296
# Number of fraud in the balanced dataset 164989/199008
# New synthetic data generated 297
# Number of fraud in the balanced dataset 165286/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 165580/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 165875/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 166170/199008
# New synthetic data generated 296
# Number of fraud in the balanced dataset 166466/199008
# New synthetic data generated 297
# Number of fraud in the balanced dataset 166763/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 167057/199008
# New synthetic data generated 293
# Number of fraud in the balanced dataset 167350/199008
# New synthetic data generated 298
# Number of fraud in the balanced dataset 167648/199008
# New synthetic data generated 299
# Number of fraud in the balanced dataset 167947/199008
# New synthetic data generated 296
# Number of fraud in the balanced dataset 168243/199008
# New synthetic data generated 291
# Number of fraud in the balanced dataset 168534/199008
# New synthetic data generated 300
# Number of fraud in the balanced dataset 168834/199008
# New synthetic data generated 297
# Number of fraud in the balanced dataset 169131/199008
# New synthetic data generated 292
# Number of fraud in the balanced dataset 169423/199008
# New synthetic data generated 297
# Number of fraud in the balanced dataset 169720/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 170015/199008
# New synthetic data generated 293
# Number of fraud in the balanced dataset 170308/199008
# New synthetic data generated 296
# Number of fraud in the balanced dataset 170604/199008
# New synthetic data generated 293
# Number of fraud in the balanced dataset 170897/199008
# New synthetic data generated 298
# Number of fraud in the balanced dataset 171195/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 171490/199008
# New synthetic data generated 296
# Number of fraud in the balanced dataset 171786/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 172081/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 172376/199008
# New synthetic data generated 296
# Number of fraud in the balanced dataset 172672/199008
# New synthetic data generated 297
# Number of fraud in the balanced dataset 172969/199008
# New synthetic data generated 297
# Number of fraud in the balanced dataset 173266/199008
# New synthetic data generated 298
# Number of fraud in the balanced dataset 173564/199008
# New synthetic data generated 292
# Number of fraud in the balanced dataset 173856/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 174150/199008
# New synthetic data generated 296
# Number of fraud in the balanced dataset 174446/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 174741/199008
# New synthetic data generated 297
# Number of fraud in the balanced dataset 175038/199008
# New synthetic data generated 298
# Number of fraud in the balanced dataset 175336/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 175630/199008
# New synthetic data generated 292
# Number of fraud in the balanced dataset 175922/199008
# New synthetic data generated 298
# Number of fraud in the balanced dataset 176220/199008
# New synthetic data generated 298
# Number of fraud in the balanced dataset 176518/199008
# New synthetic data generated 297
# Number of fraud in the balanced dataset 176815/199008
# New synthetic data generated 296
# Number of fraud in the balanced dataset 177111/199008
# New synthetic data generated 299
# Number of fraud in the balanced dataset 177410/199008
# New synthetic data generated 297
# Number of fraud in the balanced dataset 177707/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 178002/199008
# New synthetic data generated 297
# Number of fraud in the balanced dataset 178299/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 178593/199008
# New synthetic data generated 296
# Number of fraud in the balanced dataset 178889/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 179183/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 179478/199008
# New synthetic data generated 290
# Number of fraud in the balanced dataset 179768/199008
# New synthetic data generated 298
# Number of fraud in the balanced dataset 180066/199008
# New synthetic data generated 298
# Number of fraud in the balanced dataset 180364/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 180658/199008
# New synthetic data generated 290
# Number of fraud in the balanced dataset 180948/199008
# New synthetic data generated 292
# Number of fraud in the balanced dataset 181240/199008
# New synthetic data generated 297
# Number of fraud in the balanced dataset 181537/199008
# New synthetic data generated 296
# Number of fraud in the balanced dataset 181833/199008
# New synthetic data generated 298
# Number of fraud in the balanced dataset 182131/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 182425/199008
# New synthetic data generated 296
# Number of fraud in the balanced dataset 182721/199008
# New synthetic data generated 293
# Number of fraud in the balanced dataset 183014/199008
# New synthetic data generated 296
# Number of fraud in the balanced dataset 183310/199008
# New synthetic data generated 299
# Number of fraud in the balanced dataset 183609/199008
# New synthetic data generated 297
# Number of fraud in the balanced dataset 183906/199008
# New synthetic data generated 292
# Number of fraud in the balanced dataset 184198/199008
# New synthetic data generated 296
# Number of fraud in the balanced dataset 184494/199008
# New synthetic data generated 299
# Number of fraud in the balanced dataset 184793/199008
# New synthetic data generated 296
# Number of fraud in the balanced dataset 185089/199008
# New synthetic data generated 288
# Number of fraud in the balanced dataset 185377/199008
# New synthetic data generated 298
# Number of fraud in the balanced dataset 185675/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 185970/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 186264/199008
# New synthetic data generated 296
# Number of fraud in the balanced dataset 186560/199008
# New synthetic data generated 297
# Number of fraud in the balanced dataset 186857/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 187152/199008
# New synthetic data generated 297
# Number of fraud in the balanced dataset 187449/199008
# New synthetic data generated 298
# Number of fraud in the balanced dataset 187747/199008
# New synthetic data generated 297
# Number of fraud in the balanced dataset 188044/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 188339/199008
# New synthetic data generated 297
# Number of fraud in the balanced dataset 188636/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 188930/199008
# New synthetic data generated 299
# Number of fraud in the balanced dataset 189229/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 189524/199008
# New synthetic data generated 296
# Number of fraud in the balanced dataset 189820/199008
# New synthetic data generated 296
# Number of fraud in the balanced dataset 190116/199008
# New synthetic data generated 293
# Number of fraud in the balanced dataset 190409/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 190703/199008
# New synthetic data generated 293
# Number of fraud in the balanced dataset 190996/199008
# New synthetic data generated 297
# Number of fraud in the balanced dataset 191293/199008
# New synthetic data generated 296
# Number of fraud in the balanced dataset 191589/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 191883/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 192178/199008
# New synthetic data generated 298
# Number of fraud in the balanced dataset 192476/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 192770/199008
# New synthetic data generated 293
# Number of fraud in the balanced dataset 193063/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 193358/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 193653/199008
# New synthetic data generated 298
# Number of fraud in the balanced dataset 193951/199008
# New synthetic data generated 291
# Number of fraud in the balanced dataset 194242/199008
# New synthetic data generated 298
# Number of fraud in the balanced dataset 194540/199008
# New synthetic data generated 298
# Number of fraud in the balanced dataset 194838/199008
# New synthetic data generated 298
# Number of fraud in the balanced dataset 195136/199008
# New synthetic data generated 296
# Number of fraud in the balanced dataset 195432/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 195726/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 196020/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 196315/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 196610/199008
# New synthetic data generated 294
# Number of fraud in the balanced dataset 196904/199008
# New synthetic data generated 298
# Number of fraud in the balanced dataset 197202/199008
# New synthetic data generated 298
# Number of fraud in the balanced dataset 197500/199008
# New synthetic data generated 297
# Number of fraud in the balanced dataset 197797/199008
# New synthetic data generated 296
# Number of fraud in the balanced dataset 198093/199008
# New synthetic data generated 295
# Number of fraud in the balanced dataset 198388/199008
# New synthetic data generated 297
# Number of fraud in the balanced dataset 198685/199008
# New synthetic data generated 298
# Number of fraud in the balanced dataset 198983/199008
# New synthetic data generated 296
# Number of fraud in the balanced dataset 199279/199008
# (398287, 31)
# Number of fraud in the balanced dataset 199279
# Number of non-fraud in the balanced dataset 199008

# %%
class Attention(nn.Module):
    def __init__(self, input_dim):
        super(Attention, self).__init__()
        self.attention_weights = nn.Linear(input_dim, 1, bias=False)  # Learnable attention weights

    def forward(self, lstm_output):
        # Compute attention scores (softmax over time dimension)
        attention_scores = torch.softmax(self.attention_weights(lstm_output), dim=1)  
        weighted_output = lstm_output * attention_scores  # Apply attention
        return torch.sum(weighted_output, dim=1)  # Sum over sequence length (time steps)

# %%
class ALSTM(nn.Module):
    def __init__(self, input_dim, hidden_dim):
        super(ALSTM, self).__init__()
        self.lstm = nn.LSTM(input_dim, hidden_dim, batch_first=True)  # Forward LSTM
        self.attention = Attention(hidden_dim)  # Attention Layer
        self.fc = nn.Linear(hidden_dim, 1)  # Fully connected output layer
        self.sigmoid = nn.Sigmoid()  # Sigmoid activation for binary classification

    def forward(self, x):
        lstm_output, _ = self.lstm(x)  # Get LSTM output
        attention_out = self.attention(lstm_output)  # Apply attention
        output = self.fc(attention_out)  # Fully connected layer
        return self.sigmoid(output)  # Sigmoid activation for probability output

# %%
# split data_train_oversampled in 20-80 split test-train
data_oversampled_labels = data_train_oversampled[:, -1]
data_train_oversampled = data_train_oversampled[:, :-1]
data_reshaped = data_train_oversampled.reshape(data_train_oversampled.shape[0], 1, data_train_oversampled.shape[1])

# Convert to PyTorch tensors
X_tensor = torch.tensor(data_reshaped, dtype=torch.float32)
y_tensor = torch.tensor(data_oversampled_labels, dtype=torch.float32)

# Split into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X_tensor, y_tensor, test_size=0.2, random_state=42)

# Create DataLoader for PyTorch
train_dataset = TensorDataset(X_train, y_train)
test_dataset = TensorDataset(X_test, y_test)

train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=32, shuffle=False)

# %%
input_dim = data_reshaped.shape[2]  # Number of features per transaction
hidden_dim = 128 # da cercare il valore migliore

# Initialize model, loss function, and optimizer
ALSTMmodel = ALSTM(input_dim, hidden_dim)
criterion = nn.BCELoss()  # Binary Cross Entropy for classification
optimizer = torch.optim.Adam(ALSTMmodel.parameters(), lr=0.001)

# Move model to GPU if available
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
ALSTMmodel.to(device)
# Out:
# ALSTM(
#   (lstm): LSTM(30, 128, batch_first=True)
#   (attention): Attention(
#     (attention_weights): Linear(in_features=128, out_features=1, bias=False)
#   )
#   (fc): Linear(in_features=128, out_features=1, bias=True)
#   (sigmoid): Sigmoid()
# )

# %%
def train_ALSTM(model, train_loader, residual):
    num_epochs = 10
    for epoch in range(num_epochs):
        model.train()
        epoch_loss = 0

        for X_batch, _ in train_loader:
            # transform residual in tensor
            residual = torch.tensor(residual, dtype=torch.float32)
            X_batch, residual = X_batch.to(device), residual.to(device)

            optimizer.zero_grad()  # Reset gradients
            y_pred = model(X_batch).squeeze()
        
            loss = criterion(y_pred, residual)  # Compute loss
            loss.backward()  # Backpropagation
            optimizer.step()  # Update weights

            epoch_loss += loss.item()
    
        print(f"Epoch [{epoch+1}/{num_epochs}], Loss: {epoch_loss:.4f}")
        
    return model

# %%
def loss(y, y_hat):
    return 1/2 * np.sum((y - y_hat)**2)

# %%
h_x = loss(data_oversampled_labels, 0)

for _ in range(6):

    residual = (data_oversampled_labels - h_x)
    ALSTMmodel = train_ALSTM(ALSTMmodel, train_loader, residual)
    y_pred = ALSTMmodel(train_loader).squeeze().detach().numpy()
    step_length = np.argmin(loss(data_oversampled_labels, h_x + step_length * y_pred))
    h_x += step_length * y_pred
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[14], line 6
#       3 for _ in range(6):
#       5     residual = (data_oversampled_labels - h_x)
# ----> 6     ALSTMmodel = train_ALSTM(ALSTMmodel, train_loader, residual)
#       7     y_pred = ALSTMmodel(train_loader).squeeze().detach().numpy()
#       8     step_length = np.argmin(loss(data_oversampled_labels, h_x + step_length * y_pred))
#
# Cell In[12], line 15, in train_ALSTM(model, train_loader, residual)
#      12 optimizer.zero_grad()  # Reset gradients
#      13 y_pred = model(X_batch).squeeze()
# ---> 15 loss = criterion(y_pred, residual)  # Compute loss
#      16 loss.backward()  # Backpropagation
#      17 optimizer.step()  # Update weights
#
# File c:\Users\nicco\AppData\Local\Programs\Python\Python313\Lib\site-packages\torch\nn\modules\module.py:1739, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1737     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738 else:
# -> 1739     return self._call_impl(*args, **kwargs)
#
# File c:\Users\nicco\AppData\Local\Programs\Python\Python313\Lib\site-packages\torch\nn\modules\module.py:1750, in Module._call_impl(self, *args, **kwargs)
#    1745 # If we don't have any hooks, we want to skip the rest of the logic in
#    1746 # this function, and just call forward.
#    1747 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1748         or _global_backward_pre_hooks or _global_backward_hooks
#    1749         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750     return forward_call(*args, **kwargs)
#    1752 result = None
#    1753 called_always_called_hooks = set()
#
# File c:\Users\nicco\AppData\Local\Programs\Python\Python313\Lib\site-packages\torch\nn\modules\loss.py:699, in BCELoss.forward(self, input, target)
#     698 def forward(self, input: Tensor, target: Tensor) -> Tensor:
# --> 699     return F.binary_cross_entropy(
#     700         input, target, weight=self.weight, reduction=self.reduction
#     701     )
#
# File c:\Users\nicco\AppData\Local\Programs\Python\Python313\Lib\site-packages\torch\nn\functional.py:3560, in binary_cross_entropy(input, target, weight, size_average, reduce, reduction)
#    3558     reduction_enum = _Reduction.get_enum(reduction)
#    3559 if target.size() != input.size():
# -> 3560     raise ValueError(
#    3561         f"Using a target size ({target.size()}) that is different to the input size ({input.size()}) is deprecated. "
#    3562         "Please ensure they have the same size."
#    3563     )
#    3565 if weight is not None:
#    3566     new_size = _infer_size(target.size(), weight.size())
#
# ValueError: Using a target size (torch.Size([398287])) that is different to the input size (torch.Size([32])) is deprecated. Please ensure they have the same size.

# %%
ALSTMmodel.eval()  # Set model to evaluation mode

correct = 0
total = 0

with torch.no_grad():  # No gradients needed for evaluation
    for X_batch, y_batch in test_loader:
        X_batch, y_batch = X_batch.to(device), y_batch.to(device)
        y_pred = ALSTMmodel(X_batch).squeeze()
        y_pred_labels = (y_pred > 0.5).float()  # Convert probabilities to binary labels
        
        correct += (y_pred_labels == y_batch).sum().item()
        total += y_batch.size(0)

accuracy = correct / total
print(f"Test Accuracy: {accuracy:.4f}")
