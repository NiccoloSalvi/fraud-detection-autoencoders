# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset
from sklearn.preprocessing import MinMaxScaler, StandardScaler, RobustScaler
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
# -----------------------------
# 1. Load and preprocess dataset
# -----------------------------
data = pd.read_csv('creditcard.csv')
data['Amount'] = RobustScaler().fit_transform(data['Amount'].values.reshape(-1, 1))
data['Time'] = RobustScaler().fit_transform(data['Time'].values.reshape(-1, 1))
data = data.drop(['Time'], axis=1)

dataset = data.to_numpy().astype(np.float32)

# divide the samples and the labels
X = dataset[:, :-1]
y = dataset[:, -1]

# %%
# generate a pie chart to visualize the distribution of fraud vs. legitimate transactions
# we see how fraud transactions are much less than legitimate ones

fraud_count = np.bincount(y.astype(int))

labels = ["Legit", "Fraud"]
colors = ["blue", "red"]

# Plotting as a pie chart
plt.figure(figsize=(6, 6))
plt.pie(fraud_count, labels=labels, colors=colors, autopct="%1.1f%%", startangle=90, shadow=False)
plt.title("Fraud vs. Legitimate Transactions")
plt.axis("equal")  # Equal aspect ratio to ensure the pie is circular
plt.show()

# %%
# Split entire dataset into train and test
data_train, data_test, label_train, label_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
# -----------------------------
# 3. Define the Autoencoder Model
# -----------------------------
class Autoencoder(nn.Module):
    def __init__(self):
        super(Autoencoder, self).__init__()
        # Encoder: 29 -> 23 -> 19 -> 17 -> 8
        self.encoder = nn.Sequential(
            nn.Linear(29, 23),
            nn.LeakyReLU(0.2),
            nn.Dropout(0.1),
            nn.Linear(23, 19),
            nn.LeakyReLU(0.2),
            nn.Dropout(0.2),
            nn.Linear(19, 17),
            nn.LeakyReLU(),
            nn.Linear(17, 8)
        )
        # Decoder: 8 -> 17 -> 19 -> 23 -> 29 with Sigmoid at the end
        # (Sigmoid is generally optional if you are using MSELoss and inputs are not strictly [0,1])
        self.decoder = nn.Sequential(
            nn.Linear(8, 17),
            nn.LeakyReLU(0.2),
            nn.Dropout(0.2),
            nn.Linear(17, 19),
            nn.LeakyReLU(0.2),
            nn.Dropout(0.1),
            nn.Linear(19, 23),
            nn.LeakyReLU(0.2),
            nn.Linear(23, 29)
        )

    def forward(self, x):
        latent = self.encoder(x)
        reconstructed = self.decoder(latent)
        return reconstructed

# %%
# -----------------------------
# 1. Extract fraud samples using label_train (1 = fraud)
# -----------------------------
# data_train and label_train are assumed to be already defined from your previous splitting.
data_train_fraud = data_train[label_train == 1]

# -----------------------------
# 2. Train/Validation Split (80-20) on the fraud samples
# -----------------------------
data_train_autoencoder, test_data_autoencoder = train_test_split(data_train_fraud, test_size=0.2, random_state=32)

print(data_train_autoencoder.shape)
# Convert numpy arrays to PyTorch tensors (ensure float type)
tensor_fraud_train = torch.from_numpy(data_train_autoencoder).float()
tensor_fraud_val   = torch.from_numpy(test_data_autoencoder).float()

# For an autoencoder, input equals target
train_dataset = TensorDataset(tensor_fraud_train, tensor_fraud_train)
val_dataset   = TensorDataset(tensor_fraud_val, tensor_fraud_val)

batch_size = 128
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
val_loader   = DataLoader(val_dataset,   batch_size=batch_size, shuffle=False)

# -----------------------------
# 4. Initialize Model, Loss, Optimizer, and Scheduler
# -----------------------------
my_autoencoder = Autoencoder().to(device)
criterion = nn.MSELoss()  # Using MSELoss now
optimizer = optim.Adam(my_autoencoder.parameters(), lr=2e-4)
scheduler = optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=500, eta_min=1e-6)

# -----------------------------
# 5. Training Loop with L1 Regularization and Validation Evaluation
# -----------------------------
num_epochs = 2000
history_loss_train = []
history_loss_val   = []
patience = 75
best_val_loss = float('inf')
patience_counter = 0
best_model_state = None

l1_lambda = 1e-3  # L1 regularization strength

for epoch in range(num_epochs):
    my_autoencoder.train()
    running_loss_train = 0.0
    for batch_x, _ in train_loader:
        inputs = batch_x.to(device)
        optimizer.zero_grad()
        outputs = my_autoencoder(inputs)
        loss = criterion(outputs, inputs)
        
        # Compute L1 norm of the model parameters
        #l1_norm = sum(p.abs().sum() for p in my_autoencoder.parameters())
        #loss = loss + l1_lambda * l1_norm
        
        loss.backward()
        optimizer.step()
        running_loss_train += loss.item() * inputs.size(0)
    
    epoch_loss_train = running_loss_train / len(train_loader.dataset)
    history_loss_train.append(epoch_loss_train)

    # --- Validation Phase ---
    my_autoencoder.eval()
    running_loss_val = 0.0
    with torch.no_grad():
        for batch_x, _ in val_loader:
            inputs = batch_x.to(device)
            outputs = my_autoencoder(inputs)
            loss = criterion(outputs, inputs)
            running_loss_val += loss.item() * inputs.size(0)
    epoch_loss_val = running_loss_val / len(val_loader.dataset)
    history_loss_val.append(epoch_loss_val)

    # Early stopping check
    if epoch_loss_val < best_val_loss:
        best_val_loss = epoch_loss_val
        best_model_state = my_autoencoder.state_dict()
        patience_counter = 0
    else:
        patience_counter += 1
    if patience_counter >= patience:
        print(f"Early stopping at epoch {epoch}")
        my_autoencoder.load_state_dict(best_model_state)
        break

    # Optionally step the scheduler
    # scheduler.step()

    if epoch % 50 == 0:
        print(f"Epoch {epoch}, Train Loss: {epoch_loss_train:.4f}, Val Loss: {epoch_loss_val:.4f}")

# Save the model
torch.save(my_autoencoder.state_dict(), "autoencoder.pth")

# -----------------------------
# 6. Plot Training & Validation Loss
# -----------------------------
plt.figure()
plt.plot(history_loss_train, label='Train Loss')
plt.plot(history_loss_val, label='Validation Loss')
plt.xlabel("Epoch")
plt.ylabel("Loss (Log Scale)")
plt.title("Training and Validation Loss")
plt.yscale('log')
plt.legend()
plt.show()
# Out:
# (284, 29)
# Epoch 0, Train Loss: 24.4979, Val Loss: 29.9473
# Epoch 50, Train Loss: 20.7823, Val Loss: 24.8268
# Epoch 100, Train Loss: 7.8173, Val Loss: 8.0613
# Epoch 150, Train Loss: 7.0770, Val Loss: 7.5245
# Epoch 200, Train Loss: 6.7603, Val Loss: 7.3282
# Epoch 250, Train Loss: 7.0104, Val Loss: 7.3353
# Epoch 300, Train Loss: 6.4864, Val Loss: 7.3461
# Epoch 350, Train Loss: 6.2441, Val Loss: 7.3131
# Epoch 400, Train Loss: 6.2072, Val Loss: 7.2235
# Epoch 450, Train Loss: 6.0840, Val Loss: 7.2771
# Early stopping at epoch 493

# %%
my_autoencoder.eval()
train_mse_loss = 0.0
with torch.no_grad():
    for batch_x, _ in train_loader:
        inputs = batch_x.to(device)
        outputs = my_autoencoder(inputs)
        loss = criterion(outputs, inputs)
        train_mse_loss += loss.item() * inputs.size(0)
train_mse_loss /= len(train_loader.dataset)
print(f"Epoch {epoch}, Train MSE Loss (no L1): {train_mse_loss:.4f}")
# Out:
# Epoch 493, Train MSE Loss (no L1): 5.4878

# %%
# create the balanced dataset to train the SVM model
data_train_non_fraud = data_train[label_train == 0][:len(data_train_fraud)]

# Combine the selected data
X_balanced_SVM = np.vstack((data_train_non_fraud, data_train_fraud))
y_balanced_SVM = np.hstack((np.zeros(len(data_train_fraud)), np.ones(len(data_train_fraud))))  # Create labels: 0 for non-fraud, 1 for fraud

# Shuffle the data
shuffle_idx = np.random.permutation(len(X_balanced_SVM))
X_balanced_SVM = X_balanced_SVM[shuffle_idx]
y_balanced_SVM = y_balanced_SVM[shuffle_idx]

# Split into training and test sets for SVM
data_train_SVM, data_test_SVM, label_train_SVM, label_test_SVM = train_test_split(X_balanced_SVM, y_balanced_SVM, test_size=0.2, random_state=42)

# Train SVM model for validation in the oversampling process
my_svm = SVC(kernel='linear', C=1.0)
my_svm.fit(data_train_SVM, label_train_SVM)

# Get predictions and accuracy
label_pred_test = my_svm.predict(data_test_SVM)
label_pred_train = my_svm.predict(data_train_SVM)
accuracy_train = np.mean(label_pred_train == label_train_SVM)
accuracy_test = np.mean(label_pred_test == label_test_SVM)

print(f"Train Accuracy: {accuracy_train:.4f}")
print(f"Test Accuracy: {accuracy_test:.4f}")
# Out:
# Train Accuracy: 0.9490
# Test Accuracy: 0.9161

# %%
def get_fraud_indices(labels):
    """Return indices for which label == 1."""
    return np.where(labels == 1)[0]

def get_legit_indices(labels):
    """Return indices for which label == 0."""
    return np.where(labels == 0)[0]

# Example: placeholders for data_train, y_train
# data_train = np.random.randn(100, 30)
# y_train    = np.random.randint(0, 2, size=100)

# Make your copies to oversample
oversampled_data = data_train.copy()
oversampled_labels = label_train.copy()

# For oversampling, we want to add synthetic fraud samples until fraud count equals non-fraud count.
non_fraud_count = np.sum(oversampled_labels == 0)
fraud_count = np.sum(oversampled_labels == 1)
print(f"Initial counts - Fraud: {fraud_count}, Non-fraud: {non_fraud_count}")

# Number of synthetic samples to generate per iteration and noise std
n_samples_per_iter = 300

# Use only the original fraud samples (from the training set) as the basis for synthetic data generation.
original_fraud_data = data_train[label_train == 1]
original_fraud_data_tensor = torch.tensor(original_fraud_data, dtype=torch.float32)

# Ensure the autoencoder is in evaluation mode
my_autoencoder.eval()

alpha = 0.9

while len(get_fraud_indices(oversampled_labels)) < len(get_legit_indices(oversampled_labels)):
    fraud_indices = get_fraud_indices(oversampled_labels)
    legit_count = len(get_legit_indices(oversampled_labels))
    fraud_count = len(fraud_indices)
    remaining_needed = legit_count - fraud_count

    if fraud_count == 0:
        print("No fraud data found. Cannot proceed with oversampling.")
        break

    # 1) Gather all fraud samples
    fraud_only_X = oversampled_data[fraud_indices, :]
    fraud_data_tensor = torch.tensor(fraud_only_X, dtype=torch.float32)

    # 2) Encode to latent space
    latent_representations = my_autoencoder.encoder(fraud_data_tensor)
    n = len(latent_representations)
    if n == 0:
        print("Error: no latent representations. Check input data.")
        break

    # 3) Interpolate in latent space + add noise
    noisy_vectors = []
    for _ in range(300):  # You can reduce this if too many are generated
        i = np.random.randint(0, n)
        j = np.random.randint(0, n)

        z_i = latent_representations[i]
        z_j = latent_representations[j]

        lambda_ = np.random.rand()
        z_ij = lambda_ * z_i + (1 - lambda_) * z_j

        noise = torch.normal(mean=0.0, std=alpha, size=z_ij.shape)
        z_syn = z_ij + noise

        noisy_vectors.append(z_syn.detach().cpu().numpy())

    noisy_vectors = np.array(noisy_vectors)
    
    #latent_reps = np.array(noisy_vectors.detach().cpu().numpy())
    # 4) Decode to original 30-dim space
    X_synthetic = my_autoencoder.decoder(    torch.tensor(noisy_vectors, dtype=torch.float32)).detach().cpu().numpy()
    
    #with torch.no_grad():
        #X_synthetic = my_autoencoder(original_fraud_data_tensor).cpu().numpy()
    # 5) Classify with SVM
    y_pred = my_svm.predict(X_synthetic)

    # 6) Keep only predicted fraud
    synthetic_fraud_mask = (y_pred == 1)
    X_synthetic_fraud = X_synthetic[synthetic_fraud_mask]
    y_synthetic_fraud = y_pred[synthetic_fraud_mask]

    # 7) Limit the number of fraud samples added to only what is needed
    max_add = min(len(X_synthetic_fraud), remaining_needed)
    if max_add <= 0:
        break  # done

    oversampled_data = np.vstack((oversampled_data, X_synthetic_fraud[:max_add]))
    oversampled_labels = np.hstack((oversampled_labels, y_synthetic_fraud[:max_add]))

    n_fraud = len(get_fraud_indices(oversampled_labels))
    n_legit = len(get_legit_indices(oversampled_labels))
    print(f"Added {max_add} synthetic fraud samples")
    print(f"Fraud / Legit count: {n_fraud} / {n_legit}")

print("\nFinal shape of data:", oversampled_data.shape)
print("Final # Fraud:", len(get_fraud_indices(oversampled_labels)))
print("Final # Legit:", len(get_legit_indices(oversampled_labels)))

# Save the balanced data
np.save("data_train_balanced.npy", oversampled_data)
np.save("y_train_balanced.npy", oversampled_labels)
# Out:
# Initial counts - Fraud: 356, Non-fraud: 199008
# Added 286 synthetic fraud samples
# Fraud / Legit count: 642 / 199008
# Added 294 synthetic fraud samples
# Fraud / Legit count: 936 / 199008
# Added 294 synthetic fraud samples
# Fraud / Legit count: 1230 / 199008
# Added 297 synthetic fraud samples
# Fraud / Legit count: 1527 / 199008
# Added 299 synthetic fraud samples
# Fraud / Legit count: 1826 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 2126 / 199008
# Added 296 synthetic fraud samples
# Fraud / Legit count: 2422 / 199008
# Added 299 synthetic fraud samples
# Fraud / Legit count: 2721 / 199008
# Added 299 synthetic fraud samples
# Fraud / Legit count: 3020 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 3320 / 199008
# Added 299 synthetic fraud samples
# Fraud / Legit count: 3619 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 3919 / 199008
# Added 299 synthetic fraud samples
# Fraud / Legit count: 4218 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 4518 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 4818 / 199008
# Added 299 synthetic fraud samples
# Fraud / Legit count: 5117 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 5417 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 5717 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 6017 / 199008
# Added 299 synthetic fraud samples
# Fraud / Legit count: 6316 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 6616 / 199008
# Added 299 synthetic fraud samples
# Fraud / Legit count: 6915 / 199008
# Added 298 synthetic fraud samples
# Fraud / Legit count: 7213 / 199008
# Added 299 synthetic fraud samples
# Fraud / Legit count: 7512 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 7812 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 8112 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 8412 / 199008
# Added 299 synthetic fraud samples
# Fraud / Legit count: 8711 / 199008
# Added 299 synthetic fraud samples
# Fraud / Legit count: 9010 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 9310 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 9610 / 199008
# Added 299 synthetic fraud samples
# Fraud / Legit count: 9909 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 10209 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 10509 / 199008
# Added 299 synthetic fraud samples
# Fraud / Legit count: 10808 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 11108 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 11408 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 11708 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 12008 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 12308 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 12608 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 12908 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 13208 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 13508 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 13808 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 14108 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 14408 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 14708 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 15008 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 15308 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 15608 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 15908 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 16208 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 16508 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 16808 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 17108 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 17408 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 17708 / 199008
# Added 298 synthetic fraud samples
# Fraud / Legit count: 18006 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 18306 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 18606 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 18906 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 19206 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 19506 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 19806 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 20106 / 199008
# Added 299 synthetic fraud samples
# Fraud / Legit count: 20405 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 20705 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 21005 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 21305 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 21605 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 21905 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 22205 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 22505 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 22805 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 23105 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 23405 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 23705 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 24005 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 24305 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 24605 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 24905 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 25205 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 25505 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 25805 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 26105 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 26405 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 26705 / 199008
# Added 299 synthetic fraud samples
# Fraud / Legit count: 27004 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 27304 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 27604 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 27904 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 28204 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 28504 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 28804 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 29104 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 29404 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 29704 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 30004 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 30304 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 30604 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 30904 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 31204 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 31504 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 31804 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 32104 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 32404 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 32704 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 33004 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 33304 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 33604 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 33904 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 34204 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 34504 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 34804 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 35104 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 35404 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 35704 / 199008
# Added 299 synthetic fraud samples
# Fraud / Legit count: 36003 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 36303 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 36603 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 36903 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 37203 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 37503 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 37803 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 38103 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 38403 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 38703 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 39003 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 39303 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 39603 / 199008
# Added 299 synthetic fraud samples
# Fraud / Legit count: 39902 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 40202 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 40502 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 40802 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 41102 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 41402 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 41702 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 42002 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 42302 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 42602 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 42902 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 43202 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 43502 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 43802 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 44102 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 44402 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 44702 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 45002 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 45302 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 45602 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 45902 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 46202 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 46502 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 46802 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 47102 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 47402 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 47702 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 48002 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 48302 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 48602 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 48902 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 49202 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 49502 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 49802 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 50102 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 50402 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 50702 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 51002 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 51302 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 51602 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 51902 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 52202 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 52502 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 52802 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 53102 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 53402 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 53702 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 54002 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 54302 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 54602 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 54902 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 55202 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 55502 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 55802 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 56102 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 56402 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 56702 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 57002 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 57302 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 57602 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 57902 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 58202 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 58502 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 58802 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 59102 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 59402 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 59702 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 60002 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 60302 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 60602 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 60902 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 61202 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 61502 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 61802 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 62102 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 62402 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 62702 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 63002 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 63302 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 63602 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 63902 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 64202 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 64502 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 64802 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 65102 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 65402 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 65702 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 66002 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 66302 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 66602 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 66902 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 67202 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 67502 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 67802 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 68102 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 68402 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 68702 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 69002 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 69302 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 69602 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 69902 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 70202 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 70502 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 70802 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 71102 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 71402 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 71702 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 72002 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 72302 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 72602 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 72902 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 73202 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 73502 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 73802 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 74102 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 74402 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 74702 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 75002 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 75302 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 75602 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 75902 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 76202 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 76502 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 76802 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 77102 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 77402 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 77702 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 78002 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 78302 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 78602 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 78902 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 79202 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 79502 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 79802 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 80102 / 199008
# Added 299 synthetic fraud samples
# Fraud / Legit count: 80401 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 80701 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 81001 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 81301 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 81601 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 81901 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 82201 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 82501 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 82801 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 83101 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 83401 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 83701 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 84001 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 84301 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 84601 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 84901 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 85201 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 85501 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 85801 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 86101 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 86401 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 86701 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 87001 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 87301 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 87601 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 87901 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 88201 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 88501 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 88801 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 89101 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 89401 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 89701 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 90001 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 90301 / 199008
# Added 299 synthetic fraud samples
# Fraud / Legit count: 90600 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 90900 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 91200 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 91500 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 91800 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 92100 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 92400 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 92700 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 93000 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 93300 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 93600 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 93900 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 94200 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 94500 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 94800 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 95100 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 95400 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 95700 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 96000 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 96300 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 96600 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 96900 / 199008
# Added 299 synthetic fraud samples
# Fraud / Legit count: 97199 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 97499 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 97799 / 199008
# Added 299 synthetic fraud samples
# Fraud / Legit count: 98098 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 98398 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 98698 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 98998 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 99298 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 99598 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 99898 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 100198 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 100498 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 100798 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 101098 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 101398 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 101698 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 101998 / 199008
# Added 299 synthetic fraud samples
# Fraud / Legit count: 102297 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 102597 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 102897 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 103197 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 103497 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 103797 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 104097 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 104397 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 104697 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 104997 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 105297 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 105597 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 105897 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 106197 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 106497 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 106797 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 107097 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 107397 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 107697 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 107997 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 108297 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 108597 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 108897 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 109197 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 109497 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 109797 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 110097 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 110397 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 110697 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 110997 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 111297 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 111597 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 111897 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 112197 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 112497 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 112797 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 113097 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 113397 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 113697 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 113997 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 114297 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 114597 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 114897 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 115197 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 115497 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 115797 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 116097 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 116397 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 116697 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 116997 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 117297 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 117597 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 117897 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 118197 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 118497 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 118797 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 119097 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 119397 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 119697 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 119997 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 120297 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 120597 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 120897 / 199008
# Added 299 synthetic fraud samples
# Fraud / Legit count: 121196 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 121496 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 121796 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 122096 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 122396 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 122696 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 122996 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 123296 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 123596 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 123896 / 199008
# Added 299 synthetic fraud samples
# Fraud / Legit count: 124195 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 124495 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 124795 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 125095 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 125395 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 125695 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 125995 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 126295 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 126595 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 126895 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 127195 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 127495 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 127795 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 128095 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 128395 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 128695 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 128995 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 129295 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 129595 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 129895 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 130195 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 130495 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 130795 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 131095 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 131395 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 131695 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 131995 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 132295 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 132595 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 132895 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 133195 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 133495 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 133795 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 134095 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 134395 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 134695 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 134995 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 135295 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 135595 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 135895 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 136195 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 136495 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 136795 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 137095 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 137395 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 137695 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 137995 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 138295 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 138595 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 138895 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 139195 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 139495 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 139795 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 140095 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 140395 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 140695 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 140995 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 141295 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 141595 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 141895 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 142195 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 142495 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 142795 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 143095 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 143395 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 143695 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 143995 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 144295 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 144595 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 144895 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 145195 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 145495 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 145795 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 146095 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 146395 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 146695 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 146995 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 147295 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 147595 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 147895 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 148195 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 148495 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 148795 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 149095 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 149395 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 149695 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 149995 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 150295 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 150595 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 150895 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 151195 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 151495 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 151795 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 152095 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 152395 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 152695 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 152995 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 153295 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 153595 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 153895 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 154195 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 154495 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 154795 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 155095 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 155395 / 199008
# Added 299 synthetic fraud samples
# Fraud / Legit count: 155694 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 155994 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 156294 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 156594 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 156894 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 157194 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 157494 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 157794 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 158094 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 158394 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 158694 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 158994 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 159294 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 159594 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 159894 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 160194 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 160494 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 160794 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 161094 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 161394 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 161694 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 161994 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 162294 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 162594 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 162894 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 163194 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 163494 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 163794 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 164094 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 164394 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 164694 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 164994 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 165294 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 165594 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 165894 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 166194 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 166494 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 166794 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 167094 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 167394 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 167694 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 167994 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 168294 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 168594 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 168894 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 169194 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 169494 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 169794 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 170094 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 170394 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 170694 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 170994 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 171294 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 171594 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 171894 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 172194 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 172494 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 172794 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 173094 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 173394 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 173694 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 173994 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 174294 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 174594 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 174894 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 175194 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 175494 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 175794 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 176094 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 176394 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 176694 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 176994 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 177294 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 177594 / 199008
# Added 299 synthetic fraud samples
# Fraud / Legit count: 177893 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 178193 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 178493 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 178793 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 179093 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 179393 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 179693 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 179993 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 180293 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 180593 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 180893 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 181193 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 181493 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 181793 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 182093 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 182393 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 182693 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 182993 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 183293 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 183593 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 183893 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 184193 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 184493 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 184793 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 185093 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 185393 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 185693 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 185993 / 199008
# Added 299 synthetic fraud samples
# Fraud / Legit count: 186292 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 186592 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 186892 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 187192 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 187492 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 187792 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 188092 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 188392 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 188692 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 188992 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 189292 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 189592 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 189892 / 199008
# Added 298 synthetic fraud samples
# Fraud / Legit count: 190190 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 190490 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 190790 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 191090 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 191390 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 191690 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 191990 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 192290 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 192590 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 192890 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 193190 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 193490 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 193790 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 194090 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 194390 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 194690 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 194990 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 195290 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 195590 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 195890 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 196190 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 196490 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 196790 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 197090 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 197390 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 197690 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 197990 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 198290 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 198590 / 199008
# Added 300 synthetic fraud samples
# Fraud / Legit count: 198890 / 199008
# Added 118 synthetic fraud samples
# Fraud / Legit count: 199008 / 199008
#
# Final shape of data: (398016, 29)
# Final # Fraud: 199008
# Final # Legit: 199008

# %%
#from imblearn.over_sampling import BorderlineSMOTE, KMeansSMOTE

#borderlineSMOTE = BorderlineSMOTE(random_state=42)

#X_train_with_smote, y_train_with_smote = borderlineSMOTE.fit_resample(data_train, label_train)

#print(X_train_with_smote.shape)

# %%
from tensorflow.keras.layers import LSTM, Dense, Embedding, Dropout, Input, Attention, Layer, Concatenate, Permute, Dot, Multiply, Flatten
from tensorflow.keras.layers import RepeatVector, Activation, Lambda
from tensorflow.keras.models import Model
import tensorflow as tf

class attention(Layer):
    def __init__(self,**kwargs):
        super(attention,self).__init__(**kwargs)

    def build(self,input_shape):
        self.W=self.add_weight(name="att_weight",shape=(input_shape[-1],1),initializer="normal")
        self.b=self.add_weight(name="att_bias",shape=(input_shape[1],1),initializer="zeros")        
        super(attention, self).build(input_shape)

    def call(self,x):
        et=tf.squeeze(tf.tanh(tf.linalg.matmul(x,self.W)+self.b),axis=-1)
        at=tf.nn.softmax(et)
        at=tf.expand_dims(at,axis=-1)
        output=x*at
        return tf.reduce_sum(output,axis=1)

    def compute_output_shape(self,input_shape):
        return (input_shape[0],input_shape[-1])

    def get_config(self):
        return super(attention,self).get_config()

def create_ALSTM_model():
    inputs1=Input((1,29))
    att_in=LSTM(50,return_sequences=True,dropout=0.3,recurrent_dropout=0.2)(inputs1)
    att_in_1=LSTM(50,return_sequences=True,dropout=0.3,recurrent_dropout=0.2)(att_in)
    att_out=attention()(att_in_1)
    outputs1=Dense(1,activation='sigmoid',trainable=True)(att_out)
    model1=Model(inputs1,outputs1)
    
    model1.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

    return model1

# %%
from scipy.optimize import minimize_scalar

# --- Adjusted training function using Keras without a validation dataset ---
def train_model(model, X, y, num_epochs=2, batch_size=128):
    # Ensure X has shape (num_samples, 1, 30)
    if X.ndim == 2:
        X_train = X.reshape(-1, 1, X.shape[1])
    else:
        X_train = X

    # Train the model using Keras' fit without validation monitoring
    history = model.fit(X_train, y, epochs=num_epochs, batch_size=batch_size, verbose=1)
    return model

def GB_classifier(X, y, n_estimators=10):
    estimators = []
    
    # Define squared-error loss (for evaluating the ensemble)
    loss_fn = lambda y_true, y_pred: 0.5 * np.sum((y_true - y_pred)**2)
    
    # Initialize ensemble predictions for training data
    hx = np.full(len(y), 0, dtype=np.float32)
    
    for t in range(n_estimators):
        # Compute training residuals: true labels minus current ensemble predictions
        residuals = y - hx
        
        # Create a new instance of the Keras ALSTM model
        model_t = create_ALSTM_model()
        
        # Train the model on (X, residuals)
        train_model(model_t, X, residuals, num_epochs=2, batch_size=128)
        
        # Predict the current weak learner's output h_t on the training set.
        X_input = X.reshape(-1, 1, X.shape[1]) if X.ndim == 2 else X
        predictions = model_t.predict(X_input)
        h_t = predictions.flatten()
        
        # Use line search to determine the optimal step length alpha
        func = lambda alpha: np.sum(loss_fn(y, hx + alpha * h_t))
        alpha_t = np.float32(minimize_scalar(func, method="golden").x)
        
        # Update the ensemble predictions for training data
        hx += alpha_t * h_t
        
        print(f"a_{t+1} = {alpha_t:.4f}")
        print(f"hx_{t+1} = {hx}")
        
        estimators.append((model_t, alpha_t))
    
    return estimators

# %%
estimators = GB_classifier(oversampled_data, oversampled_labels, n_estimators=6)
# estimators = GB_classifier(X_train_with_smote, y_train_with_smote, n_estimators=6)
# Out:
# Epoch 1/2
# 3110/3110 ━━━━━━━━━━━━━━━━━━━━ 9s 2ms/step - accuracy: 0.9831 - loss: 0.0702
# Epoch 2/2
# 3110/3110 ━━━━━━━━━━━━━━━━━━━━ 7s 2ms/step - accuracy: 0.9996 - loss: 0.0032
# 12438/12438 ━━━━━━━━━━━━━━━━━━━━ 5s 378us/step
# a_1 = 0.9998
# hx_1 = [1.1045380e-05 6.6800079e-05 1.4627178e-05 ... 9.9979925e-01 9.9980116e-01
#  9.9978751e-01]
# Epoch 1/2
# 3110/3110 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - accuracy: 0.0000e+00 - loss: 0.0630
# Epoch 2/2
# 3110/3110 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - accuracy: 0.0000e+00 - loss: 0.0013
# 12438/12438 ━━━━━━━━━━━━━━━━━━━━ 5s 395us/step
# a_2 = 5.0248
# hx_2 = [1.6582471e-05 7.4567120e-05 2.9497305e-05 ... 9.9981648e-01 9.9981868e-01
#  9.9980772e-01]
# Epoch 1/2
# 3110/3110 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.0000e+00 - loss: 0.0622
# Epoch 2/2
# 3110/3110 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - accuracy: 0.0000e+00 - loss: 1.2793e-05
# 12438/12438 ━━━━━━━━━━━━━━━━━━━━ 5s 381us/step
# a_3 = 26.5698
# hx_3 = [2.7842549e-05 7.6079436e-05 1.4911333e-04 ... 9.9981719e-01 9.9981928e-01
#  9.9980897e-01]
# Epoch 1/2
# 3110/3110 ━━━━━━━━━━━━━━━━━━━━ 9s 2ms/step - accuracy: 0.0000e+00 - loss: 0.0634
# Epoch 2/2
# 3110/3110 ━━━━━━━━━━━━━━━━━━━━ 7s 2ms/step - accuracy: 0.0000e+00 - loss: -6.2859e-04
# 12438/12438 ━━━━━━━━━━━━━━━━━━━━ 5s 397us/step
# a_4 = 57.3451
# hx_4 = [4.6444016e-05 2.1753869e-04 1.7002910e-04 ... 1.0003170e+00 1.0002558e+00
#  1.0006722e+00]
# Epoch 1/2
# 3110/3110 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.0000e+00 - loss: 0.0542
# Epoch 2/2
# 3110/3110 ━━━━━━━━━━━━━━━━━━━━ 7s 2ms/step - accuracy: 0.0000e+00 - loss: -0.0125
# 12438/12438 ━━━━━━━━━━━━━━━━━━━━ 5s 391us/step
# a_5 = 39478.4531
# hx_5 = [4.6444016e-05 2.1753869e-04 1.7002910e-04 ... 1.0003170e+00 1.0002558e+00
#  1.0006722e+00]
# Epoch 1/2
# 3110/3110 ━━━━━━━━━━━━━━━━━━━━ 9s 2ms/step - accuracy: 0.0000e+00 - loss: 0.0560
# Epoch 2/2
# 3110/3110 ━━━━━━━━━━━━━━━━━━━━ 7s 2ms/step - accuracy: 0.0000e+00 - loss: -0.0117
# 12438/12438 ━━━━━━━━━━━━━━━━━━━━ 5s 383us/step
# a_6 = 205664768.0000
# hx_6 = [4.6453802e-05 2.1753869e-04 1.7002910e-04 ... 1.0003170e+00 1.0002558e+00
#  1.0006722e+00]

# %%
# Assuming data_test and label_test are defined from your earlier train_test_split
# Ensure data_test has shape (n_samples, 1, 30) if needed by the model
if data_test.ndim == 2:
    data_test_input = data_test.reshape(-1, 1, data_test.shape[1])
else:
    data_test_input = data_test

hx = np.full(len(data_test_input), 0, dtype=np.float32)

# Go through each model in the trained ensemble
for model, alpha in estimators:
    prediction = model.predict(data_test_input).flatten()
    hx += alpha * prediction

# Threshold the accumulated predictions to get binary outputs
y_pred_binary = np.where(hx > 0.5, 1, 0)

from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

precision = precision_score(label_test, y_pred_binary)
recall = recall_score(label_test, y_pred_binary)
f1 = f1_score(label_test, y_pred_binary)
accuracy = accuracy_score(label_test, y_pred_binary)

print(f"Precision: {precision:.4f}")
print(f"Recall: {recall:.4f}")
print(f"F1 Score: {f1:.4f}")
print(f"Accuracy: {accuracy:.4f}")
# Out:
# 2671/2671 ━━━━━━━━━━━━━━━━━━━━ 1s 499us/step
# 2671/2671 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step
# 2671/2671 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step
# 2671/2671 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step
# 2671/2671 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step
# 2671/2671 ━━━━━━━━━━━━━━━━━━━━ 2s 589us/step
# Precision: 0.7808
# Recall: 0.8382
# F1 Score: 0.8085
# Accuracy: 0.9994

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

# Add after your existing metrics
cm = confusion_matrix(label_test, y_pred_binary)
print("Confusion Matrix:")
print(cm)

# Visualize confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', 
            xticklabels=['Negative', 'Positive'],
            yticklabels=['Negative', 'Positive'])
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')
plt.show()
# Out:
# Confusion Matrix:
# [[85275    32]
#  [   22   114]]

# %%
# (TP) shows how many fraud samples were successfully categorized.
TP = np.sum((label_test == 1) & (y_pred_binary == 1))
# (FP) refers to the number of legitimate samples that were incorrectly categorized.
FP = np.sum((label_test == 0) & (y_pred_binary == 1))
# (FN) shows how many fraud samples were missed.
FN = np.sum((label_test == 1) & (y_pred_binary == 0))
# (TN) refers to the number of legitimate samples that were correctly categorized.
TN = np.sum((label_test == 0) & (y_pred_binary == 0))

# Calculate the metrics
accuracy = (TP + TN) / (TP + FP + FN + TN)
specificity = TP / (FN + TP)
precision = TP / (FP + TP)
recall = TN / (TN + FP)
f1 = 2 * (precision * recall) / (precision + recall)

print(f"Accuracy: {accuracy:.4f}")
print(f"Specificity: {specificity:.4f}")
print(f"Precision: {precision:.4f}")
print(f"Recall: {recall:.4f}")
print(f"F1 Score: {f1:.4f}")
# Out:
# Accuracy: 0.9994
# Specificity: 0.8382
# Precision: 0.7808
# Recall: 0.9996
# F1 Score: 0.8768

# %%
# correct metrics found online

accuracy = (TP + TN) / (TP + FP + FN + TN)
precision = TP / (TP + FP + 1e-7)
recall = TP / (TP + FN + 1e-7)
specificity = TN / (TN + FP + 1e-7)
f1 = 2 * precision * recall / (precision + recall + 1e-7)

print(f"Accuracy    : {accuracy:.4f}")
print(f"Precision   : {precision:.4f}")
print(f"Recall      : {recall:.4f}")
print(f"Specificity : {specificity:.4f}")
print(f"F1 Score    : {f1:.4f}")
# Out:
# Accuracy    : 0.9994
# Precision   : 0.7808
# Recall      : 0.8382
# Specificity : 0.9996
# F1 Score    : 0.8085
